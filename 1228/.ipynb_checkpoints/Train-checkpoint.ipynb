# %%
# %matplotlib tk

import argparse
import gym
import datetime
import os
import random
import tempfile
import numpy as np
import pickle

import ray
from ray import tune
from ray.tune.logger import Logger, UnifiedLogger, pretty_print
from ray.rllib.env.multi_agent_env import make_multi_agent
from ray.rllib.examples.models.shared_weights_model import TF2SharedWeightsModel
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.framework import try_import_tf
from ray.rllib.utils.test_utils import check_learning_achieved
from ray.rllib.agents.ppo import ppo, PPOTrainer, PPOTFPolicy
from ray.rllib.agents.a3c.a3c_tf_policy import A3CTFPolicy
from ray.rllib.agents.a3c import a3c
from ray.rllib.models import ModelCatalog
from ray.rllib.policy.policy import PolicySpec
from environment_rllib_3d import MyEnv
from settings.initial_settings import *
from settings.reset_conditions import reset_conditions
#from modules.models import MyConv2DModel_v0B_Small_CBAM_1DConv_Share
from modules.models import DenseNetModelLarge
from tensorflow.keras.utils import plot_model
from modules.savers import save_conditions
from utility.result_env import render_env
from utility.terminate_uavsimproc import teminate_proc
from utility.latest_learned_file_path import latest_learned_file_path
from utility.save_logs import save_logs

import matplotlib.pyplot as plt
import matplotlib
import tensorflow as tf
import cv2
import ctypes
import warnings

#UCAV.exeが起動している場合、プロセスキルする。
teminate_proc.UAVsimprockill(proc_name="UCAV.exe")

warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
warnings.filterwarnings('ignore', category=matplotlib.MatplotlibDeprecationWarning)
np.set_printoptions(precision=3, suppress=True)
PROJECT = "UCAV"
TRIAL_ID = 2
TRIAL = 'test_' + str(TRIAL_ID)
EVAL_FREQ = 10
CONTINUAL = False
NUM_EVAL = 1
def custom_log_creator(custom_path, custom_str):
    timestr = datetime.datetime.today().strftime("%Y-%m-%d_%H-%M-%S")
    logdir_prefix = "{}_{}".format(custom_str, timestr)

    def logger_creator(config):
        if not os.path.exists(custom_path):
            os.makedirs(custom_path)
        logdir = tempfile.mkdtemp(prefix=logdir_prefix, dir=custom_path)
        return UnifiedLogger(config, logdir, loggers=None)

    return logger_creator

ray.shutdown()
ray.init(ignore_reinit_error=True, log_to_driver=False)

ModelCatalog.register_custom_model('my_model', DenseNetModelLarge)

# config = {"env": MyEnv,
#           "num_workers": NUM_WORKERS,
#           "num_gpus": NUM_GPUS,
#           "num_cpus_per_worker": NUM_CPUS_PER_WORKER,
#           "num_sgd_iter": NUM_SGD_ITER,
#           "lr": LEARNING_RATE,
#           "gamma": GAMMA,  # default=0.99
#           "model": {"custom_model": "my_model"}
#           # "framework": framework
#           }  # use tensorflow 2
eval_env = MyEnv({})
policies = {
    #"blue_1": PolicySpec(config={"gamma": 0.99}),
    #"blue_2": PolicySpec(config={"gamma": 0.95}),
    "blue_0": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space, {}),
    "blue_1": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space, {}),
    #"blue_0": (A3CTFPolicy, eval_env.observation_space, eval_env.action_space, {}),
    #"blue_1": (A3CTFPolicy, eval_env.observation_space, eval_env.action_space, {}),
}
policy_ids = list(policies.keys())

def policy_mapping_fn(agent_id, episode, **kwargs):
    #print(agent_id,episode)
    #pol_id = policy_ids[agent_id]

    pol_id = agent_id
    return pol_id

# Instanciate the evaluation env

config = {"env": MyEnv,"num_gpus": 0,"num_workers": 0, "num_cpus_per_worker": 0,"num_gpus_per_worker": 0,
          "create_env_on_driver": True,"train_batch_size": 600*5,"batch_mode": "complete_episodes",
          "shuffle_sequences": True, "gamma":0.999, "lr": 1e-5,
          "clip_actions":True,"normalize_actions":False,
          "observation_space":eval_env.observation_space,"action_space":eval_env.action_space,
          "explore":True,
          "sgd_minibatch_size": 200, "num_sgd_iter":20,
          "exploration_config": {"type": "StochasticSampling","random_timesteps":60000}, #PPO デフォルト
          "model":{"fcnet_activation": "tanh","fcnet_hiddens": [256, 256, 256],"post_fcnet_activation": "linear",},#"linear","relu","tanh" 
          #"model":{"fcnet_hiddens": [256, 256]},
          "multiagent": {"policies": policies,  "policy_mapping_fn": policy_mapping_fn}
         }
res_name = "sgd"+str(config["sgd_minibatch_size"])+"sgd_num"+str(config["num_sgd_iter"])+"lr"+str(config["lr"])+"gamma"+str(config["gamma"])
res_name = "test"
conditions_dir = os.path.join('./' + PROJECT + '/conditions/')

if not os.path.exists(conditions_dir):
    os.makedirs(conditions_dir)
save_conditions(conditions_dir)

# PPOTrainer()は、try_import_tfを使うと、なぜかTensorflowのeager modeのエラーになる。

trainer = ppo.PPOTrainer(config=config,
                         logger_creator=custom_log_creator(
                             os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))

if CONTINUAL:
    # Continual learning: Need to specify the checkpoint
    # model_path = PROJECT + '/checkpoints/' + TRIAL + '/checkpoint_000197/checkpoint-197'
    model_path = latest_learned_file_path('./UCAV/checkpoints/test_2/*')
    trainer.restore(checkpoint_path=model_path)

# models_dir = os.path.join('./' + PROJECT + '/models/')
# if not os.path.exists(models_dir):
#     os.makedirs(models_dir)
# text_name = models_dir + TRIAL + '.txt'
# with open(text_name, "w") as fp:
#     trainer.get_policy().model.base_model.summary(print_fn=lambda x: fp.write(x + "\r\n"))
# png_name = models_dir + TRIAL + '.png'
# plot_model(trainer.get_policy().model.base_model, to_file=png_name, show_shapes=True)



# Define checkpoint dir
check_point_dir = os.path.join('./' + PROJECT + '/checkpoints/', TRIAL)
if not os.path.exists(check_point_dir):
    os.makedirs(check_point_dir)
# Out:
# C:\Users\T-OHKI-MSI\miniconda3\envs\AI2\lib\site-packages\quaternion\numba_wrapper.py:23: UserWarning:
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Could not import from numba, which means that some
# parts of this code may run MUCH more slowly.  You
# may wish to install numba.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#   warnings.warn(warning_text)
# 2021-12-27 17:24:50,259	INFO trainer.py:723 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also want to then set `eager_tracing=True` in order to reach similar execution speed as with static-graph mode.
# 2021-12-27 17:24:50,260	INFO ppo.py:167 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# 2021-12-27 17:24:50,260	INFO trainer.py:745 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2021-12-27 17:24:51,442	WARNING deprecation.py:46 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# 2021-12-27 17:24:55,501	WARNING util.py:57 -- Install gputil for GPU system monitoring.

# %%
#def getkey(key):
    # return 111
#    return(bool(ctypes.windll.user32.GetAsyncKeyState(key) & 0x8000))
# Training & evaluation

record_mode = 0
results_dir = os.path.join('./' + PROJECT + '/results/')

if not os.path.exists(results_dir):
    os.makedirs(results_dir)
results_file = results_dir + TRIAL + '.pkl'
for steps in range(10001):
    # Training
    print(f'\n----------------- Training at steps:{steps} start! -----------------')
    eval_env.reset()
    results = trainer.train()
    save_logs(res_name,results,steps,CONTINUAL)
    print(pretty_print(results))
    #check_point = trainer.save(checkpoint_dir=check_point_dir)
    # Evaluation
    if steps % EVAL_FREQ == 0:
        print(f'\n----------------- Evaluation at steps:{steps} starting ! -----------------')
        #print(pretty_print(results))
        check_point = trainer.save(checkpoint_dir=check_point_dir)
        win = 0
        for i in range(NUM_EVAL):
            # print(f'\nEvaluation {i}:')
            obs = eval_env.reset()
            done = False
            
            step_num = 0
            fig = plt.figure(1,figsize=(8.0, 6.0))
            ESC = 0x1B          # ESCキーの仮想キーコード
            trajectory_length = 100
            env_blue_pos = [0]
            env_red_pos = [0]
            env_mrm_pos = [0]
            if record_mode == 0:
                file_name = "test_num" + str(steps) +str(i)
                video = cv2.VideoWriter(file_name+'.mp4',0x00000020,20.0,(800,600))

            while True:
                action_dict = {}
                for j in range(eval_env.blue_num):
                    #if not eval_env.blue[j].hitpoint == 0:
                    #action_dict['blue_' + str(j)] = trainer.compute_action(obs['blue_' + str(j)])
                    action_dict['blue_' + str(j)] = trainer.compute_single_action(obs['blue_' + str(j)],policy_id='blue_' + str(j),
                                                                       clip_action=True,explore=False)
                obs, rewards, dones, infos = eval_env.step(action_dict)
                env_blue_pos_temp, env_red_pos_temp, env_mrm_pos_temp= render_env.copy_from_env(eval_env)
                env_blue_pos.append(env_blue_pos_temp)
                env_red_pos.append(env_red_pos_temp)
                env_mrm_pos.append(env_mrm_pos_temp)
                if step_num == 0:
                    del env_blue_pos[0]
                    del env_red_pos[0]
                    del env_mrm_pos[0]

                hist_blue_pos = np.vstack(env_blue_pos)
                hist_red_pos = np.vstack(env_red_pos)
                hist_mrm_pos = np.vstack(env_mrm_pos)
                plt.clf()
                render_env.rend_3d(eval_env,hist_blue_pos,"b",1)
                render_env.rend_3d(eval_env,hist_red_pos,"r",1)
                render_env.rend_3d(eval_env,hist_mrm_pos,"k",1)
                fig.canvas.draw()
                plt.pause(.01)
                if record_mode == 0:
                    img = np.array(fig.canvas.renderer.buffer_rgba())
                    img = cv2.cvtColor(img, cv2.COLOR_RGBA2BGR)
                    # cv2.imshow('test', img)
                    # cv2.waitKey(1)
                    # cv2.destroyAllWindows()
                    video.write(img.astype('uint8'))

                
                step_num = step_num + 1
                
                done = dones["__all__"]
                #print(f'rewards:{rewards}')
                #if record_mode == 0:
                #    img = eval_env.render_movie(file_name,step_num)
                #    video.write(img.astype('unit8'))
                #elif record_mode == 1:
                #    eval_env.render()
                #elif record_mode == 2:
                #    eval_env.render()
                    
                #env_blue_pos_temp, env_red_pos_temp, env_mrm_pos_temp = render_env.copy_from_env(eval_env)
                
                #env_blue_pos.append(env_blue_pos_temp)
                #env_red_pos.append(env_red_pos_temp)
                #env_mrm_pos.append(env_mrm_pos_temp)
                #step_num = step_num + 1
                # エピソードの終了処理
                if dones['__all__']:
                    # print(f'all done at {env.steps}')
                    break
                
            #del env_blue_pos[0]
            #del env_red_pos[0]
            #del env_mrm_pos[0]
            
            #hist_blue_pos = np.vstack(env_blue_pos)
            #hist_red_pos = np.vstack(env_red_pos)
            #hist_mrm_pos = np.vstack(env_mrm_pos)
            
            #f = open(results_file,'wb')
            #pickle.dump(emv_blue_pos,f)
            #pickle.dump(emv_red_pos,f)
            #pickle.dump(emv_mrm_pos,f)
            #f.close()
            
            if record_mode == 0:
                video.release()

ray.shutdown()
# Out:
# ----------------- Training at steps:0 start! -----------------
# 72 blue_0 DOWN
# 388 blue_1 Shoot at red_1 launch distance : 99878.50471447798 True True
# 389 blue_1 Shoot at red_0 launch distance : 98806.53984934399 True True
# 591 blue_1 DOWN
# DOWN LOSE
# blue_0 True True 591 0.0 -10.0
# blue_1 True True 591 -10.0 -8.896896042000002
# 351 blue_0 Shoot at red_1 launch distance : 99849.55120079409 True True
# 352 blue_0 Shoot at red_0 launch distance : 95329.86303357412 True True
# 369 blue_0 DOWN
# 397 blue_1 DOWN
# DOWN LOSE
# blue_0 True True 397 0.0 -7.885431322000002
# blue_1 True True 397 -10.0 -10.0
# 394 blue_0 Shoot at red_1 launch distance : 98084.87847777556 True True
# 397 blue_0 Shoot at red_1 launch distance : 97294.32758902237 True True
# 418 blue_1 DOWN
# 548 red_0 Shoot at blue_0
# 670 blue_0 DOWN
# DOWN LOSE
# blue_0 True True 670 -10.0 -6.5336591340000325
# blue_1 True True 670 0.0 -10.0
# 143 blue_0 DOWN
# 336 blue_1 Shoot at red_1 launch distance : 99538.87626952596 True True
# 343 blue_1 Shoot at red_1 launch distance : 98520.83722746168 True True
# 588 red_0 Shoot at blue_1
# 713 blue_1 DOWN
# DOWN LOSE
# blue_0 True True 713 0.0 -10.0
# blue_1 True True 713 -9.99 -7.698686514000007
# 301 blue_0 Shoot at red_0 launch distance : 99681.16659128745 True True
# 304 blue_0 Shoot at red_0 launch distance : 98547.01766669552 True True
# 407 blue_1 Shoot at red_1 launch distance : 98767.93045315873 True True
# 411 blue_1 Shoot at red_1 launch distance : 98070.38191523473 True True
# 427 blue_1 DOWN
# 627 blue_0 DOWN
# DOWN LOSE
# blue_0 True True 627 -10.0 -7.745699328000002
# blue_1 True True 627 0.0 -8.645807789999992
# 376 blue_0 Shoot at red_0 launch distance : 99410.43230466307 True True
# 379 blue_1 Shoot at red_1 launch distance : 99685.98941175234 True True
# 382 blue_1 Shoot at red_1 launch distance : 98411.07451399969 True True
# 386 blue_0 Shoot at red_0 launch distance : 98455.21949597188 True True
# 730 blue_1 DOWN
# 934 blue_0 DOWN
# DOWN LOSE
# blue_0 True True 934 -10.0 -9.051728594000002
# blue_1 True True 934 0.0 -8.974072143999997
# 2021-12-27 17:32:02,000	WARNING deprecation.py:46 -- DeprecationWarning: `slice` has been deprecated. Use `SampleBatch[start:stop]` instead. This will raise an error in the future!
# agent_timesteps_total: 7864
# custom_metrics: {}
# date: 2021-12-27_17-32-06
# done: false
# episode_len_mean: 655.3333333333334
# episode_media: {}
# episode_reward_max: -16.391507118000007
# episode_reward_mean: -17.57199681133335
# episode_reward_min: -18.896896042000016
# episodes_this_iter: 6
# episodes_total: 6
# experiment_id: c4232e2b103e4eb18e399aa6710cb694
# hostname: MSI
# info:
#   learner:
#     blue_0:
#       custom_metrics: {}
#       learner_stats:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 9.999999747378752e-06
#         entropy: 5.620853900909424
#         entropy_coeff: 0.0
#         kl: 0.0004065053362865001
#         model: {}
#         policy_loss: 0.2715906500816345
#         total_loss: 28.495996475219727
#         vf_explained_var: -0.10276545584201813
#         vf_loss: 28.224323272705078
#     blue_1:
#       custom_metrics: {}
#       learner_stats:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 9.999999747378752e-06
#         entropy: 5.626967906951904
#         entropy_coeff: 0.0
#         kl: 0.0002989543427247554
#         model: {}
#         policy_loss: 0.28582823276519775
#         total_loss: 41.67626953125
#         vf_explained_var: 0.004850015509873629
#         vf_loss: 41.390377044677734
#   num_agent_steps_sampled: 7864
#   num_agent_steps_trained: 7864
#   num_steps_sampled: 3932
#   num_steps_trained: 3932
# iterations_since_restore: 1
# node_ip: 127.0.0.1
# num_healthy_workers: 0
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 47.55287162162163
#   ram_util_percent: 50.41030405405406
# pid: 17268
# policy_reward_max:
#   blue_0: -6.5336591340000325
#   blue_1: -7.698686514000007
# policy_reward_mean:
#   blue_0: -8.53608639633334
#   blue_1: -9.035910415
# policy_reward_min:
#   blue_0: -10.0
#   blue_1: -10.0
# sampler_perf:
#   mean_action_processing_ms: 0.41627186780784564
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 99.06870585920973
#   mean_inference_ms: 3.080631375403735
#   mean_raw_obs_processing_ms: 5.132608913205338
# time_since_restore: 428.28262543678284
# time_this_iter_s: 428.28262543678284
# time_total_s: 428.28262543678284
# timers:
#   learn_throughput: 853.746
#   learn_time_ms: 4605.587
#   load_throughput: 0.0
#   load_time_ms: 0.0
#   sample_throughput: 9.219
#   sample_time_ms: 426498.754
# timestamp: 1640593926
# timesteps_since_restore: 0
# timesteps_this_iter: 0
# timesteps_total: 3932
# training_iteration: 1
# trial_id: default
#
#
# ----------------- Evaluation at steps:0 starting ! -----------------
# 2021-12-27 17:32:10,601	WARNING deprecation.py:46 -- DeprecationWarning: `compute_action` has been deprecated. Use `compute_single_action` instead. This will raise an error in the future!
# 2021-12-27 17:32:10,602	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:10,687	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:11,080	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:11,084	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:11,301	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:11,303	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:11,514	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:11,517	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:11,751	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:11,754	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:11,976	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:11,979	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:12,211	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:12,215	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:12,436	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:12,439	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:12,653	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:12,656	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:12,864	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:12,867	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:13,069	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:13,072	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:13,420	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:13,422	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:13,618	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:13,621	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:13,828	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:13,831	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:14,036	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:14,039	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:14,240	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:14,242	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:14,446	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:14,448	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:14,658	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:14,661	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:14,867	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:14,870	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:15,069	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:15,072	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:15,267	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:15,270	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:15,471	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:15,474	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:15,676	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:15,679	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:15,883	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:15,885	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:16,087	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:16,089	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:16,290	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:16,292	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:16,495	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:16,498	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:16,695	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:16,698	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:16,901	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:16,904	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:17,095	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:17,098	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:17,304	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:17,307	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:17,510	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:17,513	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:17,707	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:17,710	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:18,067	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:18,070	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:18,279	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:18,282	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:18,486	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:18,490	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:18,698	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:18,701	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:18,900	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:18,903	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:19,096	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:19,099	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:19,305	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:19,308	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:19,509	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:19,512	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:19,703	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:19,706	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:19,903	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:19,906	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:20,101	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:20,104	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:20,304	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:20,307	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:20,503	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:20,507	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:20,705	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:20,707	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:20,913	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:20,916	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:21,116	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:21,119	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:21,314	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:21,317	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:21,523	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:21,525	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:21,723	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:21,727	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:21,921	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:21,924	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:22,128	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:22,131	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:22,337	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:22,341	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:22,716	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:22,719	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:22,913	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:22,916	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:23,110	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:23,114	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:23,315	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:23,319	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:23,532	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:23,535	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:23,738	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:23,741	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:23,938	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:23,942	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:24,141	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:24,144	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:24,342	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:24,346	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:24,557	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:24,560	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:24,750	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:24,753	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:24,958	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:24,961	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:25,153	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:25,156	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:25,362	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:25,366	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:25,568	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:25,571	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:25,771	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:25,774	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:25,973	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:25,976	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:26,173	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:26,176	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:26,365	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:26,369	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:26,567	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:26,570	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:26,777	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:26,779	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:26,975	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:26,978	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:27,345	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:27,348	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:27,548	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:27,551	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:27,750	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:27,753	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:27,961	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:27,964	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:28,158	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:28,161	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:28,362	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:28,365	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:28,566	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:28,569	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:28,771	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:28,774	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:28,968	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:32:28,971	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# ...
# 2021-12-27 17:35:02,527	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:02,744	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:02,747	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:02,962	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:02,966	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:03,179	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:03,182	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:03,550	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:03,554	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:03,774	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:03,777	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:03,990	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:03,993	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:04,214	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:04,217	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:04,429	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:04,433	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:04,653	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:04,656	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:04,869	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:04,873	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:05,089	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:05,093	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:05,307	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 759 red_0 Splash :blue_1
# 2021-12-27 17:35:05,310	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:05,516	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:05,519	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:05,748	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:05,752	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:05,964	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:05,967	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:06,196	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:06,199	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:06,570	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:06,573	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:06,794	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:06,797	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:07,010	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:07,013	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:07,229	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:07,232	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:07,444	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:07,447	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:07,676	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:07,679	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:07,907	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:07,911	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:08,136	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:08,139	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:08,378	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:08,381	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:08,613	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:08,616	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:08,848	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:08,851	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:09,072	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:09,075	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:09,308	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:09,311	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:09,696	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:09,699	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:09,933	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 2021-12-27 17:35:09,936	WARNING deprecation.py:46 -- DeprecationWarning: `Trainer.compute_single_action(`clip_actions`=...)` has been deprecated. Use `Trainer.compute_single_action(`clip_action`=...)` instead. This will raise an error in the future!
# 779 red_1 Splash :blue_0
# TIME LIMIT LOSE
# blue_0 False True 779 -9.99 -6.992746294000021
# blue_1 False True 779 0.01 3.451401851999972
#
# ----------------- Training at steps:1 start! -----------------
