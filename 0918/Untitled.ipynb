# %%
import ray_env

# %%
ray_env.main()
# Out:
# 2021-09-19 13:47:57,002	INFO worker.py:836 -- Calling ray.init() again after it has already been called.
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\anaconda3\envs\AI\lib\site-packages\redis\connection.py in connect(self)
#     558         try:
# --> 559             sock = self._connect()
#     560         except socket.timeout:
#
# ~\anaconda3\envs\AI\lib\site-packages\redis\connection.py in _connect(self)
#     614         if err is not None:
# --> 615             raise err
#     616         raise socket.error("socket.getaddrinfo returned an empty list")
#
# ~\anaconda3\envs\AI\lib\site-packages\redis\connection.py in _connect(self)
#     602                 # connect
# --> 603                 sock.connect(socket_address)
#     604
#
# ConnectionRefusedError: [WinError 10061] 対象のコンピューターによって拒否されたため、接続できませんでした。
#
# ...
