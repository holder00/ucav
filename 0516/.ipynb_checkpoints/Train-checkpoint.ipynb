# %%
# %matplotlib tk

import argparse
import gym
import datetime
import os
import random
import tempfile
import numpy as np
import pickle

import ray
from ray import tune
from ray.tune.logger import Logger, UnifiedLogger, pretty_print
from ray.rllib.env.multi_agent_env import make_multi_agent
from ray.rllib.examples.models.shared_weights_model import TF2SharedWeightsModel
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.framework import try_import_tf
from ray.rllib.utils.test_utils import check_learning_achieved
from ray.rllib.agents.ppo import ppo, PPOTrainer, PPOTFPolicy
from ray.rllib.agents.a3c.a3c_tf_policy import A3CTFPolicy
from ray.rllib.agents.a3c import a3c
from ray.rllib.models import ModelCatalog
from ray.rllib.policy.policy import PolicySpec
from environment_rllib_3d3 import MyEnv
#from test_env_for_lstm import MyEnv
from settings.initial_settings import *
from settings.reset_conditions import reset_conditions

from tensorflow.keras.utils import plot_model
from modules.savers import save_conditions
from utility.result_env import render_env
from utility.terminate_uavsimproc import teminate_proc
from utility.latest_learned_file_path import latest_learned_file_path
from utility.read_wright_weights import save_weights
from utility.read_wright_weights import reload_weights
from utility.save_logs import save_logs
from utility.save_logs import save_hists
from utility.save_logs import save_env_info

import matplotlib.pyplot as plt
import matplotlib
import tensorflow as tf
import cv2
import ctypes
import warnings

#UCAV.exeが起動している場合、プロセスキルする。
teminate_proc.UAVsimprockill(proc_name="UCAV.exe")

warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
warnings.filterwarnings('ignore', category=matplotlib.MatplotlibDeprecationWarning)
np.set_printoptions(precision=3, suppress=True)
PROJECT = "UCAV"
TRIAL_ID = 2
TRIAL = 'test_' + str(TRIAL_ID)
EVAL_FREQ = 1
CONTINUAL = False
NUM_EVAL = 1
def custom_log_creator(custom_path, custom_str):
    timestr = datetime.datetime.today().strftime("%Y-%m-%d_%H-%M-%S")
    logdir_prefix = "{}_{}".format(custom_str, timestr)

    def logger_creator(config):
        if not os.path.exists(custom_path):
            os.makedirs(custom_path)
        logdir = tempfile.mkdtemp(prefix=logdir_prefix, dir=custom_path)
        return UnifiedLogger(config, logdir, loggers=None)

    return logger_creator

ray.shutdown()
ray.init(ignore_reinit_error=True, log_to_driver=False)

#ModelCatalog.register_custom_model('my_model', MyRNNUAVClass)
eval_env = MyEnv({"eval":True})
policy_own_config = (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
                 {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},
                  "exploration_config": {"type": "StochasticSampling","random_timesteps":0},"explore":True,})
policy_enem_config = (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
                 {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},
                  "exploration_config": {"type": "StochasticSampling","random_timesteps":0},"explore":False,})
policies_own = {}
policies_enem = {}
for i in range(eval_env.blue_num):
    policies_own["blue_"+str(i)] = policy_own_config
for i in range(eval_env.red_num):
    policies_enem["red_"+str(i)] = policy_enem_config

def policy_mapping_fn(agent_id, episode, **kwargs):
    #print(agent_id,episode)
    #pol_id = policy_ids[agent_id]

    pol_id = agent_id
    return pol_id

# Instanciate the evaluation env
config_own = ppo.DEFAULT_CONFIG.copy()
config_own = {"env": MyEnv,"env_config": {"eval":False},
              "num_gpus": 1,"num_workers": 0,"num_gpus_per_worker": 1,"num_envs_per_worker":eval_env.env_max,
          "train_batch_size": 1200*25,
          "batch_mode": "complete_episodes",
          "gamma":0.995, "lr": 2.5e-4,"shuffle_sequences": True,
          "observation_space":eval_env.observation_space,"action_space":eval_env.action_space,
          "sgd_minibatch_size": 600, "num_sgd_iter":20,
          "multiagent": {"policies": policies_own,  "policy_mapping_fn": policy_mapping_fn}
         }
#config_enem = ppo.DEFAULT_CONFIG.copy()
#config_enem = {"env": MyEnv,"num_gpus": 1,"num_workers": 0, "num_gpus_per_worker": 1,"num_envs_per_worker":1,
#          "train_batch_size": 600,
#          "batch_mode": "complete_episodes",
#          "gamma":0.995, "lr": 2.5e-4,"shuffle_sequences": True,
#          "observation_space":eval_env.observation_space,"action_space":eval_env.action_space,
#          "sgd_minibatch_size": 600, "num_sgd_iter":20,
#          "multiagent": {"policies": policies_enem,  "policy_mapping_fn": policy_mapping_fn}
#         }

res_name = "test"
conditions_dir = os.path.join('./' + PROJECT + '/conditions/')

if not os.path.exists(conditions_dir):
    os.makedirs(conditions_dir)
save_conditions(conditions_dir)

# PPOTrainer()は、try_import_tfを使うと、なぜかTensorflowのeager modeのエラーになる。

trainer = ppo.PPOTrainer(config=config_own,
                         logger_creator=custom_log_creator(
                             os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))

#adversary = ppo.PPOTrainer(config=config_enem,
#                         logger_creator=custom_log_creator(
#                             os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))

if CONTINUAL:
    # Continual learning: Need to specify the checkpoint
    # model_path = PROJECT + '/checkpoints/' + TRIAL + '/checkpoint_000197/checkpoint-197'
    model_path = latest_learned_file_path('./UCAV/checkpoints/test_2/*')
    
    #trainer.restore(checkpoint_path=model_path)
    #save_weights("blue_0",trainer)
    #save_weights("blue_1",trainer)

    #reload_weights(policy_id="red_0",trainer=trainer,set_policy_id="blue_0")
    #reload_weights(policy_id="red_1",trainer=trainer,set_policy_id="blue_1")
    for i in range(eval_env.blue_num):
        reload_weights(policy_id="blue_"+str(i),trainer=trainer,set_policy_id="blue_"+str(i))

    #save_weights("red_0",trainer)
    #save_weights("red_1",trainer)


models_dir = os.path.join('./' + PROJECT + '/models/')
if not os.path.exists(models_dir):
    os.makedirs(models_dir)
hist_dir = os.path.join('./' + PROJECT + '/hist/')
if not os.path.exists(hist_dir):
    os.makedirs(hist_dir)

for j in range(2):
    text_name = models_dir + TRIAL + "blue_"+str(j) +'.txt'
    with open(text_name, "w") as fp:
        trainer.get_policy("blue_"+str(j)).model.base_model.summary(print_fn=lambda x: fp.write(x + "\r\n"))
    png_name = models_dir + TRIAL + '.png'
    plot_model(trainer.get_policy("blue_"+str(j)).model.base_model, to_file=png_name, show_shapes=True)



# Define checkpoint dir
check_point_dir = os.path.join('./' + PROJECT + '/checkpoints/', TRIAL)
if not os.path.exists(check_point_dir):
    os.makedirs(check_point_dir)
# Out:
# C:\Users\Takumi\anaconda3\envs\AI2\lib\site-packages\ale_py\roms\utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# C:\Users\Takumi\anaconda3\envs\AI2\lib\site-packages\quaternion\numba_wrapper.py:23: UserWarning:
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Could not import from numba, which means that some
# parts of this code may run MUCH more slowly.  You
# may wish to install numba.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#   warnings.warn(warning_text)
# 2022-05-04 11:50:10,518	INFO trainer.py:2141 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# 2022-05-04 11:50:10,519	WARNING ppo.py:231 -- `train_batch_size` (30000) cannot be achieved with your other settings (num_workers=0 num_envs_per_worker=4 rollout_fragment_length=200)! Auto-adjusting `rollout_fragment_length` to 7500.
# 2022-05-04 11:50:10,520	INFO ppo.py:250 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# 2022-05-04 11:50:10,520	INFO trainer.py:781 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2022-05-04 11:50:23,922	INFO trainable.py:130 -- Trainable.setup took 13.405 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-05-04 11:50:23,923	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
eval_env.reset()
save_env_info(eval_env)
record_mode = 0
results_dir = os.path.join('./' + PROJECT + '/results/')
rewards = {}
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
results_file = results_dir + TRIAL + '.pkl'
for steps in range(10001):
    # Training
    print(f'\n----------------- Training at steps:{steps} start! -----------------')
    eval_env.eval = False
    eval_env.self_play = False
    eval_env.reset()
    proc_list = [0]*eval_env.env_max
    f = open("proc_list"+".pkl",'wb')
    pickle.dump(proc_list,f)
    f.close()
    results = trainer.train()
    save_logs(res_name,results,steps,CONTINUAL,eval_env.blue_num)
    for j in range(eval_env.blue_num):
        save_weights("blue_"+str(j),trainer)
    print(pretty_print(results))
    #check_point = trainer.save(checkpoint_dir=check_point_dir)
    # Evaluation
    if steps % EVAL_FREQ == 0:
        print(f'\n-------------- Evaluation at steps:{steps} starting ! --------------')

        check_point = trainer.save(checkpoint_dir=check_point_dir)
        for i in range(NUM_EVAL):
            # print(f'\nEvaluation {i}:')
            model_path = latest_learned_file_path('./UCAV/checkpoints/test_2/*')
            #trainer.restore(checkpoint_path=model_path)
            trainer = ppo.PPOTrainer(config=config_own,
                         logger_creator=custom_log_creator(
                             os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))
            for j in range(eval_env.blue_num):
                reload_weights(policy_id="blue_"+str(j),trainer=trainer,set_policy_id="blue_"+str(j))
            eval_env.eval = True
            obs = eval_env.reset()
            done = False
            
            step_num = 0
            #fig = plt.figure(1,figsize=(8.0, 6.0))
            ESC = 0x1B          # ESCキーの仮想キーコード
            trajectory_length = 100

            cell_size = 256
            state_0=[np.zeros(cell_size, np.float32),np.zeros(cell_size, np.float32)]
            action_dict0 = [0,0]
            
            state_0=[state_0]*eval_env.blue_num
            action_dict0 = [action_dict0]*eval_env.blue_num
            
            for j in range(eval_env.blue_num):
                rewards["blue_"+str(j)] = 0

            if record_mode == 0:
                file_name = "test_num" + str(steps) +str(i)
                #video = cv2.VideoWriter(file_name+'.mp4',0x00000020,20.0,(800,600))

            while True:
                action_dict = {}
                for j in range(eval_env.blue_num):
                    action_temp = trainer.compute_single_action(obs["blue_"+str(j)],
                                                                state=state_0[j],prev_action=None,prev_reward=None,
                                                                policy_id="blue_"+str(j),explore=False)
                    state_0[j] = action_temp[1]
                    action_dict["blue_"+str(j)] = action_temp[0]
                obs, rewards, dones, infos = eval_env.step(action_dict)
                env_blue_pos_temp_mod, env_red_pos_temp_mod, env_mrm_pos_temp_mod = render_env.copy_from_env_mod(eval_env)
                if eval_env.timer == 1:
                    env_blue_pos_mod = env_blue_pos_temp_mod
                    env_red_pos_mod = env_red_pos_temp_mod
                    env_mrm_pos_mod = env_mrm_pos_temp_mod
                else:
                    env_blue_pos_mod = np.vstack([env_blue_pos_mod,env_blue_pos_temp_mod])
                    env_red_pos_mod = np.vstack([env_red_pos_mod,env_red_pos_temp_mod])
                    env_mrm_pos_mod = np.vstack([env_mrm_pos_mod,env_mrm_pos_temp_mod])


                #if record_mode == 0:
                    #img = np.array(fig.canvas.renderer.buffer_rgba())
                    #img = cv2.cvtColor(img, cv2.COLOR_RGBA2BGR)
                    #video.write(img.astype('uint8'))

                
                step_num = step_num + 1
                
                done = dones["__all__"]
                
                #print(f'rewards:{rewards}')
                #if record_mode == 0:
                #    img = eval_env.render_movie(file_name,step_num)
                #    video.write(img.astype('unit8'))
                #elif record_mode == 1:
                #    eval_env.render()
                #elif record_mode == 2:
                #    eval_env.render()

                # エピソードの終了処理
                if dones['__all__']:
                    save_hists("blue_"+str(i),steps,env_blue_pos_mod,hist_dir)
                    save_hists("red_"+str(i),steps,env_red_pos_mod,hist_dir)
                    save_hists("mrm_"+str(i),steps,env_mrm_pos_mod,hist_dir)
                    for j in range(eval_env.blue_num):
                        save_weights("blue_"+str(j),trainer)
                    #save_weights("blue_1",trainer)
                    #save_weights("blue_2",trainer)
                    # print(f'all done at {env.steps}')
                    break
                

            
            #if record_mode == 0:
               # video.release()

ray.shutdown()
# Out:
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
#
# ----------------- Training at steps:0 start! -----------------
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 88 blue_1 DOWN
# 0 91 blue_0 DOWN
# 2 200 blue_0 Shoot at red_1 launch distance : 55466.51930669528 True True
# 2 212 blue_0 Shoot at red_1 launch distance : 49289.084653704005 True True
# 2 246 red_0 Shoot at blue_0
# 2 257 red_0 Shoot at blue_0
# 0 295 blue_1 Shoot at red_1 launch distance : 59231.591385003325 True True
# 2 304 blue_0: Destroyed
# 2 TIME LIMIT LOSE
# 2 blue_0 False False 304 0.35833462666666666 78.43166143999997
# 2 blue_1 False False 304 -0.10133474 -1.5128951133333333
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 Same tgt shoot
# 0 310 blue_1 Shoot at red_0 launch distance : 54734.83871356524 True True
# 1 366 red_0 Shoot at blue_1
# 1 375 red_1 Shoot at blue_1
# 1 377 red_0 Shoot at blue_1
# 1 386 red_1 Shoot at blue_1
# 0 410 blue_1 Splash :red_0
# 0 411 blue_1 Splash :red_1
# 0 WIN
# 0 blue_0 False True 411 12.82123268919708 11.612987535863747
# 0 blue_1 False True 411 28.76164874759124 151.23820090417667
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 430 blue_1: Destroyed
# 2 164 blue_1 Shoot at red_0 launch distance : 59903.18085878245 True True
# 2 Same tgt shoot
# 2 177 blue_1 Shoot at red_1 launch distance : 57187.74380057321 True True
# 2 Same tgt shoot
# 2 213 blue_0 Shoot at red_1 launch distance : 59973.961591677435 True True
# 2 Same tgt shoot
# 2 224 blue_0 Shoot at red_1 launch distance : 59201.74626647427 True True
# 3 537 red_1 Shoot at blue_0
# 3 548 red_1 Shoot at blue_0
# 3 560 red_0 Shoot at blue_0
# 3 571 red_0 Shoot at blue_0
# 2 279 blue_1 Splash :red_0
# 0 176 blue_0 Shoot at red_0 launch distance : 57523.43530249215 True True
# 2 284 blue_1 Splash :red_1
# 3 592 blue_0: Destroyed
# 0 191 blue_1 Shoot at red_0 launch distance : 58897.973080573836 True True
# 0 206 blue_1 Shoot at red_0 launch distance : 51200.67656779547 True True
# 0 246 red_1 Shoot at blue_1
# 0 256 blue_0 DOWN
# 0 257 red_1 Shoot at blue_1
# 0 293 blue_0 Splash :red_0
# 0 317 blue_1: Destroyed
# 0 TIME LIMIT LOSE
# 0 blue_0 False False 317 0.9000495633333333 65.64445911653017
# 0 blue_1 False False 317 0.8600393633333333 95.19358433333333
# 2 WIN
# 2 blue_0 False True 424 12.731704222578616 89.95502033591187
# 2 blue_1 False True 424 12.83170925591195 156.91834796556594
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 128 blue_1 DOWN
# 2 139 blue_0 DOWN
# 2 153 blue_1 Shoot at red_1 launch distance : 57699.25463123419 True True
# 2 164 blue_1 Shoot at red_1 launch distance : 52454.80135316499 True True
# 2 203 red_0 Shoot at blue_1
# 2 214 red_0 Shoot at blue_1
# 2 265 blue_1 Splash :red_1
# 2 274 blue_1: Destroyed
# 2 TIME LIMIT LOSE
# 2 blue_0 False False 274 0.9000500866666666 2.64333819
# 2 blue_1 False False 274 0.86018392 117.3626003035849
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 45 blue_1 DOWN
# 2 153 blue_0 Shoot at red_1 launch distance : 58644.37945788155 True True
# 2 Same tgt shoot
# 2 165 blue_0 Shoot at red_0 launch distance : 56562.660996455954 True True
# 1 TIME LIMIT LOSE
# 1 blue_0 False False 1200 -0.11264418 -100.28072598000001
# 1 blue_1 False False 1200 -0.10064418 -10.947744676666664
# 3 TIME LIMIT LOSE
# 3 blue_0 False False 1200 -0.10090107333333334 -33.31490127666667
# 3 blue_1 False False 1200 -0.10690107333333335 -85.05128421000013
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 248 blue_0 DOWN
# 2 TIME LIMIT LOSE
# 2 blue_0 False False 248 -0.60124509 61.632352576666676
# 2 blue_1 False False 248 -0.10125269 -1.4082399166666666
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 113 blue_1 DOWN
# 2 102 blue_0 DOWN
# 1 160 blue_0 Shoot at red_0 launch distance : 59501.66735478931 True True
# 1 Same tgt shoot
# 1 172 blue_0 Shoot at red_1 launch distance : 55121.66482427758 True True
# 3 175 blue_1 Shoot at red_0 launch distance : 59183.84788098861 True True
# 3 190 blue_1 Shoot at red_0 launch distance : 53135.36236820071 True True
# 2 181 blue_1 DOWN
# 2 TIME LIMIT LOSE
# 2 blue_0 False False 181 -0.1012855 -1.3122904366666666
# 2 blue_1 False False 181 -1.1052851 -1.761569703333333
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 247 red_1 Shoot at blue_1
# 3 258 red_1 Shoot at blue_1
# 1 268 blue_0 Splash :red_0
# 1 277 blue_0 Splash :red_1
# 1 WIN
# 1 blue_0 False True 277 33.49793719169675 155.0487839956271
# 1 blue_1 False True 277 14.233669230565585 13.019218200565586
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 296 blue_1 Splash :red_0
# 3 306 blue_1: Destroyed
# 1 72 blue_1 DOWN
# 2 133 blue_1 DOWN
# 2 199 blue_0 Shoot at red_1 launch distance : 58983.74483703116 True True
# 2 Same tgt shoot
# 2 210 blue_0 Shoot at red_0 launch distance : 59769.853228864464 True True
# 1 177 blue_0 Shoot at red_1 launch distance : 58621.90008008952 True True
# 1 192 blue_0 Shoot at red_1 launch distance : 51229.89409514722 True True
# 1 219 red_0 Shoot at blue_0
# 1 230 red_0 Shoot at blue_0
# 2 313 blue_0 Splash :red_1
# 2 326 blue_0 Splash :red_0
# 2 WIN
# 2 blue_0 False True 326 31.544478555276072 157.23617654466906
# 2 blue_1 False True 326 13.58250623175869 12.16302122175869
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 289 blue_0: Destroyed
# 1 TIME LIMIT LOSE
# 1 blue_0 False False 289 0.35861822 104.82572519666667
# 1 blue_1 False False 289 -0.10133181333333334 -1.5118980666666668
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 TIME LIMIT LOSE
# 0 blue_0 False False 1200 -0.006348503333333333 -55.936961666666626
# 0 blue_1 False False 1200 -0.10235403666666668 -1.5166909533333333
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 192 blue_0 Shoot at red_0 launch distance : 59937.996771663966 True True
# 2 205 blue_0 Shoot at red_0 launch distance : 59558.18125161312 True True
# 1 203 blue_0 Shoot at red_0 launch distance : 55229.6067793353 True True
# 2 216 blue_1 Shoot at red_0 launch distance : 59841.1907468426 True True
# 2 Same tgt shoot
# 2 Same tgt shoot
# 2 217 blue_0 Shoot at red_1 launch distance : 59634.92639385078 True True
# 2 Same tgt shoot
# 2 Same tgt shoot
# 2 235 blue_1 Shoot at red_1 launch distance : 58037.03649394927 True True
# 1 230 red_1 Shoot at blue_0
# 1 241 red_1 Shoot at blue_0
# 1 300 blue_0: Destroyed
# 2 317 blue_0 Splash :red_0
# 1 315 blue_0 Splash :red_0
# 2 332 blue_0 Splash :red_1
# 2 WIN
# 2 blue_0 False True 435 12.760166332988506 151.37103260362125
# 2 blue_1 False True 435 12.760166332988506 115.1750887563217
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 292 blue_1 Shoot at red_1 launch distance : 59193.95395646417 True True
# 0 304 blue_1 Shoot at red_1 launch distance : 54167.77087900147 True True
# 0 338 red_0 Shoot at blue_1
# 0 349 red_0 Shoot at blue_1
# 0 406 blue_1: Destroyed
# 0 410 blue_1 Splash :red_1
# 3 TIME LIMIT LOSE
# 3 blue_0 False False 1200 0.8935813566666666 -91.84963470666668
# 3 blue_1 False False 1200 0.8995762566666666 88.16197564144146
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 188 blue_0 Shoot at red_1 launch distance : 58729.92508934436 True True
# 3 Same tgt shoot
# 3 203 blue_0 Shoot at red_0 launch distance : 59787.19981735221 True True
# 2 455 red_1 Shoot at blue_0
# 2 466 red_1 Shoot at blue_0
# 2 472 red_0 Shoot at blue_0
# 2 483 red_0 Shoot at blue_0
# 3 300 blue_0 Splash :red_1
# 2 518 blue_0: Destroyed
# 3 317 blue_0 Splash :red_0
# 3 WIN
# 3 blue_0 False True 317 31.858005380304938 154.81081230363827
# 3 blue_1 False True 317 13.787033028990535 11.746988685657202
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 199 blue_0 Shoot at red_0 launch distance : 58367.75612442198 True True
# 1 TIME LIMIT LOSE
# 1 blue_0 False False 1200 0.90045199 105.66748570904757
# 1 blue_1 False False 1200 0.89445199 -37.69907903333335
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 780 blue_1 DOWN
# 2 TIME LIMIT LOSE
# 2 blue_0 False False 780 -0.10153133 -27.092300783333318
# 2 blue_1 False False 780 -1.10153893 -40.001920359999986
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 289 red_1 Shoot at blue_0
# 3 300 red_1 Shoot at blue_0
# 3 316 blue_0 Splash :red_0
# 2 63 blue_1 DOWN
# 3 361 blue_0: Destroyed
# 0 TIME LIMIT LOSE
# 0 blue_0 False False 1200 0.8980954233333334 -24.860707713333333
# 0 blue_1 False False 1200 0.9000954233333334 92.26011424658536
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 246 blue_1 Shoot at red_0 launch distance : 54239.30430047937 True True
# 1 259 blue_1 Shoot at red_0 launch distance : 47562.50361366609 True True
# 1 275 red_0 Shoot at blue_1
# 1 288 red_1 Shoot at blue_1
# 1 299 red_1 Shoot at blue_1
# 1 345 blue_1 Splash :red_0
# 1 353 blue_1: Destroyed
# 0 215 blue_1 Shoot at red_1 launch distance : 59039.943936287746 True True
# 0 226 blue_1 Shoot at red_1 launch distance : 53910.83654516965 True True
# 0 265 red_0 Shoot at blue_1
# 0 276 red_0 Shoot at blue_1
# 0 327 blue_1: Destroyed
# 0 329 blue_1 Splash :red_1
# 2 670 red_0 Shoot at blue_0
# 2 676 red_1 Shoot at blue_0
# 2 681 red_0 Shoot at blue_0
# 2 687 red_1 Shoot at blue_0
# 2 732 blue_0: Destroyed
# 2 TIME LIMIT LOSE
# 2 blue_0 False False 732 -0.1392092533333333 -25.107236586666662
# 2 blue_1 False False 732 -0.10186065333333334 -1.4082171466666666
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 197 blue_0 Shoot at red_0 launch distance : 59241.181385924436 True True
# 2 208 blue_0 Shoot at red_0 launch distance : 53452.11746039627 True True
# 3 TIME LIMIT LOSE
# 3 blue_0 False False 1200 0.9005165133333333 63.72446375886074
# 3 blue_1 False False 1200 0.8945165133333333 -30.334738523333293
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 245 red_1 Shoot at blue_0
# 2 256 red_1 Shoot at blue_0
# 2 Same tgt shoot
# 2 Same tgt shoot
# 2 274 blue_1 Shoot at red_1 launch distance : 57751.98858048093 True True
# 2 Same tgt shoot
# 2 Same tgt shoot
# 2 285 blue_1 Shoot at red_1 launch distance : 52984.39058817229 True True
# 2 306 blue_0 Splash :red_0
# 3 135 blue_0 DOWN
# 2 356 blue_1 Splash :red_1
# 3 144 blue_1 DOWN
# 3 TIME LIMIT LOSE
# 3 blue_0 False False 144 -0.10122565666666668 -1.2182544933333335
# 3 blue_1 False False 144 -0.7052172233333334 2.23914379
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 TIME LIMIT LOSE
# 1 blue_0 False False 1200 0.8945303133333333 -35.11530305333327
# 1 blue_1 False False 1200 0.9005303133333333 105.53094277913047
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 WIN
# 2 blue_0 False True 485 12.375767007457044 144.96296633569122
# 2 blue_1 False True 485 12.475767007457044 131.91960938116537
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 175 blue_1 Shoot at red_0 launch distance : 58820.58082848213 True True
# 3 184 blue_0 Shoot at red_0 launch distance : 57429.540186214275 True True
# 3 Same tgt shoot
# 3 Same tgt shoot
# 3 190 blue_1 Shoot at red_1 launch distance : 56381.432972211696 True True
# 3 Same tgt shoot
# 3 Same tgt shoot
# 3 200 blue_0 Shoot at red_1 launch distance : 55153.13011062926 True True
# 0 TIME LIMIT LOSE
# 0 blue_0 False False 1200 0.9002690333333333 -69.33793861666682
# 0 blue_1 False False 1200 0.9002690333333333 93.78290577674771
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 166 blue_0 Shoot at red_0 launch distance : 59443.48601823416 True True
# 1 178 blue_0 Shoot at red_0 launch distance : 53215.599526830476 True True
# 3 287 blue_1 Splash :red_0
# 2 166 blue_1 Shoot at red_1 launch distance : 58097.66952296796 True True
# 3 298 blue_1 Splash :red_1
# 2 Same tgt shoot
# 2 178 blue_1 Shoot at red_0 launch distance : 55300.32157230191 True True
# 1 209 red_1 Shoot at blue_0
# 2 Same tgt shoot
# 2 191 blue_0 Shoot at red_1 launch distance : 58446.01397871372 True True
# 1 220 red_1 Shoot at blue_0
# 2 Same tgt shoot
# 2 205 blue_0 Shoot at red_1 launch distance : 54326.44410413772 True True
# 1 231 blue_1 Shoot at red_0 launch distance : 58904.32653888847 True True
# 1 250 blue_1 Shoot at red_0 launch distance : 59623.14421430658 True True
# 1 273 blue_0: Destroyed
# 1 280 blue_0 Splash :red_0
# 2 268 blue_1 Splash :red_1
# 3 WIN
# 3 blue_0 False True 400 12.90153257 103.03623780333339
# 3 blue_1 False True 400 13.00153597 156.76023684981283
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 281 blue_1 Splash :red_0
# 0 171 blue_0 Shoot at red_0 launch distance : 59256.17875799957 True True
# 0 Same tgt shoot
# 0 186 blue_0 Shoot at red_1 launch distance : 59730.43921653347 True True
# 2 WIN
# 2 blue_0 False True 405 12.964471126296296 87.93335636629644
# 2 blue_1 False True 405 12.964474526296295 154.54665194713118
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 280 blue_0 Splash :red_0
# 0 298 blue_0 Splash :red_1
# 0 WIN
# 0 blue_0 False True 298 32.58207508608501 166.0846651441802
# 0 blue_1 False True 298 14.028384010917227 10.669589764250562
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 189 blue_0 Shoot at red_1 launch distance : 52453.85584492335 True True
# 3 193 blue_1 Shoot at red_1 launch distance : 59745.39040796369 True True
# 3 200 blue_0 Shoot at red_1 launch distance : 46245.44757054471 True True
# 3 205 blue_1 Shoot at red_1 launch distance : 53771.70014979999 True True
# 3 212 red_1 Shoot at blue_0
# 2 93 blue_0 DOWN
# 3 234 red_0 Shoot at blue_0
# 3 245 red_0 Shoot at blue_0
# 0 84 blue_1 DOWN
# 0 98 blue_0 DOWN
# 0 TIME LIMIT LOSE
# 0 blue_0 False False 98 -1.1011565533333334 -1.4157966400000002
# 0 blue_1 False False 98 -0.10116782 -1.4129947233333333
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 272 blue_0 Splash :red_1
# 3 285 blue_0: Destroyed
# 0 216 blue_1 Shoot at red_0 launch distance : 58818.71356974751 True True
# 0 Same tgt shoot
# 0 229 blue_1 Shoot at red_1 launch distance : 52509.16105785732 True True
# 0 Same tgt shoot
# 0 248 blue_0 Shoot at red_0 launch distance : 57084.787237932316 True True
# 0 255 red_1 Shoot at blue_1
# 0 326 blue_1 Splash :red_1
# 0 327 blue_1 Splash :red_0
# 0 WIN
# 0 blue_0 False True 455 12.638878914029304 62.78381184069608
# 0 blue_1 False True 455 12.538878914029304 143.34508437216417
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 753 blue_1 DOWN
# 3 TIME LIMIT LOSE
# 3 blue_0 False False 753 0.9003420666666666 102.39106137176469
# 3 blue_1 False False 753 -0.1056579333333334 66.55582276666675
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 66 blue_0 DOWN
# 3 43 blue_1 DOWN
# 2 718 red_0 Shoot at blue_1
# 2 724 red_1 Shoot at blue_1
# 2 729 red_0 Shoot at blue_1
# 2 735 red_1 Shoot at blue_1
# 0 173 blue_1 Shoot at red_0 launch distance : 59781.135661678425 True True
# 0 186 blue_1 Shoot at red_0 launch distance : 53987.854791610305 True True
# 1 TIME LIMIT LOSE
# 1 blue_0 False False 1200 0.9005336833333333 115.87691013809523
# 1 blue_1 False False 1200 0.9005336833333333 9.3284056900001
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 786 blue_1: Destroyed
# 2 TIME LIMIT LOSE
# 2 blue_0 False False 786 -0.102215 -1.4118110733333333
# 2 blue_1 False False 786 -0.13805566666666666 -25.190278270000004
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 232 red_1 Shoot at blue_1
# 0 243 red_1 Shoot at blue_1
# 0 288 blue_1 Splash :red_0
# 0 305 blue_1: Destroyed
# 0 TIME LIMIT LOSE
# 0 blue_0 False False 305 0.9000555533333333 -0.4058336166666666
# 0 blue_1 False False 305 0.8599805533333333 127.72899972000002
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 273 blue_0 Shoot at red_1 launch distance : 59530.232294188136 True True
# 3 Same tgt shoot
# 3 285 blue_0 Shoot at red_0 launch distance : 54359.98191684762 True True
# 1 179 blue_0 Shoot at red_0 launch distance : 59425.95098944568 True True
# 2 170 blue_1 Shoot at red_1 launch distance : 59077.415904895504 True True
# 1 190 blue_0 Shoot at red_0 launch distance : 53815.33900292741 True True
# 1 195 blue_1 Shoot at red_0 launch distance : 59260.56904046737 True True
# 2 184 blue_1 Shoot at red_1 launch distance : 52282.89496575338 True True
# 2 Same tgt shoot
# 2 Same tgt shoot
# 2 190 blue_0 Shoot at red_0 launch distance : 59776.2322750439 True True
# 1 207 blue_1 Shoot at red_0 launch distance : 53912.58930899164 True True
# 2 Same tgt shoot
# 2 Same tgt shoot
# 2 202 blue_0 Shoot at red_0 launch distance : 54715.3478011426 True True
# 1 232 red_1 Shoot at blue_0
# 2 224 red_0 Shoot at blue_1
# 3 390 blue_0 Splash :red_1
# 3 393 blue_0 Splash :red_0
# 3 WIN
# 3 blue_0 False True 393 29.66184228684478 158.84837588402422
# 3 blue_1 False True 393 12.95497205783715 11.44654925783715
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 243 red_1 Shoot at blue_0
# 1 293 blue_0 Splash :red_0
# 2 279 blue_1 Splash :red_1
# 2 287 blue_1: Destroyed
# 1 304 blue_0: Destroyed
# 2 305 blue_0 Splash :red_0
# 2 WIN
# 2 blue_0 False True 305 31.804807421857927 149.4908376185246
# 2 blue_1 False True 305 14.335946829508197 123.80684651714262
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 266 blue_0 Shoot at red_1 launch distance : 57471.87065861002 True True
# 3 143 blue_1 Shoot at red_0 launch distance : 59865.98102428457 True True
# 0 Same tgt shoot
# 0 278 blue_0 Shoot at red_0 launch distance : 54668.73612038237 True True
# 3 155 blue_0 Shoot at red_0 launch distance : 59704.20470117662 True True
# 3 158 blue_1 Shoot at red_0 launch distance : 52234.24935806008 True True
# 3 Same tgt shoot
# 3 Same tgt shoot
# 3 Same tgt shoot
# 3 166 blue_0 Shoot at red_1 launch distance : 59913.65881833624 True True
# 3 196 red_1 Shoot at blue_1
# 3 249 blue_1 Splash :red_0
# 0 378 blue_0 Splash :red_1
# 0 381 blue_0 Splash :red_0
# 0 WIN
# 0 blue_0 False True 381 29.850330384304463 142.3941557768442
# 0 blue_1 False True 381 13.151116219212598 7.491293329212597
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 183 blue_0 Shoot at red_0 launch distance : 57631.70447765709 True True
# 3 272 blue_0 Splash :red_1
# 2 195 blue_0 Shoot at red_0 launch distance : 51625.23643529393 True True
# 2 236 red_1 Shoot at blue_0
# 2 247 red_1 Shoot at blue_0
# 2 294 blue_0 Splash :red_0
# 2 308 blue_0: Destroyed
# 3 WIN
# 3 blue_0 False True 396 13.031835386969698 132.16007556540154
# 3 blue_1 False True 396 13.031835386969698 144.3731943038381
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 176 blue_0 Shoot at red_1 launch distance : 58256.04701659734 True True
# 0 Same tgt shoot
# 0 187 blue_0 Shoot at red_0 launch distance : 57198.42194501523 True True
# 0 286 blue_0 Splash :red_1
# 0 295 blue_0 Splash :red_0
# 0 WIN
# 0 blue_0 False True 295 32.60492595384181 157.88717102545027
# 0 blue_1 False True 295 13.969333466836158 13.536177646836158
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 192 blue_1 DOWN
# 3 275 blue_0 Shoot at red_0 launch distance : 59553.086544695565 True True
# 3 Same tgt shoot
# 3 310 blue_0 Shoot at red_1 launch distance : 56741.532214066974 True True
# 0 215 blue_0 Shoot at red_0 launch distance : 59657.33018665854 True True
# 0 230 blue_0 Shoot at red_0 launch distance : 53691.98612456053 True True
# 3 399 blue_0 Splash :red_0
# 3 423 blue_0 Splash :red_1
# 3 WIN
# 3 blue_0 False True 423 28.912184057872345 163.93334087185735
# 3 blue_1 False True 423 12.738425192624113 6.623200419290779
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 270 blue_0 DOWN
# 0 336 blue_0 Splash :red_0
# 1 TIME LIMIT LOSE
# 1 blue_0 False False 1200 0.90052968 127.36684346986351
# 1 blue_1 False False 1200 0.89452968 68.12259976333408
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 169 blue_1 Shoot at red_0 launch distance : 59298.02521163753 True True
# 3 Same tgt shoot
# 3 181 blue_1 Shoot at red_1 launch distance : 57786.43326941022 True True
# 3 Same tgt shoot
# 3 190 blue_0 Shoot at red_0 launch distance : 59927.155814371836 True True
# 3 Same tgt shoot
# 3 Same tgt shoot
# 3 201 blue_0 Shoot at red_1 launch distance : 58844.42809646467 True True
# 3 283 blue_1 Splash :red_0
# 3 293 blue_1 Splash :red_1
# 1 252 red_1 Shoot at blue_1
# 3 WIN
# 3 blue_0 False True 401 12.894066126575229 107.9888348999085
# 3 blue_1 False True 401 12.894066126575229 157.4554406507973
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 263 red_1 Shoot at blue_1
# 1 270 red_0 Shoot at blue_1
# 1 281 red_0 Shoot at blue_1
# 2 Same tgt shoot
# 2 Same tgt shoot
# 2 1189 blue_1 Shoot at red_1 launch distance : 85.63293758829018 True True
# 2 TIME LIMIT LOSE
# 2 blue_0 False False 1200 1.3998808166666667 107.2825430661224
# 2 blue_1 False False 1200 1.39987445 -6.443854066666683
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 342 blue_1: Destroyed
# 3 163 blue_0 Shoot at red_1 launch distance : 57426.75074388242 True True
# 3 Same tgt shoot
# 3 174 blue_0 Shoot at red_0 launch distance : 58972.034414627415 True True
# 2 162 blue_0 Shoot at red_1 launch distance : 57554.01207561468 True True
# 2 Same tgt shoot
# 2 182 blue_0 Shoot at red_0 launch distance : 54919.61170656617 True True
# 3 279 blue_0 Splash :red_1
# 2 Same tgt shoot
# 2 227 blue_1 Shoot at red_0 launch distance : 40259.53345482285 True True
# 2 228 red_0 Shoot at blue_0
# 3 292 blue_0 Splash :red_0
# 3 WIN
# 3 blue_0 False True 292 32.730284119954334 136.99236998425536
# 3 blue_1 False True 292 14.111097404429223 11.730138164429224
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2 239 red_0 Shoot at blue_0
# 2 Same tgt shoot
# 2 241 blue_1 Shoot at red_0 launch distance : 34550.08500713131 True True
# 2 271 blue_0 Splash :red_1
# 2 290 blue_0: Destroyed
# 3 59 blue_0 DOWN
# 2 300 blue_1 Splash :red_0
# 3 161 blue_1 Shoot at red_0 launch distance : 59245.714461047726 True True
# 3 174 blue_1 Shoot at red_0 launch distance : 53990.81312593838 True True
# 2 WIN
# 2 blue_0 False True 441 12.622601768707483 104.59764362292646
# 2 blue_1 False True 441 12.622601768707483 100.20793908870775
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 1171 red_1 Shoot at blue_1
# 3 217 red_1 Shoot at blue_1
# 0 1182 red_1 Shoot at blue_1
# 3 228 red_1 Shoot at blue_1
# 0 TIME LIMIT LOSE
# 0 blue_0 False False 1200 0.8995770166666667 54.446883612857164
# 0 blue_1 False False 1200 0.89358465 -74.62858587333339
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 3 275 blue_1: Destroyed
# 3 TIME LIMIT LOSE
# 3 blue_0 False False 275 -0.10131618333333334 -1.6099335133333332
# 3 blue_1 False False 275 0.35895198333333334 80.18401294000002
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 48 blue_0 DOWN
# 2 128 blue_1 DOWN
# 2 209 blue_0 Shoot at red_1 launch distance : 58979.908867342274 True True
# 2 Same tgt shoot
# 2 221 blue_0 Shoot at red_0 launch distance : 55585.06479262213 True True
# 3 155 blue_1 Shoot at red_1 launch distance : 59675.92085590301 True True
# 3 163 blue_0 Shoot at red_1 launch distance : 59364.585385564686 True True
# 3 Same tgt shoot
# 3 Same tgt shoot
# 3 167 blue_1 Shoot at red_0 launch distance : 53895.469206604 True True
# 3 Same tgt shoot
# 3 Same tgt shoot
# 3 175 blue_0 Shoot at red_0 launch distance : 53527.566309332615 True True
# 3 196 red_0 Shoot at blue_1
# 0 274 red_1 Shoot at blue_1
# 2 316 blue_0 Splash :red_1
# 0 285 red_1 Shoot at blue_1
# 2 326 blue_0 Splash :red_0
# 2 WIN
# 2 blue_0 False True 326 31.544456298609408 150.5844975574702
# 2 blue_1 False True 326 13.582493108425357 12.267192898425357
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 0 296 red_0 Shoot at blue_1
# 3 264 blue_1 Splash :red_0
# 3 269 blue_1 Splash :red_1
# 0 307 red_0 Shoot at blue_1
# 2 33 blue_0 DOWN
# 0 360 blue_1: Destroyed
# 0 TIME LIMIT LOSE
# 0 blue_0 False False 360 -0.10150382333333334 -1.6104130300000001
# 0 blue_1 False False 360 -0.14107039 2.6084589366666657
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 1 TIME LIMIT LOSE
# 1 blue_0 False False 1200 -0.11426207 -90.71124565666668
# 1 blue_1 False False 1200 -0.10226970333333334 3.551986526666672
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2022-05-04 12:38:16,744	WARNING deprecation.py:46 -- DeprecationWarning: `clear_buffer` has been deprecated. Use `Filter.reset_buffer()` instead. This will raise an error in the future!
# agent_timesteps_total: 61064
# custom_metrics: {}
# date: 2022-05-04_12-38-16
# done: false
# episode_len_mean: 610.64
# episode_media: {}
# episode_reward_max: 276.8825757168569
# episode_reward_mean: 107.90554330643816
# episode_reward_min: -118.36618548666685
# episodes_this_iter: 50
# episodes_total: 50
# experiment_id: a3ba759500134ec3bf493321bd802397
# hostname: DESKTOP
# info:
#   learner:
#     blue_0:
#       learner_stats:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0002500000118743628
#         entropy: 5.7469282150268555
#         entropy_coeff: 0.0
#         kl: 0.15119312703609467
#         model: {}
#         policy_loss: -0.03685041144490242
#         total_loss: 937.9043579101562
#         vf_explained_var: -0.056172873824834824
#         vf_loss: 937.9109497070312
#       train: null
#     blue_1:
#       learner_stats:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0002500000118743628
#         entropy: 5.909292221069336
#         entropy_coeff: 0.0
#         kl: 0.12638401985168457
#         model: {}
#         policy_loss: -0.018881961703300476
#         total_loss: 594.8025512695312
#         vf_explained_var: -0.03018217720091343
#         vf_loss: 594.7962036132812
#       train: null
#   num_agent_steps_sampled: 61064
#   num_agent_steps_trained: 61064
#   num_steps_sampled: 30532
#   num_steps_trained: 30532
#   num_steps_trained_this_iter: 30532
# iterations_since_restore: 1
# node_ip: 127.0.0.1
# num_healthy_workers: 0
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 67.51370000000001
#   ram_util_percent: 43.40625
# pid: 10176
# policy_reward_max:
#   blue_0: 166.0846651441802
#   blue_1: 157.4554406507973
# policy_reward_mean:
#   blue_0: 62.34111184838666
#   blue_1: 45.56443145805154
# policy_reward_min:
#   blue_0: -100.28072598000001
#   blue_1: -85.05128421000013
# sampler_perf:
#   mean_action_processing_ms: 1.992132268664735
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 151.83786976302133
#   mean_inference_ms: 28.225946229934937
#   mean_raw_obs_processing_ms: 32.940729591121105
# time_since_restore: 2864.2238783836365
# time_this_iter_s: 2864.2238783836365
# time_total_s: 2864.2238783836365
# timers:
#   learn_throughput: 25.58
#   learn_time_ms: 1193587.596
#   load_throughput: 72032.477
#   load_time_ms: 423.864
#   sample_throughput: 18.189
#   sample_time_ms: 1678603.596
# timestamp: 1651635496
# timesteps_since_restore: 30532
# timesteps_this_iter: 30532
# timesteps_total: 30532
# training_iteration: 1
# trial_id: default
#
#
# -------------- Evaluation at steps:0 starting ! --------------
# 2022-05-04 12:38:17,099	WARNING ppo.py:231 -- `train_batch_size` (30000) cannot be achieved with your other settings (num_workers=0 num_envs_per_worker=4 rollout_fragment_length=200)! Auto-adjusting `rollout_fragment_length` to 7500.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2022-05-04 12:38:30,381	INFO trainable.py:130 -- Trainable.setup took 13.285 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-05-04 12:38:30,383	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10176/3356831010.py in <module>
#      34                              os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))
#      35             for j in range(eval_env.blue_num):
# ---> 36                 reload_weights(policy_id="blue_"+str(j),trainer=trainer,set_policy_id="blue_"+str(j))
#      37             eval_env.eval = True
#      38             obs = eval_env.reset()
#
# ~\ucav\0427 3vs3\utility\read_wright_weights.py in reload_weights(policy_id, trainer, set_policy_id)
#      21 def reload_weights(policy_id,trainer,set_policy_id):
#      22     weight = load_weights(set_policy_id)
# ---> 23     trainer.set_weights({policy_id:weight[set_policy_id]})
#      24
#
# ~\anaconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py in set_weights(self, weights)
#    1661             weights: Map of policy ids to weights to set.
#    1662         """
# -> 1663         self.workers.local_worker().set_weights(weights)
#    1664
#    1665     @PublicAPI
#
# ~\anaconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\rollout_worker.py in set_weights(self, weights, global_vars)
#    1406
#    1407         for pid, w in weights.items():
# -> 1408             self.policy_map[pid].set_weights(w)
#    1409         if global_vars:
#    1410             self.set_global_vars(global_vars)
#
# ~\anaconda3\envs\AI2\lib\site-packages\ray\rllib\policy\tf_policy.py in set_weights(self, weights)
#     451     @DeveloperAPI
#     452     def set_weights(self, weights) -> None:
# --> 453         return self._variables.set_weights(weights)
#     454
#     455     @override(Policy)
#
# ~\anaconda3\envs\AI2\lib\site-packages\ray\experimental\tf_utils.py in set_weights(self, new_weights)
#     181         else:
#     182             assign_list, feed_dict = self._assign_weights(new_weights)
# --> 183             self.sess.run(assign_list, feed_dict=feed_dict)
#     184
#     185     def _assign_weights(self, weights):
#
# ~\anaconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     966     try:
#     967       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 968                          run_metadata_ptr)
#     969       if run_metadata:
#     970         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\anaconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1163               not subfeed_t.get_shape().is_compatible_with(np_val.shape)):
#    1164             raise ValueError(
# -> 1165                 f'Cannot feed value of shape {str(np_val.shape)} for Tensor '
#    1166                 f'{subfeed_t.name}, which has shape '
#    1167                 f'{str(subfeed_t.get_shape())}')
#
# ValueError: Cannot feed value of shape (256, 256) for Tensor blue_0/Placeholder_blue_0/fc_value_1/kernel:0, which has shape (157, 256)
