# %%
# %matplotlib tk

import argparse
import gym
import datetime
import os
import random
import tempfile
import numpy as np
import pickle

import ray
from ray import tune
from ray.tune.logger import Logger, UnifiedLogger, pretty_print
from ray.rllib.env.multi_agent_env import make_multi_agent
from ray.rllib.examples.models.shared_weights_model import TF2SharedWeightsModel
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.framework import try_import_tf
from ray.rllib.utils.test_utils import check_learning_achieved
from ray.rllib.agents.ppo import ppo, PPOTrainer, PPOTFPolicy
from ray.rllib.agents.a3c.a3c_tf_policy import A3CTFPolicy
from ray.rllib.agents.a3c import a3c
from ray.rllib.models import ModelCatalog
from ray.rllib.policy.policy import PolicySpec
from environment_rllib_3d import MyEnv
#from test_env_for_lstm import MyEnv
from settings.initial_settings import *
from settings.reset_conditions import reset_conditions
#from modules.models import MyConv2DModel_v0B_Small_CBAM_1DConv_Share
#from modules.models import MyRNNUAVClass
#from modules.models import DenseNetModelLarge
from tensorflow.keras.utils import plot_model
from modules.savers import save_conditions
from utility.result_env import render_env
from utility.terminate_uavsimproc import teminate_proc
from utility.latest_learned_file_path import latest_learned_file_path
from utility.save_logs import save_logs

import matplotlib.pyplot as plt
import matplotlib
#import tensorflow as tf
import tensorflow.compat.v1 as tf
import cv2
import ctypes
import warnings

#UCAV.exeが起動している場合、プロセスキルする。
teminate_proc.UAVsimprockill(proc_name="UCAV.exe")

warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
warnings.filterwarnings('ignore', category=matplotlib.MatplotlibDeprecationWarning)
np.set_printoptions(precision=3, suppress=True)
PROJECT = "UCAV"
TRIAL_ID = 2
TRIAL = 'test_' + str(TRIAL_ID)
EVAL_FREQ = 1
CONTINUAL = True
NUM_EVAL = 1
def custom_log_creator(custom_path, custom_str):
    timestr = datetime.datetime.today().strftime("%Y-%m-%d_%H-%M-%S")
    logdir_prefix = "{}_{}".format(custom_str, timestr)

    def logger_creator(config):
        if not os.path.exists(custom_path):
            os.makedirs(custom_path)
        logdir = tempfile.mkdtemp(prefix=logdir_prefix, dir=custom_path)
        return UnifiedLogger(config, logdir, loggers=None)

    return logger_creator

ray.shutdown()
ray.init(ignore_reinit_error=True, log_to_driver=False)

#ModelCatalog.register_custom_model('my_model', MyRNNUAVClass)

# config = {"env": MyEnv,
#           "num_workers": NUM_WORKERS,
#           "num_gpus": NUM_GPUS,
#           "num_cpus_per_worker": NUM_CPUS_PER_WORKER,
#           "num_sgd_iter": NUM_SGD_ITER,
#           "lr": LEARNING_RATE,
#           "gamma": GAMMA,  # default=0.99
#           "model": {"custom_model": "my_model"}
#           # "framework": framework
#           }  # use tensorflow 2
eval_env = MyEnv(2)
policies = {
    #"blue_1": PolicySpec(config={"gamma": 0.99}),
    #"blue_2": PolicySpec(config={"gamma": 0.95}),
    "blue_0": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space, {"model":{"vf_share_layers": True,"use_lstm": True,"max_seq_len": 100},}),
    "blue_1": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space, {"model":{"vf_share_layers": True,"use_lstm": True,"max_seq_len": 100},}),
    #"blue_0": (A3CTFPolicy, eval_env.observation_space, eval_env.action_space, {}),
    #"blue_1": (A3CTFPolicy, eval_env.observation_space, eval_env.action_space, {}),
}
policy_ids = list(policies.keys())

def policy_mapping_fn(agent_id, episode, **kwargs):
    #print(agent_id,episode)
    #pol_id = policy_ids[agent_id]

    pol_id = agent_id
    return pol_id

# Instanciate the evaluation env
config = ppo.DEFAULT_CONFIG.copy()
config = {"env": MyEnv,"num_gpus": 0,"num_workers": 0, "num_cpus_per_worker": 0,"num_gpus_per_worker": 0,
          "train_batch_size": 300,
          "batch_mode": "complete_episodes",
          "gamma":0.995, "lr": 2.5e-4,"shuffle_sequences": True,
          #"clip_actions":True,"normalize_actions":True,
          "observation_space":eval_env.observation_space,"action_space":eval_env.action_space,
          "explore":True,
          "sgd_minibatch_size": 300, "num_sgd_iter":20,
          "exploration_config": {"type": "StochasticSampling","random_timesteps":600}, #PPO デフォルト "random_timesteps":0
          #"model":{"fcnet_activation": "relu","fcnet_hiddens": [256, 256, 256],"post_fcnet_activation": "linear",
          #         "vf_share_layers": True,},#"linear","relu","tanh" "use_lstm":True,"lstm_cell_size":256,"max_seq_len":128
          
          #"model": {"custom_model": "my_model"},
          "multiagent": {"policies": policies,  "policy_mapping_fn": policy_mapping_fn}
         }
#res_name = "sgd"+str(config["sgd_minibatch_size"])+"sgd_num"+str(config["num_sgd_iter"])+"lr"+str(config["lr"])+"gamma"+str(config["gamma"])
res_name = "test"
conditions_dir = os.path.join('./' + PROJECT + '/conditions/')

if not os.path.exists(conditions_dir):
    os.makedirs(conditions_dir)
save_conditions(conditions_dir)

# PPOTrainer()は、try_import_tfを使うと、なぜかTensorflowのeager modeのエラーになる。

trainer = ppo.PPOTrainer(config=config,
                         logger_creator=custom_log_creator(
                             os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))

if CONTINUAL:
    # Continual learning: Need to specify the checkpoint
    # model_path = PROJECT + '/checkpoints/' + TRIAL + '/checkpoint_000197/checkpoint-197'
    model_path = latest_learned_file_path('./UCAV/checkpoints/test_2/*')
    trainer.restore(checkpoint_path=model_path)

models_dir = os.path.join('./' + PROJECT + '/models/')
if not os.path.exists(models_dir):
    os.makedirs(models_dir)
for j in range(2):
    text_name = models_dir + TRIAL + "blue_"+str(j) +'.txt'
    with open(text_name, "w") as fp:
        trainer.get_policy("blue_"+str(j)).model.base_model.summary(print_fn=lambda x: fp.write(x + "\r\n"))
    png_name = models_dir + TRIAL + '.png'
    plot_model(trainer.get_policy("blue_"+str(j)).model.base_model, to_file=png_name, show_shapes=True)



# Define checkpoint dir
check_point_dir = os.path.join('./' + PROJECT + '/checkpoints/', TRIAL)
if not os.path.exists(check_point_dir):
    os.makedirs(check_point_dir)
# Out:
# C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ale_py\roms\utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\quaternion\numba_wrapper.py:23: UserWarning:
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Could not import from numba, which means that some
# parts of this code may run MUCH more slowly.  You
# may wish to install numba.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#   warnings.warn(warning_text)
# 2022-03-04 15:23:39,199	INFO services.py:1340 -- View the Ray dashboard at http://127.0.0.1:8265
# 2022-03-04 15:23:50,921	INFO trainer.py:723 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also want to then set `eager_tracing=True` in order to reach similar execution speed as with static-graph mode.
# 2022-03-04 15:23:50,922	WARNING ppo.py:151 -- `train_batch_size` (300) cannot be achieved with your other settings (num_workers=0 num_envs_per_worker=1 rollout_fragment_length=200)! Auto-adjusting `rollout_fragment_length` to 300.
# 2022-03-04 15:23:50,923	INFO ppo.py:167 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# 2022-03-04 15:23:50,924	INFO trainer.py:745 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2022-03-04 15:23:53,426	WARNING deprecation.py:46 -- DeprecationWarning: `SampleBatch['is_training']` has been deprecated. Use `SampleBatch.is_training` instead. This will raise an error in the future!
# 2022-03-04 15:24:02,696	INFO trainable.py:127 -- Trainable.setup took 11.781 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-03-04 15:24:02,702	WARNING util.py:57 -- Install gputil for GPU system monitoring.
# 2022-03-04 15:24:03,419	INFO trainable.py:468 -- Restored on 127.0.0.1 from checkpoint: ./UCAV/checkpoints/test_2\checkpoint_000001\checkpoint-1
# 2022-03-04 15:24:03,422	INFO trainable.py:475 -- Current state after restoring: {'_iteration': 1, '_timesteps_total': 0, '_time_total': 64.44099497795105, '_episodes_total': 1}
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
record_mode = 0
results_dir = os.path.join('./' + PROJECT + '/results/')

if not os.path.exists(results_dir):
    os.makedirs(results_dir)
results_file = results_dir + TRIAL + '.pkl'
for steps in range(10001):
    # Training
    print(f'\n----------------- Training at steps:{steps} start! -----------------')
    eval_env.eval = False
    #eval_env.reset()
    #results = trainer.train()
    #save_logs(res_name,results,steps,CONTINUAL)
    #print(pretty_print(results))
    #check_point = trainer.save(checkpoint_dir=check_point_dir)
    # Evaluation
    if steps % EVAL_FREQ == 0:
        print(f'\n-------------- Evaluation at steps:{steps} starting ! --------------')
        #print(pretty_print(results))
        #check_point = trainer.save(checkpoint_dir=check_point_dir)
        for i in range(NUM_EVAL):
            # print(f'\nEvaluation {i}:')
            model_path = latest_learned_file_path('./UCAV/checkpoints/test_2/*')
            trainer.restore(checkpoint_path=model_path)
            eval_env.eval = True
            #obs = eval_env.reset()
            obs = {'blue_0': eval_env.observation_space.sample(), 'blue_1': eval_env.observation_space.sample()}
            done = False
            
            step_num = 0
            fig = plt.figure(1,figsize=(8.0, 6.0))
            ESC = 0x1B          # ESCキーの仮想キーコード
            trajectory_length = 100
            env_blue_pos = [0]
            env_red_pos = [0]
            env_mrm_pos = [0]
            cell_size = 256
            state=[np.zeros(cell_size, np.float32),
            np.zeros(cell_size, np.float32)]
            if record_mode == 0:
                file_name = "test_num" + str(steps) +str(i)
                video = cv2.VideoWriter(file_name+'.mp4',0x00000020,20.0,(800,600))

            while True:
                action_dict = {}
                #for j in range(eval_env.blue_num):
                    #if not eval_env.blue[j].hitpoint == 0:
                    #action_dict['blue_' + str(j)] = trainer.compute_action(obs['blue_' + str(j)])
                    #action_dict['blue_' + str(j)] = trainer.compute_single_action(obs['blue_' + str(j)],policy_id='blue_' + str(j),
                    #                                                   clip_actions=True,explore=False)
                    #action_dict['blue_' + str(j)] = trainer.compute_single_action(obs['blue_' + str(j)],policy_id='blue_' + str(j))
                action_dict0 = trainer.compute_single_action(obs['blue_0'],state=None,prev_action=None,prev_reward=None,policy_id='blue_0',explore=False)
                action_dict1 = trainer.compute_single_action(obs['blue_1'],state=None,prev_action=None,prev_reward=None,policy_id='blue_1',explore=False)
                #action_dict0 = trainer.compute_single_action(obs['blue_0'],policy_id='blue_0')
                #action_dict1 = trainer.compute_single_action(obs['blue_1'],policy_id='blue_1')
                obs, rewards, dones, infos = eval_env.step({'blue_0': action_dict0, 'blue_1': action_dict1})
                env_blue_pos_temp, env_red_pos_temp, env_mrm_pos_temp= render_env.copy_from_env(eval_env)
                env_blue_pos.append(env_blue_pos_temp)
                env_red_pos.append(env_red_pos_temp)
                env_mrm_pos.append(env_mrm_pos_temp)
                if step_num == 0:
                    del env_blue_pos[0]
                    del env_red_pos[0]
                    del env_mrm_pos[0]

                hist_blue_pos = np.vstack(env_blue_pos)
                hist_red_pos = np.vstack(env_red_pos)
                hist_mrm_pos = np.vstack(env_mrm_pos)
                plt.clf()
                render_env.rend_3d(eval_env,hist_blue_pos,"b",1)
                render_env.rend_3d(eval_env,hist_red_pos,"r",1)
                render_env.rend_3d(eval_env,hist_mrm_pos,"k",1)
                plt.subplots_adjust(left=-0.1,right=1.1,bottom=-0.1,top=1.1)
                fig.canvas.draw()
                plt.pause(.01)
                if record_mode == 0:
                    img = np.array(fig.canvas.renderer.buffer_rgba())
                    img = cv2.cvtColor(img, cv2.COLOR_RGBA2BGR)
                    video.write(img.astype('uint8'))

                
                step_num = step_num + 1
                
                done = dones["__all__"]
                #print(f'rewards:{rewards}')
                #if record_mode == 0:
                #    img = eval_env.render_movie(file_name,step_num)
                #    video.write(img.astype('unit8'))
                #elif record_mode == 1:
                #    eval_env.render()
                #elif record_mode == 2:
                #    eval_env.render()
                    
                #env_blue_pos_temp, env_red_pos_temp, env_mrm_pos_temp = render_env.copy_from_env(eval_env)
                
                #env_blue_pos.append(env_blue_pos_temp)
                #env_red_pos.append(env_red_pos_temp)
                #env_mrm_pos.append(env_mrm_pos_temp)
                #step_num = step_num + 1
                # エピソードの終了処理
                if dones['__all__']:
                    # print(f'all done at {env.steps}')
                    break
                
            #del env_blue_pos[0]
            #del env_red_pos[0]
            #del env_mrm_pos[0]
            
            #hist_blue_pos = np.vstack(env_blue_pos)
            #hist_red_pos = np.vstack(env_red_pos)
            #hist_mrm_pos = np.vstack(env_mrm_pos)
            
            #f = open(results_file,'wb')
            #pickle.dump(emv_blue_pos,f)
            #pickle.dump(emv_red_pos,f)
            #pickle.dump(emv_mrm_pos,f)
            #f.close()
            
            if record_mode == 0:
                video.release()

ray.shutdown()
# Out:
# ----------------- Training at steps:0 start! -----------------
#
# -------------- Evaluation at steps:0 starting ! --------------
# 2022-03-04 15:24:03,764	INFO trainable.py:468 -- Restored on 127.0.0.1 from checkpoint: ./UCAV/checkpoints/test_2\checkpoint_000001\checkpoint-1
# 2022-03-04 15:24:03,767	INFO trainable.py:475 -- Current state after restoring: {'_iteration': 1, '_timesteps_total': 0, '_time_total': 64.44099497795105, '_episodes_total': 1}
# 2022-03-04 15:24:07,805	ERROR tf_run_builder.py:47 -- Error fetching: [{'vector_psi_x': <tf.Tensor 'blue_0/cond_1/Merge:0' shape=(?,) dtype=int64>}, <tf.Tensor 'blue_0/model_1/lstm/while/Exit_3:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'blue_0/model_1/lstm/while/Exit_4:0' shape=(?, 256) dtype=float32>, {'action_prob': <tf.Tensor 'blue_0/Exp:0' shape=(?,) dtype=float32>, 'action_logp': <tf.Tensor 'blue_0/cond_2/Merge:0' shape=(?,) dtype=float32>, 'action_dist_inputs': <tf.Tensor 'blue_0/Reshape_37:0' shape=(?, 5) dtype=float32>, 'vf_preds': <tf.Tensor 'blue_0/Reshape_38:0' shape=(?,) dtype=float32>}], feed_dict={<tf.Tensor 'blue_0/obs:0' shape=(?, 34) dtype=float32>: array([[ 0.  ,  1.  ,  1.  ,  0.  ,  0.39,  0.25, -0.28, -0.98,  0.01,
#          0.08,  0.34,  0.  ,  1.  ,  0.  ,  1.  ,  0.5 ,  0.15, -0.19,
#          0.75, -0.63,  0.65, -0.52, -0.48, -0.38,  0.16,  0.25, -0.55,
#          0.74, -0.25,  0.39, -0.12,  0.31,  0.12,  0.19]], dtype=float32), <tf.Tensor 'blue_0/is_training:0' shape=() dtype=bool>: False, <tf.Tensor 'blue_0/is_exploring:0' shape=() dtype=bool>: False, <tf.Tensor 'blue_0/timestep:0' shape=() dtype=int64>: 335}
# Traceback (most recent call last):
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py", line 1380, in _do_call
#     return fn(*args)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py", line 1364, in _run_fn
#     target_list, run_metadata)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py", line 1458, in _call_tf_sessionrun
#     run_metadata)
# tensorflow.python.framework.errors_impl.InvalidArgumentError: You must feed a value for placeholder tensor 'blue_0/seq_lens' with dtype int32 and shape [?]
# 	 [[{{node blue_0/seq_lens}}]]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\utils\tf_run_builder.py", line 44, in get
#     self.feed_dict, os.environ.get("TF_TIMELINE_DIR"))
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\utils\tf_run_builder.py", line 92, in run_timeline
#     fetches = sess.run(ops, feed_dict=feed_dict)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py", line 971, in run
#     run_metadata_ptr)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py", line 1194, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py", line 1374, in _do_run
#     run_metadata)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py", line 1399, in _do_call
#     raise type(e)(node_def, op, message)  # pylint: disable=no-value-for-parameter
# tensorflow.python.framework.errors_impl.InvalidArgumentError: You must feed a value for placeholder tensor 'blue_0/seq_lens' with dtype int32 and shape [?]
# 	 [[node blue_0/seq_lens
#  (defined at C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\dynamic_tf_policy.py:214)
# ]]
#
# Errors may have originated from an input operation.
#
# Operation defined at: (most recent call last)
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\runpy.py", line 193, in _run_module_as_main
# >>>     "__main__", mod_spec)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\runpy.py", line 85, in _run_code
# >>>     exec(code, run_globals)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
# >>>     app.launch_new_instance()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
# >>>     app.start()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
# >>>     self.io_loop.start()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
# >>>     self.asyncio_loop.run_forever()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\base_events.py", line 539, in run_forever
# >>>     self._run_once()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\base_events.py", line 1775, in _run_once
# >>>     handle._run()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\events.py", line 88, in _run
# >>>     self._context.run(self._callback, *self._args)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 457, in dispatch_queue
# >>>     await self.process_one()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 446, in process_one
# >>>     await dispatch(*args)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 353, in dispatch_shell
# >>>     await result
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 648, in execute_request
# >>>     reply_content = await reply_content
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\ipkernel.py", line 353, in do_execute
# >>>     res = shell.run_cell(code, store_history=store_history, silent=silent)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
# >>>     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 2902, in run_cell
# >>>     raw_cell, store_history, silent, shell_futures)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 2947, in _run_cell
# >>>     return runner(coro)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
# >>>     coro.send(None)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3173, in run_cell_async
# >>>     interactivity=interactivity, compiler=compiler, result=result)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
# >>>     if (await self.run_code(code, result,  async_=asy)):
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
# >>>     exec(code_obj, self.user_global_ns, self.user_ns)
# >>>
# >>>   File "C:\Users\ookit1\AppData\Local\Temp/ipykernel_17832/952322642.py", line 133, in <module>
# >>>     os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 103, in __init__
# >>>     remote_checkpoint_dir, sync_function_tpl)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 662, in __init__
# >>>     sync_function_tpl)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\tune\trainable.py", line 121, in __init__
# >>>     self.setup(copy.deepcopy(self.config))
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 113, in setup
# >>>     super().setup(config)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 764, in setup
# >>>     self._init(self.config, self.env_creator)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 141, in _init
# >>>     num_workers=self.config["num_workers"])
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 1733, in _make_workers
# >>>     logdir=self.logdir)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\worker_set.py", line 118, in __init__
# >>>     spaces=spaces,
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\worker_set.py", line 489, in _make_worker
# >>>     spaces=spaces,
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 591, in __init__
# >>>     seed=seed)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 1552, in _build_policy_map
# >>>     conf, merged_conf)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\policy_map.py", line 134, in create_policy
# >>>     observation_space, action_space, merged_config)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\tf_policy_template.py", line 252, in __init__
# >>>     get_batch_divisibility_req=get_batch_divisibility_req,
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\dynamic_tf_policy.py", line 214, in __init__
# >>>     dtype=tf.int32, shape=[None], name="seq_lens")
# >>>
#
# Original stack trace for 'blue_0/seq_lens':
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\base_events.py", line 539, in run_forever
#     self._run_once()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\base_events.py", line 1775, in _run_once
#     handle._run()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 457, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 446, in process_one
#     await dispatch(*args)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 353, in dispatch_shell
#     await result
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 648, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\ipkernel.py", line 353, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 2902, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3173, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ookit1\AppData\Local\Temp/ipykernel_17832/952322642.py", line 133, in <module>
#     os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 103, in __init__
#     remote_checkpoint_dir, sync_function_tpl)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 662, in __init__
#     sync_function_tpl)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\tune\trainable.py", line 121, in __init__
#     self.setup(copy.deepcopy(self.config))
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 113, in setup
#     super().setup(config)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 764, in setup
#     self._init(self.config, self.env_creator)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 141, in _init
#     num_workers=self.config["num_workers"])
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 1733, in _make_workers
#     logdir=self.logdir)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\worker_set.py", line 118, in __init__
#     spaces=spaces,
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\worker_set.py", line 489, in _make_worker
#     spaces=spaces,
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 591, in __init__
#     seed=seed)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 1552, in _build_policy_map
#     conf, merged_conf)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\policy_map.py", line 134, in create_policy
#     observation_space, action_space, merged_config)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\tf_policy_template.py", line 252, in __init__
#     get_batch_divisibility_req=get_batch_divisibility_req,
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\dynamic_tf_policy.py", line 214, in __init__
#     dtype=tf.int32, shape=[None], name="seq_lens")
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\ops\array_ops.py", line 3289, in placeholder
#     return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\ops\gen_array_ops.py", line 6893, in placeholder
#     "Placeholder", dtype=dtype, shape=shape, name=name)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 746, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\framework\ops.py", line 3705, in _create_op_internal
#     op_def=op_def)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\framework\ops.py", line 2101, in __init__
#     self._traceback = tf_stack.extract_stack_for_node(self._c_op)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1379     try:
# -> 1380       return fn(*args)
#    1381     except errors.OpError as e:
#
# ~\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1363       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1364                                       target_list, run_metadata)
#    1365
#
# ~\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1457                                             fetch_list, target_list,
# -> 1458                                             run_metadata)
#    1459
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'blue_0/seq_lens' with dtype int32 and shape [?]
# 	 [[{{node blue_0/seq_lens}}]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17832/1611360752.py in <module>
#      47                     #                                                   clip_actions=True,explore=False)
#      48                     #action_dict['blue_' + str(j)] = trainer.compute_single_action(obs['blue_' + str(j)],policy_id='blue_' + str(j))
# ---> 49                 action_dict0 = trainer.compute_single_action(obs['blue_0'],policy_id='blue_0',explore=False)
#      50                 action_dict1 = trainer.compute_single_action(obs['blue_1'],policy_id='blue_1',explore=False)
#      51                 #action_dict0 = trainer.compute_single_action(obs['blue_0'],policy_id='blue_0')
#
# ~\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py in compute_single_action(self, observation, state, prev_action, prev_reward, info, input_dict, policy_id, full_fetch, explore, timestep, episode, unsquash_action, clip_action, unsquash_actions, clip_actions, **kwargs)
#    1255                 explore=explore,
#    1256                 timestep=timestep,
# -> 1257                 episode=episode,
#    1258             )
#    1259
#
# ~\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\policy.py in compute_single_action(self, obs, state, prev_action, prev_reward, info, input_dict, episode, explore, timestep, **kwargs)
#     217             episodes=episodes,
#     218             explore=explore,
# --> 219             timestep=timestep,
#     220         )
#     221
#
# ~\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\tf_policy.py in compute_actions_from_input_dict(self, input_dict, explore, timestep, episodes, **kwargs)
#     295
#     296         # Execute session run to get action (and other fetches).
# --> 297         fetched = builder.get(to_fetch)
#     298
#     299         # Update our global timestep by the batch size.
#
# ~\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\utils\tf_run_builder.py in get(self, to_fetch)
#      46                 logger.exception("Error fetching: {}, feed_dict={}".format(
#      47                     self.fetches, self.feed_dict))
# ---> 48                 raise e
#      49         if isinstance(to_fetch, int):
#      50             return self._executed[to_fetch]
#
# ~\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\utils\tf_run_builder.py in get(self, to_fetch)
#      42                 self._executed = run_timeline(
#      43                     self.session, self.fetches, self.debug_name,
# ---> 44                     self.feed_dict, os.environ.get("TF_TIMELINE_DIR"))
#      45             except Exception as e:
#      46                 logger.exception("Error fetching: {}, feed_dict={}".format(
#
# ~\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\utils\tf_run_builder.py in run_timeline(sess, ops, debug_name, feed_dict, timeline_dir)
#      90                 "Executing TF run without tracing. To dump TF timeline traces "
#      91                 "to disk, set the TF_TIMELINE_DIR environment variable.")
# ---> 92         fetches = sess.run(ops, feed_dict=feed_dict)
#      93     return fetches
#
# ~\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     969     try:
#     970       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 971                          run_metadata_ptr)
#     972       if run_metadata:
#     973         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1192     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1193       results = self._do_run(handle, final_targets, final_fetches,
# -> 1194                              feed_dict_tensor, options, run_metadata)
#    1195     else:
#    1196       results = []
#
# ~\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1372     if handle is None:
#    1373       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1374                            run_metadata)
#    1375     else:
#    1376       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1397                     '\nsession_config.graph_options.rewrite_options.'
#    1398                     'disable_meta_optimizer = True')
# -> 1399       raise type(e)(node_def, op, message)  # pylint: disable=no-value-for-parameter
#    1400
#    1401   def _extend_graph(self):
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'blue_0/seq_lens' with dtype int32 and shape [?]
# 	 [[node blue_0/seq_lens
#  (defined at C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\dynamic_tf_policy.py:214)
# ]]
#
# Errors may have originated from an input operation.
#
# Operation defined at: (most recent call last)
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\runpy.py", line 193, in _run_module_as_main
# >>>     "__main__", mod_spec)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\runpy.py", line 85, in _run_code
# >>>     exec(code, run_globals)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
# >>>     app.launch_new_instance()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
# >>>     app.start()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
# >>>     self.io_loop.start()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
# >>>     self.asyncio_loop.run_forever()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\base_events.py", line 539, in run_forever
# >>>     self._run_once()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\base_events.py", line 1775, in _run_once
# >>>     handle._run()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\events.py", line 88, in _run
# >>>     self._context.run(self._callback, *self._args)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 457, in dispatch_queue
# >>>     await self.process_one()
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 446, in process_one
# >>>     await dispatch(*args)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 353, in dispatch_shell
# >>>     await result
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 648, in execute_request
# >>>     reply_content = await reply_content
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\ipkernel.py", line 353, in do_execute
# >>>     res = shell.run_cell(code, store_history=store_history, silent=silent)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
# >>>     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 2902, in run_cell
# >>>     raw_cell, store_history, silent, shell_futures)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 2947, in _run_cell
# >>>     return runner(coro)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
# >>>     coro.send(None)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3173, in run_cell_async
# >>>     interactivity=interactivity, compiler=compiler, result=result)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
# >>>     if (await self.run_code(code, result,  async_=asy)):
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
# >>>     exec(code_obj, self.user_global_ns, self.user_ns)
# >>>
# >>>   File "C:\Users\ookit1\AppData\Local\Temp/ipykernel_17832/952322642.py", line 133, in <module>
# >>>     os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 103, in __init__
# >>>     remote_checkpoint_dir, sync_function_tpl)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 662, in __init__
# >>>     sync_function_tpl)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\tune\trainable.py", line 121, in __init__
# >>>     self.setup(copy.deepcopy(self.config))
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 113, in setup
# >>>     super().setup(config)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 764, in setup
# >>>     self._init(self.config, self.env_creator)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 141, in _init
# >>>     num_workers=self.config["num_workers"])
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 1733, in _make_workers
# >>>     logdir=self.logdir)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\worker_set.py", line 118, in __init__
# >>>     spaces=spaces,
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\worker_set.py", line 489, in _make_worker
# >>>     spaces=spaces,
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 591, in __init__
# >>>     seed=seed)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 1552, in _build_policy_map
# >>>     conf, merged_conf)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\policy_map.py", line 134, in create_policy
# >>>     observation_space, action_space, merged_config)
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\tf_policy_template.py", line 252, in __init__
# >>>     get_batch_divisibility_req=get_batch_divisibility_req,
# >>>
# >>>   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\dynamic_tf_policy.py", line 214, in __init__
# >>>     dtype=tf.int32, shape=[None], name="seq_lens")
# >>>
#
# Original stack trace for 'blue_0/seq_lens':
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\base_events.py", line 539, in run_forever
#     self._run_once()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\base_events.py", line 1775, in _run_once
#     handle._run()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 457, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 446, in process_one
#     await dispatch(*args)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 353, in dispatch_shell
#     await result
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\kernelbase.py", line 648, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\ipkernel.py", line 353, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 2902, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3173, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ookit1\AppData\Local\Temp/ipykernel_17832/952322642.py", line 133, in <module>
#     os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 103, in __init__
#     remote_checkpoint_dir, sync_function_tpl)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 662, in __init__
#     sync_function_tpl)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\tune\trainable.py", line 121, in __init__
#     self.setup(copy.deepcopy(self.config))
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 113, in setup
#     super().setup(config)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 764, in setup
#     self._init(self.config, self.env_creator)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer_template.py", line 141, in _init
#     num_workers=self.config["num_workers"])
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\agents\trainer.py", line 1733, in _make_workers
#     logdir=self.logdir)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\worker_set.py", line 118, in __init__
#     spaces=spaces,
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\worker_set.py", line 489, in _make_worker
#     spaces=spaces,
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 591, in __init__
#     seed=seed)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\evaluation\rollout_worker.py", line 1552, in _build_policy_map
#     conf, merged_conf)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\policy_map.py", line 134, in create_policy
#     observation_space, action_space, merged_config)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\tf_policy_template.py", line 252, in __init__
#     get_batch_divisibility_req=get_batch_divisibility_req,
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\ray\rllib\policy\dynamic_tf_policy.py", line 214, in __init__
#     dtype=tf.int32, shape=[None], name="seq_lens")
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\ops\array_ops.py", line 3289, in placeholder
#     return gen_array_ops.placeholder(dtype=dtype, shape=shape, name=name)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\ops\gen_array_ops.py", line 6893, in placeholder
#     "Placeholder", dtype=dtype, shape=shape, name=name)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 746, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\framework\ops.py", line 3705, in _create_op_internal
#     op_def=op_def)
#   File "C:\Users\ookit1\Miniconda3\envs\AI2\lib\site-packages\tensorflow\python\framework\ops.py", line 2101, in __init__
#     self._traceback = tf_stack.extract_stack_for_node(self._c_op)
