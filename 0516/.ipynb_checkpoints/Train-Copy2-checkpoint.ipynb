# %%
# %matplotlib tk

import argparse
import gym
import datetime
import os
import random
import tempfile
import numpy as np
import pickle

import ray
from ray import tune
from ray.tune.logger import Logger, UnifiedLogger, pretty_print
from ray.rllib.env.multi_agent_env import make_multi_agent
from ray.rllib.examples.models.shared_weights_model import TF2SharedWeightsModel
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.framework import try_import_tf
from ray.rllib.utils.test_utils import check_learning_achieved
from ray.rllib.agents.ppo import ppo, PPOTrainer, PPOTFPolicy
from ray.rllib.agents.a3c.a3c_tf_policy import A3CTFPolicy
from ray.rllib.agents.a3c import a3c
from ray.rllib.models import ModelCatalog
from ray.rllib.policy.policy import PolicySpec
from environment_rllib_3d1 import MyEnv
#from test_env_for_lstm import MyEnv
from settings.initial_settings import *
from settings.reset_conditions import reset_conditions

from tensorflow.keras.utils import plot_model
from modules.savers import save_conditions
from utility.result_env import render_env
from utility.terminate_uavsimproc import teminate_proc
from utility.latest_learned_file_path import latest_learned_file_path
from utility.read_wright_weights import save_weights
from utility.read_wright_weights import reload_weights
from utility.save_logs import save_logs
from utility.save_logs import save_hists
from utility.save_logs import save_env_info

import matplotlib.pyplot as plt
import matplotlib
import tensorflow as tf
import cv2
import ctypes
import warnings

#UCAV.exeが起動している場合、プロセスキルする。
teminate_proc.UAVsimprockill(proc_name="UCAV.exe")

warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
warnings.filterwarnings('ignore', category=matplotlib.MatplotlibDeprecationWarning)
np.set_printoptions(precision=3, suppress=True)
PROJECT = "UCAV"
TRIAL_ID = 2
TRIAL = 'test_' + str(TRIAL_ID)
EVAL_FREQ = 1
CONTINUAL = True
NUM_EVAL = 1
def custom_log_creator(custom_path, custom_str):
    timestr = datetime.datetime.today().strftime("%Y-%m-%d_%H-%M-%S")
    logdir_prefix = "{}_{}".format(custom_str, timestr)

    def logger_creator(config):
        if not os.path.exists(custom_path):
            os.makedirs(custom_path)
        logdir = tempfile.mkdtemp(prefix=logdir_prefix, dir=custom_path)
        return UnifiedLogger(config, logdir, loggers=None)

    return logger_creator

ray.shutdown()
ray.init(ignore_reinit_error=True, log_to_driver=False)

#ModelCatalog.register_custom_model('my_model', MyRNNUAVClass)

eval_env = MyEnv()
policies_own = {
    "blue_0": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
               {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},
               "exploration_config": {"type": "StochasticSampling","random_timesteps":0},"explore":True,}),
    "blue_1": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
               {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},
               "exploration_config": {"type": "StochasticSampling","random_timesteps":0},"explore":True,}),
    #"red_0": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
    #          {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},"explore":False,}),
    #"red_1": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
    #          {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},"explore":False,}),
}
policies_enem = {
    "red_0": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
              {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},"explore":False,}),
    "red_1": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
              {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},"explore":False,}),
}
# policy_ids = list(policies.keys())

def policy_mapping_fn(agent_id, episode, **kwargs):
    #print(agent_id,episode)
    #pol_id = policy_ids[agent_id]

    pol_id = agent_id
    return pol_id

# Instanciate the evaluation env
config_own = ppo.DEFAULT_CONFIG.copy()
config_own = {"env": MyEnv,"num_gpus": 1,"num_workers": 0, "num_cpus_per_worker": 0,"num_gpus_per_worker": 1,
          "train_batch_size": 1200*25,
          "batch_mode": "complete_episodes",
          "gamma":0.995, "lr": 2.5e-4,"shuffle_sequences": True,
          "observation_space":eval_env.observation_space,"action_space":eval_env.action_space,
          "sgd_minibatch_size": 600, "num_sgd_iter":20,
          "multiagent": {"policies": policies_own,  "policy_mapping_fn": policy_mapping_fn}
         }
config_enem = ppo.DEFAULT_CONFIG.copy()
config_enem = {"env": MyEnv,"num_gpus": 1,"num_workers": 0, "num_cpus_per_worker": 0,"num_gpus_per_worker": 1,
          "train_batch_size": 600*5*10,
          "batch_mode": "complete_episodes",
          "gamma":0.995, "lr": 2.5e-4,"shuffle_sequences": True,
          "observation_space":eval_env.observation_space,"action_space":eval_env.action_space,
          "sgd_minibatch_size": 600, "num_sgd_iter":20,
          "multiagent": {"policies": policies_enem,  "policy_mapping_fn": policy_mapping_fn}
         }

res_name = "test"
conditions_dir = os.path.join('./' + PROJECT + '/conditions/')

if not os.path.exists(conditions_dir):
    os.makedirs(conditions_dir)
save_conditions(conditions_dir)

# PPOTrainer()は、try_import_tfを使うと、なぜかTensorflowのeager modeのエラーになる。

trainer = ppo.PPOTrainer(config=config_own,
                         logger_creator=custom_log_creator(
                             os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))

adversary = ppo.PPOTrainer(config=config_enem,
                         logger_creator=custom_log_creator(
                             os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))

if CONTINUAL:
    # Continual learning: Need to specify the checkpoint
    # model_path = PROJECT + '/checkpoints/' + TRIAL + '/checkpoint_000197/checkpoint-197'
    model_path = latest_learned_file_path('./UCAV/checkpoints/test_2/*')
    
    #trainer.restore(checkpoint_path=model_path)
    #save_weights("blue_0",trainer)
    #save_weights("blue_1",trainer)

    #reload_weights(policy_id="red_0",trainer=trainer,set_policy_id="blue_0")
    #reload_weights(policy_id="red_1",trainer=trainer,set_policy_id="blue_1")
    reload_weights(policy_id="blue_0",trainer=trainer,set_policy_id="blue_0")
    reload_weights(policy_id="blue_1",trainer=trainer,set_policy_id="blue_1")
    #save_weights("red_0",trainer)
    #save_weights("red_1",trainer)


models_dir = os.path.join('./' + PROJECT + '/models/')
if not os.path.exists(models_dir):
    os.makedirs(models_dir)
hist_dir = os.path.join('./' + PROJECT + '/hist/')
if not os.path.exists(hist_dir):
    os.makedirs(hist_dir)

for j in range(2):
    text_name = models_dir + TRIAL + "blue_"+str(j) +'.txt'
    with open(text_name, "w") as fp:
        trainer.get_policy("blue_"+str(j)).model.base_model.summary(print_fn=lambda x: fp.write(x + "\r\n"))
    png_name = models_dir + TRIAL + '.png'
    plot_model(trainer.get_policy("blue_"+str(j)).model.base_model, to_file=png_name, show_shapes=True)



# Define checkpoint dir
check_point_dir = os.path.join('./' + PROJECT + '/checkpoints/', TRIAL)
if not os.path.exists(check_point_dir):
    os.makedirs(check_point_dir)
# Out:
# C:\Users\Takumi\anaconda3\envs\AI2\lib\site-packages\ale_py\roms\utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# C:\Users\Takumi\anaconda3\envs\AI2\lib\site-packages\quaternion\numba_wrapper.py:23: UserWarning:
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Could not import from numba, which means that some
# parts of this code may run MUCH more slowly.  You
# may wish to install numba.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#   warnings.warn(warning_text)
# 2022-04-05 00:07:36,456	INFO trainer.py:2141 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# 2022-04-05 00:07:36,458	INFO ppo.py:250 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# 2022-04-05 00:07:36,458	INFO trainer.py:781 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2022-04-05 00:07:50,665	INFO trainable.py:130 -- Trainable.setup took 14.212 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-04-05 00:07:50,666	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2022-04-05 00:08:03,989	INFO trainable.py:130 -- Trainable.setup took 13.279 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-04-05 00:08:03,991	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
eval_env.reset()
save_env_info(eval_env)
record_mode = 0
results_dir = os.path.join('./' + PROJECT + '/results/')

if not os.path.exists(results_dir):
    os.makedirs(results_dir)
results_file = results_dir + TRIAL + '.pkl'
for steps in range(10001):
    # Training
    print(f'\n----------------- Training at steps:{steps} start! -----------------')
    eval_env.eval = False
    eval_env.reset()
    results = trainer.train()
    save_logs(res_name,results,steps,CONTINUAL)
    print(pretty_print(results))
    #check_point = trainer.save(checkpoint_dir=check_point_dir)
    # Evaluation
    if steps % EVAL_FREQ == 0:
        print(f'\n-------------- Evaluation at steps:{steps} starting ! --------------')

        check_point = trainer.save(checkpoint_dir=check_point_dir)
        for i in range(NUM_EVAL):
            # print(f'\nEvaluation {i}:')
            model_path = latest_learned_file_path('./UCAV/checkpoints/test_2/*')
            trainer.restore(checkpoint_path=model_path)
            eval_env.eval = True
            obs = eval_env.reset()
            done = False
            
            step_num = 0
            #fig = plt.figure(1,figsize=(8.0, 6.0))
            ESC = 0x1B          # ESCキーの仮想キーコード
            trajectory_length = 100

            cell_size = 256
            state_0=[np.zeros(cell_size, np.float32),np.zeros(cell_size, np.float32)]
            state_1=[np.zeros(cell_size, np.float32),np.zeros(cell_size, np.float32)]
            action_dict0 = [0,0]
            action_dict1 = [0,0]
            rewards = {"blue_0":0,"blue_1":0}
            if record_mode == 0:
                file_name = "test_num" + str(steps) +str(i)
                #video = cv2.VideoWriter(file_name+'.mp4',0x00000020,20.0,(800,600))

            while True:
                action_dict = {}
                action_dict0 = trainer.compute_single_action(obs['blue_0'],
                                                             state=state_0,prev_action=None,prev_reward=None,
                                                             policy_id='blue_0',explore=False)
                action_dict1 = trainer.compute_single_action(obs['blue_1'],
                                                             state=state_1,prev_action=None,prev_reward=None,
                                                             policy_id='blue_1',explore=False)

                state_0 = action_dict0[1]
                state_1 = action_dict1[1]
                obs, rewards, dones, infos = eval_env.step({'blue_0': action_dict0[0], 'blue_1': action_dict1[0]})

                env_blue_pos_temp_mod, env_red_pos_temp_mod, env_mrm_pos_temp_mod = render_env.copy_from_env_mod(eval_env)
                if eval_env.timer == 1:
                    env_blue_pos_mod = env_blue_pos_temp_mod
                    env_red_pos_mod = env_red_pos_temp_mod
                    env_mrm_pos_mod = env_mrm_pos_temp_mod
                else:
                    env_blue_pos_mod = np.vstack([env_blue_pos_mod,env_blue_pos_temp_mod])
                    env_red_pos_mod = np.vstack([env_red_pos_mod,env_red_pos_temp_mod])
                    env_mrm_pos_mod = np.vstack([env_mrm_pos_mod,env_mrm_pos_temp_mod])


                #if record_mode == 0:
                    #img = np.array(fig.canvas.renderer.buffer_rgba())
                    #img = cv2.cvtColor(img, cv2.COLOR_RGBA2BGR)
                    #video.write(img.astype('uint8'))

                
                step_num = step_num + 1
                
                done = dones["__all__"]
                
                #print(f'rewards:{rewards}')
                #if record_mode == 0:
                #    img = eval_env.render_movie(file_name,step_num)
                #    video.write(img.astype('unit8'))
                #elif record_mode == 1:
                #    eval_env.render()
                #elif record_mode == 2:
                #    eval_env.render()

                # エピソードの終了処理
                if dones['__all__']:
                    save_hists("blue",steps,env_blue_pos_mod,hist_dir)
                    save_hists("red",steps,env_red_pos_mod,hist_dir)
                    save_hists("mrm",steps,env_mrm_pos_mod,hist_dir)
                    save_weights("blue_0",trainer)
                    save_weights("blue_1",trainer)
                    # print(f'all done at {env.steps}')
                    break
                

            
            #if record_mode == 0:
               # video.release()

ray.shutdown()
# Out:
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
#
# ----------------- Training at steps:0 start! -----------------
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 298 blue_0 Shoot at red_0 launch distance : 59323.498128835294 True True
# 311 blue_0 Shoot at red_0 launch distance : 52736.21868843753 True True
# 358 red_1 Shoot at blue_0
# 369 red_1 Shoot at blue_0
# 412 blue_0 Splash :red_0
# 423 blue_0: Destroyed
# 1125 blue_1 DOWN
# TIME LIMIT LOSE
# blue_0 False False 1125 0.898999897848691 123.20104297013226
# blue_1 False False 1125 -0.10700010215130895 12.156929864916068
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 880 red_0 Shoot at blue_0
# 891 red_0 Shoot at blue_0
# 926 red_1 Shoot at blue_0
# 937 red_1 Shoot at blue_0
# 957 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.10099846659283274 -21.301288776924427
# blue_1 False False 1200 -0.0009984665928327297 -47.17588964176178
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 169 blue_0 DOWN
# 295 blue_1 Shoot at red_1 launch distance : 59550.42133156825 True True
# Same tgt shoot
# 307 blue_1 Shoot at red_0 launch distance : 57568.109294169524 True True
# 410 blue_1 Splash :red_1
# 418 blue_1 Splash :red_0
# WIN
# blue_0 False True 418 12.771162764807624 11.567203921779882
# blue_1 False True 418 29.112789559065998 116.75334862797293
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 370 blue_1 Shoot at red_0 launch distance : 59210.61292602566 True True
# 456 red_0 Shoot at blue_1
# 467 red_0 Shoot at blue_1
# 558 blue_1: Destroyed
# 699 red_1 Shoot at blue_0
# 710 red_1 Shoot at blue_0
# 792 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False True 792 -0.143324973148371 0.22917242552030287
# blue_1 False True 792 -0.10099847314837103 1.883943328118635
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 288 blue_1 Shoot at red_1 launch distance : 59639.022164971386 True True
# Same tgt shoot
# 301 blue_1 Shoot at red_0 launch distance : 54315.27970017774 True True
# 322 blue_0 DOWN
# 407 blue_1 Splash :red_1
# 410 blue_1 Splash :red_0
# WIN
# blue_0 False True 410 12.827181285717671 10.590842563770487
# blue_1 False True 410 29.18083982230304 144.70254320168397
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 170 blue_1 DOWN
# 358 blue_0 Shoot at red_0 launch distance : 59658.489910130316 True True
# Same tgt shoot
# 369 blue_0 Shoot at red_1 launch distance : 55888.01530714774 True True
# 481 blue_0 Splash :red_0
# 494 blue_0 Splash :red_1
# WIN
# blue_0 False True 494 27.78786290486086 150.73529858231754
# blue_1 False True 494 12.329563309719155 10.9241987807921
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 283 blue_0 Shoot at red_0 launch distance : 59615.34672050505 True True
# 294 blue_0 Shoot at red_0 launch distance : 54329.003565662264 True True
# 294 blue_1 Shoot at red_0 launch distance : 59512.237071491305 True True
# 306 blue_1 Shoot at red_0 launch distance : 53549.04803298738 True True
# 323 red_1 Shoot at blue_0
# 334 red_1 Shoot at blue_0
# 390 blue_0: Destroyed
# 397 blue_0 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8989996990424548 114.1548060945583
# blue_1 False False 1200 0.9929996990424548 68.5880092695387
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 272 blue_1 Shoot at red_1 launch distance : 59740.25352224076 True True
# Same tgt shoot
# 284 blue_1 Shoot at red_0 launch distance : 57863.215520500096 True True
# 379 blue_1 Splash :red_1
# 391 blue_1 Splash :red_0
# WIN
# blue_0 False True 391 13.070385578164405 12.280670308439896
# blue_1 False True 391 29.70749212837753 147.97785605117718
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 282 blue_1 Shoot at red_1 launch distance : 56986.50026192875 True True
# 293 blue_1 Shoot at red_1 launch distance : 51945.97210633807 True True
# 329 red_0 Shoot at blue_1
# 340 red_0 Shoot at blue_1
# 382 blue_1: Destroyed
# 392 blue_1 Splash :red_1
# 510 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 510 -0.1010055663240026 20.865889134790436
# blue_1 False False 510 0.8989992670093307 98.18090428406595
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 795 red_0 Shoot at blue_1
# 795 red_1 Shoot at blue_1
# 806 red_0 Shoot at blue_1
# 806 red_1 Shoot at blue_1
# 851 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.10500168522119559 -79.90542788184464
# blue_1 False False 1200 -0.10100168522119558 -39.9806264516731
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 299 blue_1 Shoot at red_0 launch distance : 59617.10762160457 True True
# 310 blue_1 Shoot at red_0 launch distance : 54649.4386293946 True True
# Same tgt shoot
# Same tgt shoot
# 354 blue_0 Shoot at red_1 launch distance : 59911.621059663456 True True
# 363 red_1 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 366 blue_0 Shoot at red_1 launch distance : 54924.35251213019 True True
# 374 red_1 Shoot at blue_1
# 413 blue_1 Splash :red_0
# 424 blue_1: Destroyed
# 468 blue_0 Splash :red_1
# WIN
# blue_0 False True 574 12.089592334494775 134.23003952936614
# blue_1 False True 574 11.989592334494773 92.9235755602333
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 319 blue_0 Shoot at red_0 launch distance : 59608.754806338664 True True
# 330 blue_0 Shoot at red_0 launch distance : 55753.578311490695 True True
# 401 red_1 Shoot at blue_1
# 412 red_1 Shoot at blue_1
# 434 blue_0 Splash :red_0
# 470 blue_0 DOWN
# 472 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 472 0.8989995886139743 112.63973523097144
# blue_1 False False 472 0.858870655280641 22.835651505957756
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 298 blue_1 Shoot at red_1 launch distance : 58853.34142798432 True True
# 303 blue_0 Shoot at red_1 launch distance : 57505.33380253195 True True
# Same tgt shoot
# Same tgt shoot
# 310 blue_1 Shoot at red_0 launch distance : 53359.2111267462 True True
# Same tgt shoot
# Same tgt shoot
# 314 blue_0 Shoot at red_0 launch distance : 53106.128680808295 True True
# 410 blue_1 Splash :red_1
# 411 blue_1 Splash :red_0
# WIN
# blue_0 False True 514 12.333630350194554 121.19787928352743
# blue_1 False True 514 12.333630350194554 149.25195341184042
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 202 blue_1 DOWN
# 382 red_0 Shoot at blue_0
# 393 red_0 Shoot at blue_0
# 407 red_1 Shoot at blue_0
# 418 red_1 Shoot at blue_0
# 434 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 434 -1.113001054361241 9.619367609328057
# blue_1 False False 434 -0.10100105436124107 -1.505900876740975
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 301 blue_0 Shoot at red_1 launch distance : 59602.47440319478 True True
# Same tgt shoot
# 313 blue_0 Shoot at red_0 launch distance : 56988.87103744915 True True
# 429 blue_0 Splash :red_1
# 430 blue_0 Splash :red_0
# WIN
# blue_0 False True 430 28.873444650914095 140.95071665099465
# blue_1 False True 430 12.791054902076887 7.450359374418604
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 123 blue_0 DOWN
# 797 red_0 Shoot at blue_1
# 808 red_0 Shoot at blue_1
# 820 red_1 Shoot at blue_1
# 831 red_1 Shoot at blue_1
# 894 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 894 -0.1009984531958899 -1.2048257697158644
# blue_1 False False 894 -0.1435065531958899 -37.43497145144283
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 162 blue_0 DOWN
# 285 blue_1 Shoot at red_1 launch distance : 57896.31252462264 True True
# Same tgt shoot
# 297 blue_1 Shoot at red_0 launch distance : 56865.943709097446 True True
# 396 blue_1 Splash :red_1
# 405 blue_1 Splash :red_0
# WIN
# blue_0 False True 405 12.863298502324284 11.658926615603207
# blue_1 False True 405 29.38922442825021 151.44073738282833
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 157 blue_0 DOWN
# 272 blue_1 Shoot at red_0 launch distance : 57654.82509139097 True True
# Same tgt shoot
# 283 blue_1 Shoot at red_1 launch distance : 51961.44309529949 True True
# 307 red_1 Shoot at blue_1
# 375 blue_1 Splash :red_1
# 382 blue_1 Splash :red_0
# WIN
# blue_0 False True 507 12.265863905325443 11.06278575737998
# blue_1 False True 507 12.365863905325444 135.5808316517476
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 207 blue_0 DOWN
# 295 blue_1 Shoot at red_1 launch distance : 58408.006925612906 True True
# 307 blue_1 Shoot at red_1 launch distance : 53313.09939149815 True True
# 377 red_0 Shoot at blue_1
# 388 red_0 Shoot at blue_1
# 408 blue_1 Splash :red_1
# 463 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 463 0.8989997616597304 -0.45001084165422867
# blue_1 False False 463 0.8589670283263972 79.58509598001896
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 298 blue_1 Shoot at red_0 launch distance : 58966.87733519369 True True
# 308 blue_0 Shoot at red_0 launch distance : 59948.20043700911 True True
# Same tgt shoot
# Same tgt shoot
# 313 blue_1 Shoot at red_1 launch distance : 59129.414711010104 True True
# Same tgt shoot
# 320 blue_0 Shoot at red_0 launch distance : 55122.97822259547 True True
# 416 blue_1 Splash :red_0
# 434 blue_1 Splash :red_1
# WIN
# blue_0 False True 520 12.306692307692307 132.14194217435852
# blue_1 False True 520 12.306692307692307 116.05911976064017
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 224 blue_1 DOWN
# 520 red_1 Shoot at blue_0
# 531 red_1 Shoot at blue_0
# 635 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 635 -0.14054112966125107 -3.7008014134402973
# blue_1 False False 635 -0.10100022966125109 -1.5056492949332114
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 168 blue_1 DOWN
# 312 blue_0 Shoot at red_1 launch distance : 56772.04201841961 True True
# 323 blue_0 Shoot at red_1 launch distance : 51504.121760397495 True True
# 356 red_0 Shoot at blue_0
# 367 red_0 Shoot at blue_0
# 420 blue_0 Splash :red_1
# 428 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 428 0.8587282741603074 111.3927995444279
# blue_1 False False 428 0.8989996408269741 -0.4059393590172208
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 76 blue_1 DOWN
# 306 blue_0 Shoot at red_0 launch distance : 57025.761135211906 True True
# 318 blue_0 Shoot at red_0 launch distance : 52143.54068484598 True True
# 367 red_1 Shoot at blue_0
# 378 red_1 Shoot at blue_0
# 422 blue_0 Splash :red_0
# 436 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 436 0.8586565766294082 125.83565747865764
# blue_1 False False 436 0.8989993766294082 -0.3059508357996894
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 224 blue_0 DOWN
# 262 blue_1 Shoot at red_0 launch distance : 59847.55977572494 True True
# 276 blue_1 Shoot at red_0 launch distance : 52714.275946373964 True True
# 303 red_1 Shoot at blue_1
# 314 red_1 Shoot at blue_1
# 376 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 376 -0.10099991087902271 -3.367383384003984
# blue_1 False False 376 0.3584386891209773 105.32594205347944
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 473 red_0 Shoot at blue_1
# 484 red_0 Shoot at blue_1
# 521 red_1 Shoot at blue_1
# 532 red_1 Shoot at blue_1
# 553 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.1129987118815747 -22.80239578922219
# blue_1 False False 1200 -0.10099871188157471 -19.23368557868469
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 127 blue_1 DOWN
# 453 blue_0 Shoot at red_1 launch distance : 59219.331593838346 True True
# Same tgt shoot
# 469 blue_0 Shoot at red_0 launch distance : 59705.82740850666 True True
# 580 blue_0 Splash :red_1
# 592 blue_0 Splash :red_0
# WIN
# blue_0 False True 592 26.58156127311132 135.83146664889722
# blue_1 False True 592 11.927500285723928 10.522285869063102
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 373 blue_1 Shoot at red_0 launch distance : 58254.61488187188 True True
# 391 blue_1 Shoot at red_0 launch distance : 51159.02025740672 True True
# 460 red_1 Shoot at blue_1
# 471 red_1 Shoot at blue_1
# 492 blue_1 Splash :red_0
# 522 blue_1: Destroyed
# Same tgt shoot
# Same tgt shoot
# 1026 blue_0 Shoot at red_1 launch distance : 59916.659293868324 True True
# Same tgt shoot
# Same tgt shoot
# 1037 blue_0 Shoot at red_1 launch distance : 55012.86753273478 True True
# 1142 blue_0 Splash :red_1
# WIN
# blue_0 False False 1200 10.999003166666666 47.52341378213663
# blue_1 False False 1200 10.899 88.24484585890866
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 283 blue_1 Shoot at red_0 launch distance : 58469.605091531754 True True
# 296 blue_1 Shoot at red_0 launch distance : 52167.526020498044 True True
# 305 blue_0 Shoot at red_0 launch distance : 58346.86755155162 True True
# Same tgt shoot
# Same tgt shoot
# Same tgt shoot
# 316 blue_0 Shoot at red_1 launch distance : 56165.0124271001 True True
# 329 red_1 Shoot at blue_1
# 340 red_1 Shoot at blue_1
# 396 blue_1 Splash :red_0
# 424 blue_0 Splash :red_1
# WIN
# blue_0 False True 540 12.121216255555554 138.77581334737917
# blue_1 False True 540 12.221222222222222 118.23707641616123
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 361 blue_1 Shoot at red_1 launch distance : 58236.12722574541 True True
# Same tgt shoot
# 385 blue_1 Shoot at red_0 launch distance : 52509.5597689314 True True
# 414 blue_0 DOWN
# 426 red_0 Shoot at blue_1
# 437 red_0 Shoot at blue_1
# 488 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 488 0.39900010415860604 -4.026368526967968
# blue_1 False False 488 0.35889700415860604 63.88023935280443
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 487 red_1 Shoot at blue_1
# 498 red_1 Shoot at blue_1
# 502 red_0 Shoot at blue_1
# 513 red_0 Shoot at blue_1
# 557 blue_1: Destroyed
# 1017 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 1017 -1.1070006898486364 -43.673709035918534
# blue_1 False False 1017 -0.10100068984863637 -17.29971089607237
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 298 blue_1 Shoot at red_1 launch distance : 59529.75299290869 True True
# 310 blue_1 Shoot at red_1 launch distance : 53275.65432148643 True True
# 337 red_0 Shoot at blue_1
# 348 red_0 Shoot at blue_1
# 376 blue_1: Destroyed
# 410 blue_1 Splash :red_1
# Same tgt shoot
# Same tgt shoot
# 700 blue_0 Shoot at red_0 launch distance : 59186.64588473919 True True
# Same tgt shoot
# Same tgt shoot
# 759 blue_0 Shoot at red_0 launch distance : 46884.70555221785 True True
# 822 blue_0 Splash :red_0
# WIN
# blue_0 False True 959 11.250310274417796 119.25494133694819
# blue_1 False True 959 11.150303441084462 98.62840606427545
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 364 blue_1 Shoot at red_0 launch distance : 59624.28545688572 True True
# Same tgt shoot
# 376 blue_1 Shoot at red_1 launch distance : 57379.89897399317 True True
# 483 blue_1 Splash :red_0
# 487 blue_1 Splash :red_1
# WIN
# blue_0 False True 487 12.465457107450103 10.21799047508556
# blue_1 False True 487 27.89358235762122 141.51138292463557
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 266 blue_1 Shoot at red_1 launch distance : 59413.60856353563 True True
# Same tgt shoot
# 277 blue_1 Shoot at red_0 launch distance : 59381.27301076702 True True
# 379 blue_1 Splash :red_1
# 389 blue_1 Splash :red_0
# WIN
# blue_0 False True 389 13.085162974462618 23.236586471550993
# blue_1 False True 389 29.75482241756459 157.65319880717715
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 321 blue_0 Shoot at red_1 launch distance : 58340.220147139924 True True
# Same tgt shoot
# 333 blue_0 Shoot at red_0 launch distance : 58607.66878785826 True True
# 437 blue_0 Splash :red_1
# 455 blue_0 Splash :red_0
# WIN
# blue_0 False True 455 28.41247013958614 133.52132222543653
# blue_1 False True 455 12.637751398194203 5.548165604029297
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 318 blue_0 Shoot at red_0 launch distance : 57297.07031435683 True True
# 329 blue_0 Shoot at red_0 launch distance : 51480.37192756231 True True
# 356 red_1 Shoot at blue_0
# 367 red_1 Shoot at blue_0
# 421 blue_0: Destroyed
# 426 blue_0 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8989995247883694 115.85321779091116
# blue_1 False False 1200 0.8929920581217028 -39.98390519756465
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 186 blue_0 DOWN
# 263 blue_1 Shoot at red_1 launch distance : 57030.193547731644 True True
# 274 blue_1 Shoot at red_1 launch distance : 51800.178186459765 True True
# 320 red_0 Shoot at blue_1
# 331 red_0 Shoot at blue_1
# 372 blue_1 Splash :red_1
# 386 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 386 0.8989993971064854 -0.3038713981613417
# blue_1 False False 386 0.858844063773152 94.45727179547751
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 291 blue_1 Shoot at red_0 launch distance : 59048.05386528468 True True
# 302 blue_1 Shoot at red_0 launch distance : 53463.86962371378 True True
# 343 red_1 Shoot at blue_1
# 354 red_1 Shoot at blue_1
# 405 blue_1 Splash :red_0
# 416 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8930083305690318 -68.15339664419109
# blue_1 False False 1200 0.8990002305690319 118.44972283447396
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 194 blue_1 DOWN
# 292 blue_0 Shoot at red_0 launch distance : 59900.844946789766 True True
# Same tgt shoot
# 303 blue_0 Shoot at red_1 launch distance : 57503.17906008596 True True
# 402 blue_0 Splash :red_0
# 412 blue_0 Splash :red_1
# WIN
# blue_0 False True 412 29.2381954840486 139.32826289806798
# blue_1 False True 412 12.812952765601997 11.610058791884954
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 285 blue_1 Shoot at red_0 launch distance : 58934.07199568498 True True
# Same tgt shoot
# 301 blue_1 Shoot at red_1 launch distance : 59798.22561378725 True True
# 400 blue_1 Splash :red_0
# 426 blue_1 Splash :red_1
# WIN
# blue_0 False True 426 12.817225115798367 9.550504941784034
# blue_1 False True 426 28.951032832699777 114.01495219201877
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 224 blue_0 DOWN
# 275 blue_1 Shoot at red_1 launch distance : 58285.96788985495 True True
# 286 blue_1 Shoot at red_1 launch distance : 52628.77324345519 True True
# 328 red_0 Shoot at blue_1
# 339 red_0 Shoot at blue_1
# 386 blue_1 Splash :red_1
# 401 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 401 0.8989996193163329 -2.769284291574325
# blue_1 False False 401 0.8585860193163329 119.61400066089213
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 273 blue_1 Shoot at red_0 launch distance : 59727.81559910318 True True
# 285 blue_1 Shoot at red_0 launch distance : 54272.8866696824 True True
# 335 red_1 Shoot at blue_1
# 346 red_1 Shoot at blue_1
# 393 blue_1 Splash :red_0
# 397 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8969928054269508 -33.77919868338327
# blue_1 False False 1200 0.8989992054269508 99.03269411993219
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 283 blue_1 Shoot at red_1 launch distance : 59984.88463425344 True True
# Same tgt shoot
# 290 blue_0 Shoot at red_0 launch distance : 59906.22769350804 True True
# Same tgt shoot
# 295 blue_1 Shoot at red_1 launch distance : 54082.49964510339 True True
# Same tgt shoot
# Same tgt shoot
# 303 blue_0 Shoot at red_0 launch distance : 53629.62039284921 True True
# 399 blue_1 Splash :red_1
# 399 blue_0 Splash :red_0
# 417 blue_0 DOWN
# WIN
# blue_0 False True 503 12.284685884691848 129.40397291201015
# blue_1 False True 503 12.38468588469185 124.86796841200983
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 336 blue_1 Shoot at red_0 launch distance : 58230.535680590474 True True
# 461 blue_1 Splash :red_0
# 487 red_1 Shoot at blue_0
# 498 red_1 Shoot at blue_0
# 576 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8990004493472885 -2.9234084800603606
# blue_1 False False 1200 0.8990004493472885 32.393166438243256
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 185 blue_0 DOWN
# 375 red_0 Shoot at blue_1
# 386 red_0 Shoot at blue_1
# 386 red_1 Shoot at blue_1
# 397 red_1 Shoot at blue_1
# 448 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 448 -0.10100035979083972 -1.3046125666158817
# blue_1 False False 448 -0.14145395979083975 -13.64308181355713
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 720 red_1 Shoot at blue_1
# 727 red_0 Shoot at blue_1
# 731 red_1 Shoot at blue_1
# 738 red_0 Shoot at blue_1
# 785 blue_0 DOWN
# 817 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 817 -0.10099842468814772 -14.343605766096157
# blue_1 False False 817 -0.14287325802148107 -32.682440786566715
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2022-04-05 01:11:47,211	WARNING deprecation.py:46 -- DeprecationWarning: `clear_buffer` has been deprecated. Use `Filter.reset_buffer()` instead. This will raise an error in the future!
# agent_timesteps_total: 60696
# custom_metrics: {}
# date: 2022-04-05_01-11-47
# done: false
# episode_len_mean: 674.4
# episode_media: {}
# episode_reward_max: 270.44983269536766
# episode_reward_mean: 103.59936363342135
# episode_reward_min: -119.8860543335177
# episodes_this_iter: 45
# episodes_total: 45
# experiment_id: b7bc6bb0bdfa4636b9eb71264eb36a37
# hostname: DESKTOP
# info:
#   learner:
#     blue_0:
#       learner_stats:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0002500000118743628
#         entropy: 6.862703800201416
#         entropy_coeff: 0.0
#         kl: 0.08954828977584839
#         model: {}
#         policy_loss: 0.002263125032186508
#         total_loss: 391.0355224609375
#         vf_explained_var: -0.13413006067276
#         vf_loss: 391.0153503417969
#       train: null
#     blue_1:
#       learner_stats:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0002500000118743628
#         entropy: 6.747198581695557
#         entropy_coeff: 0.0
#         kl: 0.058865465223789215
#         model: {}
#         policy_loss: -0.015065333805978298
#         total_loss: 300.9110107421875
#         vf_explained_var: 0.05599546059966087
#         vf_loss: 300.914306640625
#       train: null
#   num_agent_steps_sampled: 60696
#   num_agent_steps_trained: 60696
#   num_steps_sampled: 30348
#   num_steps_trained: 30348
#   num_steps_trained_this_iter: 30348
# iterations_since_restore: 1
# node_ip: 127.0.0.1
# num_healthy_workers: 0
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 43.35247597930525
#   ram_util_percent: 36.02625646711013
# pid: 11808
# policy_reward_max:
#   blue_0: 150.73529858231754
#   blue_1: 157.65319880717715
# policy_reward_mean:
#   blue_0: 45.618726210141254
#   blue_1: 57.98063742328007
# policy_reward_min:
#   blue_0: -79.90542788184464
#   blue_1: -47.17588964176178
# sampler_perf:
#   mean_action_processing_ms: 0.5663333526297595
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 65.20196471506061
#   mean_inference_ms: 18.5123057046311
#   mean_raw_obs_processing_ms: 6.185320622563783
# time_since_restore: 3815.873510837555
# time_this_iter_s: 3815.873510837555
# time_total_s: 3815.873510837555
# timers:
#   learn_throughput: 28.379
#   learn_time_ms: 1069364.471
#   load_throughput: 61472.96
#   load_time_ms: 493.68
#   sample_throughput: 10.97
#   sample_time_ms: 2766458.24
# timestamp: 1649088707
# timesteps_since_restore: 30348
# timesteps_this_iter: 30348
# timesteps_total: 30348
# training_iteration: 1
# trial_id: default
#
#
# -------------- Evaluation at steps:0 starting ! --------------
# 2022-04-05 01:11:47,800	INFO trainable.py:496 -- Restored on 127.0.0.1 from checkpoint: ./UCAV/checkpoints/test_2\checkpoint_000001\checkpoint-1
# 2022-04-05 01:11:47,801	INFO trainable.py:503 -- Current state after restoring: {'_iteration': 1, '_timesteps_total': 30348, '_time_total': 3815.873510837555, '_episodes_total': 45}
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 274 blue_0 Shoot at red_0 launch distance : 59450.06966447068 True True
# 285 blue_0 Shoot at red_0 launch distance : 53819.06790109737 True True
# 301 red_1 Shoot at blue_0
# 312 red_1 Shoot at blue_0
# 356 blue_0: Destroyed
# 383 blue_0 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8990006046521788 88.00677418550706
# blue_1 False False 1200 0.8930006046521788 45.24577457423132
#
# ----------------- Training at steps:1 start! -----------------
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 284 blue_0 Shoot at red_1 launch distance : 58380.603798420794 True True
# 295 blue_0 Shoot at red_1 launch distance : 53325.65576135979 True True
# 312 blue_1 Shoot at red_1 launch distance : 59555.74148335227 True True
# Same tgt shoot
# Same tgt shoot
# Same tgt shoot
# 323 blue_1 Shoot at red_0 launch distance : 59744.52262899521 True True
# 342 red_0 Shoot at blue_0
# 353 red_0 Shoot at blue_0
# 386 blue_0: Destroyed
# 399 blue_0 Splash :red_1
# 446 blue_1 Splash :red_0
# WIN
# blue_0 False True 446 13.090933306895547 124.51645493152
# blue_1 False True 446 28.57209922617806 149.55399557892375
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 272 blue_1 Shoot at red_0 launch distance : 59442.16219845584 True True
# 284 blue_1 Shoot at red_0 launch distance : 53452.35643280195 True True
# 333 red_1 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 339 blue_0 Shoot at red_1 launch distance : 59382.25719598336 True True
# 344 red_1 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 370 blue_0 Shoot at red_1 launch distance : 45034.42679076279 True True
# 386 blue_1 Splash :red_0
# 441 blue_0 Splash :red_1
# WIN
# blue_0 False True 570 12.104263157894737 110.30068636197622
# blue_1 False True 570 12.104263157894737 160.3651220382051
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 320 blue_1 Shoot at red_0 launch distance : 59329.596943558216 True True
# 332 blue_1 Shoot at red_0 launch distance : 54471.28857109582 True True
# 397 red_1 Shoot at blue_1
# 408 red_1 Shoot at blue_1
# 440 blue_1 Splash :red_0
# 449 blue_0 DOWN
# 468 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 468 0.8989999310282553 -0.722286150689609
# blue_1 False False 468 0.8583938976949219 75.0117465929431
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 301 blue_1 Shoot at red_0 launch distance : 59662.55548969152 True True
# 313 blue_1 Shoot at red_0 launch distance : 53376.363937299015 True True
# 335 red_1 Shoot at blue_1
# 346 red_1 Shoot at blue_1
# 379 blue_0 DOWN
# 401 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 401 -0.10099945382700988 18.411008985806763
# blue_1 False False 401 0.35895747950632345 96.95538481466446
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 295 blue_1 Shoot at red_0 launch distance : 58058.812005440624 True True
# 305 blue_0 Shoot at red_0 launch distance : 59298.07039588169 True True
# Same tgt shoot
# Same tgt shoot
# 306 blue_1 Shoot at red_1 launch distance : 55005.39230147705 True True
# Same tgt shoot
# Same tgt shoot
# 317 blue_0 Shoot at red_1 launch distance : 56921.969082647454 True True
# 365 blue_0 DOWN
# 407 blue_1 Splash :red_1
# 408 blue_1 Splash :red_0
# WIN
# blue_0 False True 517 12.220083172147001 67.66907904941247
# blue_1 False True 517 12.320083172147003 150.52648851012913
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 276 blue_1 Shoot at red_0 launch distance : 59741.542104165135 True True
# Same tgt shoot
# 294 blue_0 Shoot at red_1 launch distance : 59413.573647565725 True True
# Same tgt shoot
# 297 blue_1 Shoot at red_0 launch distance : 51478.92112489426 True True
# Same tgt shoot
# 307 blue_0 Shoot at red_0 launch distance : 57176.78463849534 True True
# 321 red_1 Shoot at blue_1
# 396 blue_0 Splash :red_1
# 397 blue_1 Splash :red_0
# WIN
# blue_0 False True 521 12.303262955854127 113.59211884979314
# blue_1 False True 521 12.302262955854127 122.54484213956485
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 133 blue_1 DOWN
# 144 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 144 -1.1010020712189914 -1.4054513830108353
# blue_1 False False 144 -0.10100160455232482 -1.3038257828199098
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 193 blue_0 DOWN
# 301 blue_1 Shoot at red_0 launch distance : 59607.58441232351 True True
# 313 blue_1 Shoot at red_0 launch distance : 53413.09418268816 True True
# 335 red_1 Shoot at blue_1
# 346 red_1 Shoot at blue_1
# 406 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 406 -0.10099988114727139 -1.405579115802286
# blue_1 False False 406 0.35880815218606193 95.29623946921988
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 302 blue_1 Shoot at red_0 launch distance : 58411.80872047587 True True
# Same tgt shoot
# 318 blue_1 Shoot at red_1 launch distance : 58518.32720794922 True True
# 415 blue_1 Splash :red_0
# 424 blue_1 Splash :red_1
# WIN
# blue_0 False True 424 12.831516298736277 12.632267245911947
# blue_1 False True 424 28.99090072389351 128.19194580118963
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 295 blue_0 Shoot at red_1 launch distance : 58247.77887281497 True True
# Same tgt shoot
# 306 blue_0 Shoot at red_0 launch distance : 59384.87851492304 True True
# 339 blue_0 DOWN
# 408 blue_0 Splash :red_1
# 427 blue_0 Splash :red_0
# WIN
# blue_0 False True 427 28.83124809584231 88.7905394400851
# blue_1 False True 427 12.710639196544887 -5.6384455503512765
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 174 blue_1 DOWN
# 359 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 359 -0.9049887403011305 1.3927120844444394
# blue_1 False False 359 -0.10100040696779722 -1.3050828376722294
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 265 blue_1 Shoot at red_1 launch distance : 58536.67186299275 True True
# Same tgt shoot
# 278 blue_1 Shoot at red_0 launch distance : 58493.21700483319 True True
# Same tgt shoot
# 305 blue_0 Shoot at red_1 launch distance : 59263.19623096932 True True
# Same tgt shoot
# 319 blue_0 Shoot at red_1 launch distance : 58653.16904371699 True True
# 374 blue_1 Splash :red_1
# 390 blue_1 Splash :red_0
# WIN
# blue_0 False True 519 12.3121387283237 94.30138722832325
# blue_1 False True 519 12.3121387283237 130.42534241496813
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 200 blue_1 DOWN
# 345 blue_0 Shoot at red_0 launch distance : 57626.36960495786 True True
# 358 blue_0 Shoot at red_0 launch distance : 51540.883696786565 True True
# 397 red_1 Shoot at blue_0
# 408 red_1 Shoot at blue_0
# 459 blue_0 Splash :red_0
# 469 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 469 0.8587088165416379 124.63524719269171
# blue_1 False False 469 0.8989994498749712 -0.40447173683591675
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 275 blue_1 Shoot at red_1 launch distance : 58838.28545250363 True True
# 287 blue_1 Shoot at red_1 launch distance : 52856.431081739735 True True
# 299 blue_0 DOWN
# 323 red_0 Shoot at blue_1
# 334 red_0 Shoot at blue_1
# 386 blue_1 Splash :red_1
# 390 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 390 0.898998887766891 2.8644786453549345
# blue_1 False False 390 0.8586517544335577 117.04506831051702
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 284 blue_1 Shoot at red_0 launch distance : 58216.124655316635 True True
# Same tgt shoot
# 296 blue_1 Shoot at red_1 launch distance : 56578.00777024969 True True
# 399 blue_1 Splash :red_0
# 405 blue_1 Splash :red_1
# WIN
# blue_0 False True 405 12.964284964572164 9.557234896296295
# blue_1 False True 405 29.39021962383142 114.36517568287383
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 144 blue_0 DOWN
# 668 red_1 Shoot at blue_1
# 671 red_0 Shoot at blue_1
# 679 red_1 Shoot at blue_1
# 682 red_0 Shoot at blue_1
# 767 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 767 -0.10099882222446113 -1.406135144828517
# blue_1 False False 767 -0.14204555555779447 -11.990757292428253
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 297 blue_1 Shoot at red_0 launch distance : 58748.412680216854 True True
# 317 blue_1 Shoot at red_0 launch distance : 50213.268140749766 True True
# 357 blue_0 Shoot at red_0 launch distance : 59856.59919304503 True True
# 368 blue_0 Shoot at red_0 launch distance : 58364.253339176845 True True
# 368 red_1 Shoot at blue_1
# 379 red_1 Shoot at blue_1
# 413 blue_1 Splash :red_0
# 432 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9929992256224022 90.05877020498622
# blue_1 False False 1200 0.8989992256224022 87.55994910385266
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 300 blue_1 Shoot at red_1 launch distance : 58523.19459595913 True True
# 313 blue_1 Shoot at red_1 launch distance : 52163.23496315612 True True
# 343 red_0 Shoot at blue_1
# 354 red_0 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 367 blue_0 Shoot at red_0 launch distance : 46067.954838017286 True True
# Same tgt shoot
# Same tgt shoot
# 382 blue_0 Shoot at red_0 launch distance : 39872.68116788757 True True
# 411 blue_1 Splash :red_1
# 457 blue_0 Splash :red_0
# WIN
# blue_0 False True 582 11.960855670103092 118.33774537462511
# blue_1 False True 582 12.061855670103093 127.09452156183005
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 310 blue_0 Shoot at red_1 launch distance : 55453.35728875534 True True
# 323 blue_0 Shoot at red_1 launch distance : 49869.91426858568 True True
# Same tgt shoot
# Same tgt shoot
# 333 blue_1 Shoot at red_0 launch distance : 57090.68903858882 True True
# Same tgt shoot
# Same tgt shoot
# 346 blue_1 Shoot at red_0 launch distance : 51824.57221472636 True True
# 355 red_0 Shoot at blue_0
# 424 blue_0 Splash :red_1
# 447 blue_1 Splash :red_0
# 455 blue_0 DOWN
# WIN
# blue_0 False True 555 12.06116216216216 155.1987835539861
# blue_1 False True 555 12.161162162162162 116.87453381227397
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 279 blue_1 Shoot at red_0 launch distance : 59167.93044157299 True True
# 300 blue_1 Shoot at red_0 launch distance : 50075.662034921224 True True
# 336 red_1 Shoot at blue_1
# 347 red_1 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 376 blue_0 Shoot at red_1 launch distance : 58417.390588112336 True True
# 397 blue_1 Splash :red_0
# Same tgt shoot
# Same tgt shoot
# 404 blue_0 Shoot at red_1 launch distance : 55356.68370762365 True True
# 411 blue_1: Destroyed
# 523 blue_0 Splash :red_1
# WIN
# blue_0 False True 604 11.985754966887418 125.46090870073051
# blue_1 False True 604 11.885754966887417 113.39391177428803
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 302 blue_0 Shoot at red_1 launch distance : 57524.09054437776 True True
# 418 blue_0 Splash :red_1
# 424 red_0 Shoot at blue_1
# 435 red_0 Shoot at blue_1
# 437 blue_1 DOWN
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9929990603243063 59.53877449177307
# blue_1 False False 1200 0.899000326990973 7.1817714003440525
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 302 blue_1 Shoot at red_0 launch distance : 58734.800357964275 True True
# 327 blue_0 Shoot at red_0 launch distance : 58478.89932580322 True True
# Same tgt shoot
# Same tgt shoot
# 339 blue_0 Shoot at red_1 launch distance : 57563.84528510414 True True
# Same tgt shoot
# Same tgt shoot
# 406 blue_1 Shoot at red_1 launch distance : 46845.755875813884 True True
# 415 blue_1 Splash :red_0
# 441 blue_0 Splash :red_1
# WIN
# blue_0 False True 606 11.97919801980198 139.97662169055008
# blue_1 False True 606 11.97919801980198 100.93757858325515
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 264 blue_1 Shoot at red_0 launch distance : 58394.45192650291 True True
# 275 blue_1 Shoot at red_0 launch distance : 52657.989183722566 True True
# 308 red_1 Shoot at blue_1
# 319 red_1 Shoot at blue_1
# 377 blue_1 Splash :red_0
# 378 blue_1: Destroyed
# Same tgt shoot
# Same tgt shoot
# 444 blue_0 Shoot at red_1 launch distance : 59939.2184969808 True True
# Same tgt shoot
# Same tgt shoot
# 455 blue_0 Shoot at red_1 launch distance : 55029.184344624475 True True
# 571 blue_0 Splash :red_1
# WIN
# blue_0 False True 655 11.831053602035622 110.08033363297551
# blue_1 False True 655 11.731061068702289 127.35292903929466
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 287 blue_0 Shoot at red_0 launch distance : 59556.9972795286 True True
# Same tgt shoot
# 298 blue_0 Shoot at red_1 launch distance : 54878.92793193625 True True
# Same tgt shoot
# 306 blue_1 Shoot at red_1 launch distance : 59454.577373890854 True True
# Same tgt shoot
# Same tgt shoot
# 317 blue_1 Shoot at red_0 launch distance : 57541.71216868484 True True
# 403 blue_0 Splash :red_0
# 408 blue_0 Splash :red_1
# WIN
# blue_0 False True 517 12.320083172147003 155.86301913424953
# blue_1 False True 517 12.220083172147001 115.87132567214675
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 200 blue_1 DOWN
# 822 red_0 Shoot at blue_0
# 829 red_1 Shoot at blue_0
# 833 red_0 Shoot at blue_0
# 840 red_1 Shoot at blue_0
# 887 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 887 -0.13757469605867848 -3.5243389575416053
# blue_1 False False 887 -0.10100076272534515 -1.4044971222599587
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 204 blue_0 DOWN
# 298 blue_1 Shoot at red_0 launch distance : 59712.07499953044 True True
# 312 blue_1 Shoot at red_0 launch distance : 53358.07519207913 True True
# 354 red_1 Shoot at blue_1
# 365 red_1 Shoot at blue_1
# 416 blue_1 Splash :red_0
# 426 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 426 0.8989995167582163 -1.235344499985118
# blue_1 False False 426 0.8585207834248829 116.58955650540292
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 284 blue_1 Shoot at red_0 launch distance : 55580.066039665064 True True
# Same tgt shoot
# 297 blue_1 Shoot at red_1 launch distance : 54498.82098087294 True True
# 388 blue_1 Splash :red_0
# 401 blue_1 Splash :red_1
# WIN
# blue_0 False True 401 12.993842896048365 12.812137003241896
# blue_1 False True 401 29.478873069198823 148.3363662867016
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 306 blue_0 Shoot at red_0 launch distance : 57822.67027488219 True True
# Same tgt shoot
# 317 blue_0 Shoot at red_1 launch distance : 56403.35231133506 True True
# 423 blue_0 Splash :red_0
# 430 blue_0 Splash :red_1
# WIN
# blue_0 False True 430 28.87342740825182 158.77909922183736
# blue_1 False True 430 12.791037692747947 5.9846010410852655
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 285 blue_1 Shoot at red_0 launch distance : 59852.90378861403 True True
# 297 blue_1 Shoot at red_0 launch distance : 54274.13120880994 True True
# 300 blue_0 Shoot at red_0 launch distance : 58747.23012794901 True True
# 311 blue_0 Shoot at red_0 launch distance : 53537.91120571117 True True
# 354 red_1 Shoot at blue_0
# 365 red_1 Shoot at blue_0
# 403 blue_1 Splash :red_0
# 419 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8990001081365213 99.89280912352508
# blue_1 False False 1200 0.8930001081365213 60.314577748204485
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 327 blue_1 Shoot at red_0 launch distance : 58248.5392399024 True True
# ...
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 284 blue_1 Shoot at red_0 launch distance : 57843.33644349911 True True
# 289 blue_0 Shoot at red_0 launch distance : 59164.79667353767 True True
# Same tgt shoot
# Same tgt shoot
# 299 blue_1 Shoot at red_1 launch distance : 56022.4454191147 True True
# Same tgt shoot
# 301 blue_0 Shoot at red_0 launch distance : 54185.4093962109 True True
# 393 blue_1 Splash :red_0
# 405 blue_1 Splash :red_1
# WIN
# blue_0 False True 501 12.394209580838323 98.99745384750483
# blue_1 False True 501 12.394209580838323 152.17124770243828
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 300 blue_1 Shoot at red_1 launch distance : 58587.9972847174 True True
# 311 blue_1 Shoot at red_1 launch distance : 53021.110848054 True True
# 340 red_0 Shoot at blue_1
# 351 red_0 Shoot at blue_1
# 363 blue_0 DOWN
# 412 blue_1 Splash :red_1
# 415 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 415 0.8989995806900244 18.371415992811396
# blue_1 False False 415 0.8587918140233577 89.65282727913322
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 287 blue_0 Shoot at red_1 launch distance : 59980.84474009905 True True
# 301 blue_0 Shoot at red_1 launch distance : 53230.52984603051 True True
# 302 blue_1 Shoot at red_1 launch distance : 59231.330096369646 True True
# Same tgt shoot
# Same tgt shoot
# Same tgt shoot
# 313 blue_1 Shoot at red_0 launch distance : 54935.69863352302 True True
# 332 red_0 Shoot at blue_0
# 333 blue_1 DOWN
# 343 red_0 Shoot at blue_0
# 399 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 399 0.35878965781177596 95.59033305588298
# blue_1 False False 399 0.3990013578117759 42.71292497637912
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 274 blue_1 Shoot at red_0 launch distance : 58914.28365502992 True True
# Same tgt shoot
# 288 blue_1 Shoot at red_1 launch distance : 58735.52511121766 True True
# 304 blue_0 DOWN
# 388 blue_1 Splash :red_0
# 402 blue_1 Splash :red_1
# WIN
# blue_0 False True 402 12.885380957262011 11.683659485375385
# blue_1 False True 402 29.355530210993354 158.08404059090628
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 287 blue_0 Shoot at red_1 launch distance : 59332.87689314704 True True
# Same tgt shoot
# 298 blue_0 Shoot at red_0 launch distance : 55161.44706546517 True True
# Same tgt shoot
# 311 blue_1 Shoot at red_1 launch distance : 57795.394681434096 True True
# Same tgt shoot
# Same tgt shoot
# 323 blue_1 Shoot at red_0 launch distance : 53170.131676625555 True True
# 401 blue_0 Splash :red_1
# 401 blue_0 Splash :red_0
# WIN
# blue_0 False True 523 12.294455066921607 136.44073707340527
# blue_1 False True 523 12.294455066921607 97.61370416692137
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 289 blue_1 Shoot at red_1 launch distance : 58427.95108361521 True True
# 300 blue_1 Shoot at red_1 launch distance : 52963.96778653567 True True
# 332 red_0 Shoot at blue_1
# 343 red_0 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 369 blue_0 Shoot at red_0 launch distance : 46706.53523889231 True True
# 401 blue_1 Splash :red_1
# 466 blue_0 Splash :red_0
# WIN
# blue_0 False True 466 28.225734380124223 100.09357125507867
# blue_1 False True 466 12.975519787849542 171.36038570262113
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 254 blue_1 Shoot at red_1 launch distance : 59678.253559137745 True True
# 275 blue_1 Shoot at red_1 launch distance : 49296.914334321176 True True
# 277 blue_0 Shoot at red_1 launch distance : 59552.53009216484 True True
# 289 blue_0 Shoot at red_1 launch distance : 54628.36851356775 True True
# 318 red_0 Shoot at blue_1
# 329 red_0 Shoot at blue_1
# 370 blue_1 Splash :red_1
# 390 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9940056887255072 100.68916120270632
# blue_1 False False 1200 0.8990007553921738 121.69529990954477
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 277 blue_1 Shoot at red_1 launch distance : 54057.087319772516 True True
# 281 blue_0 Shoot at red_1 launch distance : 59114.08506477959 True True
# Same tgt shoot
# Same tgt shoot
# 288 blue_1 Shoot at red_0 launch distance : 54888.416120061534 True True
# Same tgt shoot
# Same tgt shoot
# 294 blue_0 Shoot at red_0 launch distance : 59947.0694305785 True True
# 379 blue_1 Splash :red_1
# 393 blue_1 Splash :red_0
# WIN
# blue_0 False True 494 12.429149797570851 114.4983995975706
# blue_1 False True 494 12.428149797570851 154.71771828576897
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 270 blue_1 Shoot at red_1 launch distance : 59943.45620838528 True True
# 275 blue_0 Shoot at red_1 launch distance : 55045.286732204455 True True
# 283 blue_1 Shoot at red_1 launch distance : 53469.26637877162 True True
# 287 blue_0 Shoot at red_1 launch distance : 49031.696502995044 True True
# 322 red_0 Shoot at blue_0
# 333 red_0 Shoot at blue_0
# 380 blue_0 Splash :red_1
# 393 blue_0: Destroyed
# 540 blue_1 DOWN
# TIME LIMIT LOSE
# blue_0 False False 540 0.8990004369808571 117.23158589214053
# blue_1 False False 540 -0.10699956301914293 100.2878707090135
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 262 blue_1 Shoot at red_1 launch distance : 58236.60268583844 True True
# Same tgt shoot
# 273 blue_1 Shoot at red_0 launch distance : 58131.31052623852 True True
# Same tgt shoot
# 368 blue_0 Shoot at red_0 launch distance : 59986.15014348657 True True
# 371 blue_1 Splash :red_1
# Same tgt shoot
# 380 blue_0 Shoot at red_0 launch distance : 59823.24268908452 True True
# 385 blue_1 Splash :red_0
# WIN
# blue_0 False True 580 12.06796551724138 63.408211717241684
# blue_1 False True 580 12.068965517241379 152.2159824130916
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 275 blue_1 Shoot at red_1 launch distance : 59787.681504798864 True True
# Same tgt shoot
# 290 blue_1 Shoot at red_0 launch distance : 54402.52877878179 True True
# 388 blue_1 Splash :red_1
# 397 blue_1 Splash :red_0
# WIN
# blue_0 False True 397 13.023007445432524 13.013140725188919
# blue_1 False True 397 29.56833979581036 154.38282411920937
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 276 blue_1 Shoot at red_1 launch distance : 55258.006353419616 True True
# 277 blue_0 Shoot at red_1 launch distance : 55751.43305507668 True True
# 290 blue_0 Shoot at red_1 launch distance : 49260.020610598 True True
# Same tgt shoot
# Same tgt shoot
# Same tgt shoot
# 299 blue_1 Shoot at red_0 launch distance : 52223.739409106354 True True
# 380 blue_1 Splash :red_1
# 396 blue_1 Splash :red_0
# WIN
# blue_0 False True 396 13.530646579072046 125.876550030303
# blue_1 False True 396 29.591252639678107 158.68494463125995
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 137 blue_0 DOWN
# 488 red_0 Shoot at blue_1
# 499 red_0 Shoot at blue_1
# 574 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 574 -0.10100006869990906 -1.405339633252283
# blue_1 False False 574 -0.1410812353665757 -4.234807203024932
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 275 blue_1 Shoot at red_0 launch distance : 59747.59888469682 True True
# 286 blue_1 Shoot at red_0 launch distance : 54492.96854659344 True True
# Same tgt shoot
# Same tgt shoot
# 315 blue_0 Shoot at red_1 launch distance : 59540.01019957993 True True
# 324 red_1 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 328 blue_0 Shoot at red_1 launch distance : 53169.51126991478 True True
# 335 red_1 Shoot at blue_1
# 393 blue_1 Splash :red_0
# 432 blue_0 Splash :red_1
# WIN
# blue_0 False True 535 12.241990654205608 129.65279364309424
# blue_1 False True 535 12.241990654205608 128.89710674987955
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 271 blue_1 Shoot at red_1 launch distance : 59486.84908192876 True True
# 286 blue_1 Shoot at red_1 launch distance : 52158.94322662104 True True
# 340 red_0 Shoot at blue_1
# 351 red_0 Shoot at blue_1
# 387 blue_1 Splash :red_1
# 411 blue_1: Destroyed
# Same tgt shoot
# Same tgt shoot
# 525 blue_0 Shoot at red_0 launch distance : 59424.11684775489 True True
# Same tgt shoot
# Same tgt shoot
# 536 blue_0 Shoot at red_0 launch distance : 53924.12393674418 True True
# 643 blue_0 Splash :red_0
# WIN
# blue_0 False True 736 11.630434782608695 122.8441835039666
# blue_1 False True 736 11.529434782608694 120.30378183879948
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 281 blue_1 Shoot at red_0 launch distance : 59084.099024724965 True True
# 292 blue_1 Shoot at red_0 launch distance : 53250.18081691622 True True
# 328 red_1 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 334 blue_0 Shoot at red_1 launch distance : 58688.16632415985 True True
# 339 red_1 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 348 blue_0 Shoot at red_1 launch distance : 53211.146765863756 True True
# 395 blue_1 Splash :red_0
# 453 blue_0 Splash :red_1
# WIN
# blue_0 False True 548 12.18878102189781 118.93204373359745
# blue_1 False True 548 12.088781021897809 155.70097505565272
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 326 blue_0 Shoot at red_0 launch distance : 59776.26407481486 True True
# 348 blue_0 Shoot at red_0 launch distance : 50523.25596327821 True True
# 407 red_1 Shoot at blue_0
# 418 red_1 Shoot at blue_0
# 447 blue_0 Splash :red_0
# 482 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8989995920344721 86.10791164894657
# blue_1 False False 1200 0.8930024587011388 -46.47866642745273
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 163 blue_0 DOWN
# 370 blue_1 DOWN
# TIME LIMIT LOSE
# blue_0 False False 370 -0.1010014254615441 -1.4053750164459375
# blue_1 False False 370 -1.1049948921282107 -1.1772624125189737
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 294 blue_1 Shoot at red_1 launch distance : 58360.64337199118 True True
# 305 blue_1 Shoot at red_1 launch distance : 52697.26808377956 True True
# 326 blue_0 DOWN
# 331 red_0 Shoot at blue_1
# 342 red_0 Shoot at blue_1
# 403 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 403 0.39900016252220466 7.601635300716724
# blue_1 False False 403 0.35877002918887135 100.59522182686332
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 272 blue_0 Shoot at red_1 launch distance : 59887.352349966415 True True
# 279 blue_1 Shoot at red_1 launch distance : 58609.400347185445 True True
# 283 blue_0 Shoot at red_1 launch distance : 55003.65509008472 True True
# Same tgt shoot
# Same tgt shoot
# Same tgt shoot
# 294 blue_1 Shoot at red_0 launch distance : 59180.2073977302 True True
# 393 blue_0 Splash :red_1
# 410 blue_1 Splash :red_0
# WIN
# blue_0 False True 410 13.42716415426261 154.06793483063362
# blue_1 False True 410 29.180822690847975 147.60873533821143
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 322 blue_0 Shoot at red_0 launch distance : 58006.92883416196 True True
# 400 red_1 Shoot at blue_0
# 411 red_1 Shoot at blue_0
# 450 blue_0 Splash :red_0
# 466 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8990006450521553 83.41811584140456
# blue_1 False False 1200 0.9930006450521552 12.219056044792273
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 289 blue_1 Shoot at red_0 launch distance : 58139.20121885513 True True
# 301 blue_1 Shoot at red_0 launch distance : 52101.71646954492 True True
# 307 blue_0 Shoot at red_0 launch distance : 58617.780298013524 True True
# 336 red_1 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# Same tgt shoot
# 342 blue_0 Shoot at red_1 launch distance : 51567.3199546694 True True
# 347 red_1 Shoot at blue_1
# 401 blue_1 Splash :red_0
# 441 blue_0 Splash :red_1
# WIN
# blue_0 False True 547 12.192784277879342 145.13520921529405
# blue_1 False True 547 12.192784277879342 158.67406321769602
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 161 blue_0 DOWN
# 367 blue_1 Shoot at red_1 launch distance : 47641.55953733586 True True
# 379 red_0 Shoot at blue_1
# 380 blue_1 Shoot at red_1 launch distance : 42255.700151669764 True True
# 386 red_1 Shoot at blue_1
# 390 red_0 Shoot at blue_1
# 447 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 447 0.39900015480942763 -0.9063516848365055
# blue_1 False False 447 0.35891675480942764 69.77229274822108
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 199 blue_1 DOWN
# 353 blue_0 Shoot at red_1 launch distance : 59697.83294247289 True True
# 418 red_0 Shoot at blue_0
# 429 red_0 Shoot at blue_0
# 484 blue_0 Splash :red_1
# 496 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 496 0.8591612449718506 68.00443604625832
# blue_1 False False 496 0.898999778305184 -0.30467659394507396
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 132 blue_0 DOWN
# 286 blue_1 Shoot at red_1 launch distance : 57129.158083535636 True True
# 362 red_0 Shoot at blue_1
# 373 red_0 Shoot at blue_1
# 395 blue_1 Splash :red_1
# 433 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 433 0.89899962262877 -0.40561528197622065
# blue_1 False False 433 0.8589796892954367 80.18071405625433
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
