# %%
# %matplotlib tk
import argparse
import gym
import datetime
import os
import random
import tempfile
import numpy as np
import pickle

import ray
from ray import tune
from ray.tune.logger import Logger, UnifiedLogger, pretty_print
from ray.rllib.env.multi_agent_env import make_multi_agent
from ray.rllib.examples.models.shared_weights_model import TF2SharedWeightsModel
from ray.rllib.models import ModelCatalog
from ray.rllib.utils.framework import try_import_tf
from ray.rllib.utils.test_utils import check_learning_achieved
from ray.rllib.agents.ppo import ppo, PPOTrainer, PPOTFPolicy
from ray.rllib.agents.a3c.a3c_tf_policy import A3CTFPolicy
from ray.rllib.agents.a3c import a3c
from ray.rllib.models import ModelCatalog
from ray.rllib.policy.policy import PolicySpec
from environment_rllib_3d1 import MyEnv
#from test_env_for_lstm import MyEnv
from settings.initial_settings import *
from settings.reset_conditions import reset_conditions

from tensorflow.keras.utils import plot_model
from modules.savers import save_conditions
from utility.result_env import render_env
from utility.terminate_uavsimproc import teminate_proc
from utility.latest_learned_file_path import latest_learned_file_path
from utility.read_wright_weights import save_weights
from utility.read_wright_weights import reload_weights
from utility.save_logs import save_logs
from utility.save_logs import save_hists
from utility.save_logs import save_env_info

import matplotlib.pyplot as plt
import matplotlib
import tensorflow as tf
import cv2
import ctypes
import warnings

#UCAV.exeが起動している場合、プロセスキルする。
teminate_proc.UAVsimprockill(proc_name="UCAV.exe")

warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning) 
warnings.filterwarnings('ignore', category=matplotlib.MatplotlibDeprecationWarning)
np.set_printoptions(precision=3, suppress=True)
PROJECT = "UCAV"
TRIAL_ID = 2
TRIAL = 'test_' + str(TRIAL_ID)
EVAL_FREQ = 1
CONTINUAL = True
NUM_EVAL = 10
def custom_log_creator(custom_path, custom_str):
    timestr = datetime.datetime.today().strftime("%Y-%m-%d_%H-%M-%S")
    logdir_prefix = "{}_{}".format(custom_str, timestr)

    def logger_creator(config):
        if not os.path.exists(custom_path):
            os.makedirs(custom_path)
        logdir = tempfile.mkdtemp(prefix=logdir_prefix, dir=custom_path)
        return UnifiedLogger(config, logdir, loggers=None)

    return logger_creator

ray.shutdown()
ray.init(ignore_reinit_error=True, log_to_driver=False)

#ModelCatalog.register_custom_model('my_model', MyRNNUAVClass)

eval_env = MyEnv()
policies_own = {
    "blue_0": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
               {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},
               "exploration_config": {"type": "StochasticSampling","random_timesteps":0},"explore":True,}),
    "blue_1": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
               {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},
               "exploration_config": {"type": "StochasticSampling","random_timesteps":0},"explore":True,}),
    "red_0": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
              {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},"explore":False,}),
    "red_1": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
              {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},"explore":False,}),
}
policies_enem = {
    "red_0": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
              {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},"explore":False,}),
    "red_1": (PPOTFPolicy, eval_env.observation_space, eval_env.action_space,
              {"model":{"vf_share_layers": False,"use_lstm": True,"max_seq_len": 200},"explore":False,}),
}
# policy_ids = list(policies.keys())

def policy_mapping_fn(agent_id, episode, **kwargs):
    #print(agent_id,episode)
    #pol_id = policy_ids[agent_id]

    pol_id = agent_id
    return pol_id

# Instanciate the evaluation env
config_own = ppo.DEFAULT_CONFIG.copy()
config_own = {"env": MyEnv,"num_gpus": 1,"num_workers": 0, "num_cpus_per_worker": 0,"num_gpus_per_worker": 1,
          "train_batch_size": 1200*25,
          "batch_mode": "complete_episodes",
          "gamma":0.995, "lr": 2.5e-4,"shuffle_sequences": True,
          "observation_space":eval_env.observation_space,"action_space":eval_env.action_space,
          "sgd_minibatch_size": 600, "num_sgd_iter":20,
          "multiagent": {"policies": policies_own,  "policy_mapping_fn": policy_mapping_fn}
         }
config_enem = ppo.DEFAULT_CONFIG.copy()
config_enem = {"env": MyEnv,"num_gpus": 1,"num_workers": 0, "num_cpus_per_worker": 0,"num_gpus_per_worker": 1,
          "train_batch_size": 600*5*10,
          "batch_mode": "complete_episodes",
          "gamma":0.995, "lr": 2.5e-4,"shuffle_sequences": True,
          "observation_space":eval_env.observation_space,"action_space":eval_env.action_space,
          "sgd_minibatch_size": 600, "num_sgd_iter":20,
          "multiagent": {"policies": policies_enem,  "policy_mapping_fn": policy_mapping_fn}
         }

res_name = "test"
conditions_dir = os.path.join('./' + PROJECT + '/conditions/')

if not os.path.exists(conditions_dir):
    os.makedirs(conditions_dir)
save_conditions(conditions_dir)

# PPOTrainer()は、try_import_tfを使うと、なぜかTensorflowのeager modeのエラーになる。

trainer = ppo.PPOTrainer(config=config_own,
                         logger_creator=custom_log_creator(
                             os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))

adversary = ppo.PPOTrainer(config=config_enem,
                         logger_creator=custom_log_creator(
                             os.path.expanduser("./" + PROJECT + "/logs"), TRIAL))

if CONTINUAL:
    # Continual learning: Need to specify the checkpoint
    # model_path = PROJECT + '/checkpoints/' + TRIAL + '/checkpoint_000197/checkpoint-197'
    model_path = latest_learned_file_path('./UCAV/checkpoints/test_2/*')
    
    #trainer.restore(checkpoint_path=model_path)
    #save_weights("blue_0",trainer)
    #save_weights("blue_1",trainer)

    reload_weights(policy_id="red_0",trainer=trainer,set_policy_id="blue_0")
    reload_weights(policy_id="red_1",trainer=trainer,set_policy_id="blue_1")
    reload_weights(policy_id="blue_0",trainer=trainer,set_policy_id="blue_0")
    reload_weights(policy_id="blue_1",trainer=trainer,set_policy_id="blue_1")
    save_weights("red_0",trainer)
    save_weights("red_1",trainer)


models_dir = os.path.join('./' + PROJECT + '/models/')
if not os.path.exists(models_dir):
    os.makedirs(models_dir)
hist_dir = os.path.join('./' + PROJECT + '/hist/')
if not os.path.exists(hist_dir):
    os.makedirs(hist_dir)
for j in range(2):
    text_name = models_dir + TRIAL + "blue_"+str(j) +'.txt'
    with open(text_name, "w") as fp:
        trainer.get_policy("blue_"+str(j)).model.base_model.summary(print_fn=lambda x: fp.write(x + "\r\n"))
    png_name = models_dir + TRIAL + '.png'
    plot_model(trainer.get_policy("blue_"+str(j)).model.base_model, to_file=png_name, show_shapes=True)



# Define checkpoint dir
check_point_dir = os.path.join('./' + PROJECT + '/checkpoints/', TRIAL)
if not os.path.exists(check_point_dir):
    os.makedirs(check_point_dir)
# Out:
# C:\Users\Takumi\anaconda3\envs\AI2\lib\site-packages\ale_py\roms\utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# C:\Users\Takumi\anaconda3\envs\AI2\lib\site-packages\quaternion\numba_wrapper.py:23: UserWarning:
#
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Could not import from numba, which means that some
# parts of this code may run MUCH more slowly.  You
# may wish to install numba.
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#   warnings.warn(warning_text)
# 2022-04-07 00:49:19,897	INFO trainer.py:2141 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# 2022-04-07 00:49:19,899	INFO ppo.py:250 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# 2022-04-07 00:49:19,899	INFO trainer.py:781 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2022-04-07 00:49:48,779	INFO trainable.py:130 -- Trainable.setup took 28.885 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-04-07 00:49:48,781	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2022-04-07 00:50:01,878	INFO trainable.py:130 -- Trainable.setup took 13.049 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2022-04-07 00:50:01,879	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
eval_env.reset()
save_env_info(eval_env)
record_mode = 0
results_dir = os.path.join('./' + PROJECT + '/results/')

if not os.path.exists(results_dir):
    os.makedirs(results_dir)
results_file = results_dir + TRIAL + '.pkl'

best_reward = {"blue_0":0,"blue_1":0}
for steps in range(10001):
    # Training
    print(f'\n----------------- Training at steps:{steps} start! -----------------')
    eval_env.eval = False
    eval_env.self_play = True
    eval_env.reset()
    results = trainer.train()
    save_logs(res_name,results,steps,CONTINUAL)
    print(pretty_print(results))
    check_point = trainer.save(checkpoint_dir=check_point_dir)
    # Evaluation
    if steps % EVAL_FREQ == 0:
        print(f'\n-------------- Evaluation at steps:{steps} starting ! --------------')
        EVAL_reward = {"blue_0":0,"blue_1":0}
        #check_point = trainer.save(checkpoint_dir=check_point_dir)
        for i in range(NUM_EVAL):
            # print(f'\nEvaluation {i}:')
            #model_path = latest_learned_file_path('./UCAV/checkpoints/test_2/*')
            #trainer.restore(checkpoint_path=model_path)
            eval_env.eval = True
            obs = eval_env.reset()
            done = False
            
            step_num = 0
            #fig = plt.figure(1,figsize=(8.0, 6.0))
            ESC = 0x1B          # ESCキーの仮想キーコード
            trajectory_length = 100

            cell_size = 256
            state_0=[np.zeros(cell_size, np.float32),np.zeros(cell_size, np.float32)]
            state_1=[np.zeros(cell_size, np.float32),np.zeros(cell_size, np.float32)]
            state_2=[np.zeros(cell_size, np.float32),np.zeros(cell_size, np.float32)]
            state_3=[np.zeros(cell_size, np.float32),np.zeros(cell_size, np.float32)]
            action_dict0 = [0,0]
            action_dict1 = [0,0]
            action_dict2 = [0,0]
            action_dict3 = [0,0]
            rewards = {"blue_0":0,"blue_1":0}
            if record_mode == 0:
                file_name = "test_num" + str(steps) +str(i)
                #video = cv2.VideoWriter(file_name+'.mp4',0x00000020,20.0,(800,600))

            while True:
                action_dict = {}
                action_dict0 = trainer.compute_single_action(obs["blue_0"],
                                                             state=state_0,prev_action=None,prev_reward=None,
                                                             policy_id="blue_0",explore=False)
                action_dict1 = trainer.compute_single_action(obs["blue_1"],
                                                             state=state_1,prev_action=None,prev_reward=None,
                                                             policy_id="blue_1",explore=False)
                action_dict2 = trainer.compute_single_action(obs["red_0"],
                                                             state=state_2,prev_action=None,prev_reward=None,
                                                             policy_id="red_0",explore=False)
                action_dict3 = trainer.compute_single_action(obs["red_1"],
                                                             state=state_3,prev_action=None,prev_reward=None,
                                                             policy_id="red_1",explore=False)
                
                #action_dict0 = trainer.compute_single_action(obs["blue_0"],policy_id="blue_0")
                #action_dict1 = trainer.compute_single_action(obs["blue_1"],policy_id="blue_1")
                state_0 = action_dict0[1]
                state_1 = action_dict1[1]
                state_2 = action_dict2[1]
                state_3 = action_dict3[1]
                obs, rewards, dones, infos = eval_env.step({"blue_0": action_dict0[0],
                                                            "blue_1": action_dict1[0],
                                                            "red_0": action_dict2[0],
                                                            "red_1": action_dict3[0],})

                env_blue_pos_temp_mod, env_red_pos_temp_mod, env_mrm_pos_temp_mod = render_env.copy_from_env_mod(eval_env)
                if eval_env.timer == 1:
                    env_blue_pos_mod = env_blue_pos_temp_mod
                    env_red_pos_mod = env_red_pos_temp_mod
                    env_mrm_pos_mod = env_mrm_pos_temp_mod
                else:
                    env_blue_pos_mod = np.vstack([env_blue_pos_mod,env_blue_pos_temp_mod])
                    env_red_pos_mod = np.vstack([env_red_pos_mod,env_red_pos_temp_mod])
                    env_mrm_pos_mod = np.vstack([env_mrm_pos_mod,env_mrm_pos_temp_mod])
                EVAL_reward["blue_0"] += rewards["blue_0"]
                EVAL_reward["blue_1"] += rewards["blue_1"]
                # plt.clf()

                # plt.subplots_adjust(left=-0.1,right=1.1,bottom=-0.1,top=1.1)
                # fig.canvas.draw()
                # plt.pause(.01)

                #if record_mode == 0:
                    #img = np.array(fig.canvas.renderer.buffer_rgba())
                    #img = cv2.cvtColor(img, cv2.COLOR_RGBA2BGR)
                    #video.write(img.astype('uint8'))

                
                step_num = step_num + 1
                
                done = dones["__all__"]
                
                #print(f'rewards:{rewards}')
                #if record_mode == 0:
                #    img = eval_env.render_movie(file_name,step_num)
                #    video.write(img.astype('unit8'))
                #elif record_mode == 1:
                #    eval_env.render()
                #elif record_mode == 2:
                #    eval_env.render()
                    
                #env_blue_pos_temp, env_red_pos_temp, env_mrm_pos_temp = render_env.copy_from_env(eval_env)
                
                #env_blue_pos.append(env_blue_pos_temp)
                #env_red_pos.append(env_red_pos_temp)
                #env_mrm_pos.append(env_mrm_pos_temp)
                #step_num = step_num + 1
                # エピソードの終了処理
                if dones['__all__']:
                    save_hists("blue_"+str(i),steps,env_blue_pos_mod,hist_dir)
                    save_hists("red_"+str(i),steps,env_red_pos_mod,hist_dir)
                    save_hists("mrm_"+str(i),steps,env_mrm_pos_mod,hist_dir)
                    # print(f'all done at {env.steps}')
                    break
            if EVAL_reward["blue_0"]> best_reward["blue_0"]:
                save_weights("blue_0",trainer)
                reload_weights(policy_id="red_0",trainer=trainer,set_policy_id="blue_0")
                best_reward["blue_0"] = EVAL_reward["blue_0"]
            if EVAL_reward["blue_1"]> best_reward["blue_1"]:
                save_weights("blue_1",trainer)
                reload_weights(policy_id="red_1",trainer=trainer,set_policy_id="blue_1")
                best_reward["blue_1"] = EVAL_reward["blue_1"]

            
            #if record_mode == 0:
               # video.release()

ray.shutdown()
# Out:
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
#
# ----------------- Training at steps:0 start! -----------------
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 139 blue_1 DOWN
# 993 red_0 Shoot at blue_0
# 1004 red_0 Shoot at blue_0
# 1009 red_1 Shoot at blue_0
# 1020 red_1 Shoot at blue_0
# 1063 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1063 -0.137729876277264 -50.49046887302631
# blue_1 False False 1063 -0.10099940961059735 -1.2030305315428063
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 96 blue_0 DOWN
# 123 blue_1 DOWN
# TIME LIMIT LOSE
# blue_0 False False 123 -0.10100182800254708 -1.4057956680719084
# blue_1 False False 123 -1.1009973613358803 -1.3046351003204857
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 286 blue_1 Shoot at red_1 launch distance : 59727.15648536425 True True
# 297 blue_1 Shoot at red_1 launch distance : 54594.60364631783 True True
# 339 red_0 Shoot at blue_1
# 350 red_0 Shoot at blue_1
# 399 blue_1 Splash :red_1
# 412 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9929996379714597 14.356988511926877
# blue_1 False False 1200 0.8989996379714598 112.88882627717628
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 295 blue_0 Shoot at red_0 launch distance : 59801.52575984328 True True
# 309 blue_1 Shoot at red_0 launch distance : 59341.84991543574 True True
# 313 blue_0 Shoot at red_0 launch distance : 52758.544150046364 True True
# 325 blue_1 Shoot at red_0 launch distance : 51475.203212861314 True True
# 360 red_1 Shoot at blue_0
# 371 red_1 Shoot at blue_0
# 422 blue_0 Splash :red_0
# 435 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.899 108.60201082194611
# blue_1 False False 1200 0.893 79.7592437333334
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 508 blue_0 DOWN
# 839 blue_1 Shoot at red_1 launch distance : 59596.25822906521 True True
# Same tgt shoot
# 851 blue_1 Shoot at red_0 launch distance : 56422.073313803645 True True
# 953 blue_1 Splash :red_1
# 958 blue_1 Splash :red_0
# WIN
# blue_0 False True 958 11.153202673255077 8.451916089046543
# blue_1 False True 958 24.258425013268997 123.50148197402925
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 318 blue_1 Shoot at red_0 launch distance : 52905.67234460929 True True
# Same tgt shoot
# 330 blue_1 Shoot at red_1 launch distance : 50406.79599678892 True True
# 419 blue_1 Splash :red_0
# 426 blue_1 Splash :red_1
# WIN
# blue_0 False True 426 12.817252299018369 17.280565908450704
# blue_1 False True 426 28.95105211591978 153.3388707530371
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 280 blue_0 Shoot at red_1 launch distance : 59074.86978097165 True True
# Same tgt shoot
# 292 blue_0 Shoot at red_0 launch distance : 54980.28160010144 True True
# Same tgt shoot
# 378 blue_1 Shoot at red_0 launch distance : 59989.55188520629 True True
# 393 blue_0 Splash :red_1
# Same tgt shoot
# 395 blue_1 Shoot at red_0 launch distance : 58130.75458316245 True True
# 399 blue_0 Splash :red_0
# WIN
# blue_0 False True 595 12.015806722689076 155.98295721234754
# blue_1 False True 595 12.015806722689076 54.11604928935598
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 403 blue_1 Shoot at red_0 launch distance : 50200.67634603811 True True
# Same tgt shoot
# 414 blue_1 Shoot at red_1 launch distance : 53574.54451908606 True True
# 424 red_0 Shoot at blue_1
# 441 red_1 Shoot at blue_1
# 498 blue_1 Splash :red_0
# 517 blue_1 Splash :red_1
# WIN
# blue_0 False True 641 11.871075582995319 55.68073104966196
# blue_1 False True 641 11.87107488299532 136.73376666905602
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 277 blue_1 Shoot at red_0 launch distance : 59077.27020793859 True True
# 288 blue_1 Shoot at red_0 launch distance : 53314.23421758523 True True
# 331 red_1 Shoot at blue_1
# 342 red_1 Shoot at blue_1
# 391 blue_1 Splash :red_0
# 406 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9929991700864109 -17.60418167831941
# blue_1 False False 1200 0.898999170086411 104.5109271106207
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 79 blue_1 DOWN
# 939 red_0 Shoot at blue_0
# 950 red_0 Shoot at blue_0
# 961 red_1 Shoot at blue_0
# 972 red_1 Shoot at blue_0
# 1016 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1016 -0.13853390900263374 -52.05527328592033
# blue_1 False False 1016 -0.10099974233596708 -1.3048010207039955
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 314 blue_1 Shoot at red_0 launch distance : 59930.76796206055 True True
# Same tgt shoot
# 326 blue_1 Shoot at red_1 launch distance : 57181.544385145324 True True
# 379 blue_0 DOWN
# 434 blue_1 Splash :red_0
# 435 blue_1 Splash :red_1
# WIN
# blue_0 False True 435 12.658974737790976 8.499091731469537
# blue_1 False True 435 28.77621611710132 134.4170623860162
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 285 blue_1 Shoot at red_1 launch distance : 59484.51912978782 True True
# 296 blue_1 Shoot at red_1 launch distance : 53591.43545400373 True True
# 324 red_0 Shoot at blue_1
# 335 red_0 Shoot at blue_1
# 395 blue_1: Destroyed
# 399 blue_1 Splash :red_1
# TIME LIMIT LOSE
# blue_0 False False 1200 0.993008020903011 27.347433183554394
# blue_1 False False 1200 0.899000820903011 115.81351100514308
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 92 blue_1 DOWN
# 176 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 176 -1.1010057279286247 -1.4053006856698596
# blue_1 False False 176 -0.10100116126195804 -1.4055783249659748
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 272 blue_1 Shoot at red_0 launch distance : 58043.394565228766 True True
# 286 blue_1 Shoot at red_0 launch distance : 50964.9637598185 True True
# 326 red_1 Shoot at blue_1
# 337 red_1 Shoot at blue_1
# 383 blue_1 Splash :red_0
# 399 blue_1: Destroyed
# 646 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 646 -0.10299999999999998 -4.137256017958917
# blue_1 False False 646 0.899 113.70213928725352
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 448 blue_1 DOWN
# 892 red_0 Shoot at blue_0
# 896 red_1 Shoot at blue_0
# 903 red_0 Shoot at blue_0
# 907 red_1 Shoot at blue_0
# 956 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 956 -0.14035539926209917 -27.81297584437308
# blue_1 False False 956 -0.10099916592876584 -13.91186228490049
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 169 blue_0 DOWN
# 286 blue_1 Shoot at red_1 launch distance : 59941.69851106115 True True
# Same tgt shoot
# 297 blue_1 Shoot at red_0 launch distance : 53341.94656222876 True True
# 397 blue_1 Splash :red_0
# 402 blue_1 Splash :red_1
# WIN
# blue_0 False True 402 12.885403091251595 11.682153073743095
# blue_1 False True 402 28.855552344982936 150.33780873097484
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 215 blue_1 DOWN
# 1072 red_0 Shoot at blue_0
# 1083 red_0 Shoot at blue_0
# 1096 red_1 Shoot at blue_0
# 1107 red_1 Shoot at blue_0
# 1125 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1125 -0.13639441030852797 -58.83956388873293
# blue_1 False False 1125 -0.10100097697519465 -1.3043427350525587
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 277 blue_1 Shoot at red_0 launch distance : 59292.33830607836 True True
# 288 blue_1 Shoot at red_0 launch distance : 53939.606659184756 True True
# 333 red_1 Shoot at blue_1
# 344 red_1 Shoot at blue_1
# 393 blue_1 Splash :red_0
# 404 blue_1: Destroyed
# 825 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 825 -0.10300485759588418 -12.524581385348707
# blue_1 False False 825 0.8989993090707824 121.17268944692542
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 290 blue_1 Shoot at red_0 launch distance : 53682.41571190321 True True
# 305 blue_1 Shoot at red_0 launch distance : 46659.311941779975 True True
# 328 red_1 Shoot at blue_1
# 339 red_1 Shoot at blue_1
# 392 blue_1 Splash :red_0
# 400 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.993000472360834 -11.138948776747547
# blue_1 False False 1200 0.899000472360834 90.95126088928829
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 185 blue_1 DOWN
# 414 blue_0 Shoot at red_0 launch distance : 44960.61263018628 True True
# 425 blue_0 Shoot at red_0 launch distance : 40455.187023963896 True True
# 427 red_0 Shoot at blue_0
# 434 red_1 Shoot at blue_0
# 445 red_1 Shoot at blue_0
# 484 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 484 0.3588204940250301 43.00815131946612
# blue_1 False False 484 0.39900016069169675 -0.905380272519991
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 131 blue_1 DOWN
# 179 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 179 -1.1009996117935394 -1.4069083269638716
# blue_1 False False 179 -0.10100157846020608 -1.405085604472964
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 380 blue_1 Shoot at red_0 launch distance : 56732.80184927141 True True
# Same tgt shoot
# 393 blue_1 Shoot at red_1 launch distance : 57299.26611690664 True True
# 492 blue_1 Splash :red_0
# 505 blue_1 Splash :red_1
# WIN
# blue_0 False True 505 12.276636575677514 4.302743757095702
# blue_1 False True 505 27.630115123202266 156.74100678510825
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 133 blue_1 DOWN
# 912 red_1 Shoot at blue_0
# 921 red_0 Shoot at blue_0
# 923 red_1 Shoot at blue_0
# 932 red_0 Shoot at blue_0
# 984 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 984 -0.13841692704837136 -33.23126409186163
# blue_1 False False 984 -0.10100009371503804 -1.2031696655891757
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 121 blue_1 DOWN
# 1003 red_1 Shoot at blue_0
# 1009 red_0 Shoot at blue_0
# 1014 red_1 Shoot at blue_0
# 1020 red_0 Shoot at blue_0
# 1075 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1075 -0.13728711703700394 -50.74147889924644
# blue_1 False False 1075 -0.10100028370367062 -1.305232438301193
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 324 blue_1 Shoot at red_0 launch distance : 56949.50413741508 True True
# 336 blue_1 Shoot at red_0 launch distance : 50835.5873576037 True True
# 370 red_1 Shoot at blue_1
# 381 red_1 Shoot at blue_1
# 435 blue_1 Splash :red_0
# 439 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9930004741144409 -18.30327409814709
# blue_1 False False 1200 0.8990004741144408 109.24103543271075
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 133 blue_0 DOWN
# 315 blue_1 Shoot at red_0 launch distance : 58993.86534144018 True True
# 330 blue_1 Shoot at red_0 launch distance : 51704.580952353164 True True
# 349 red_1 Shoot at blue_1
# 360 red_1 Shoot at blue_1
# 421 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 421 -0.1009997492251125 -1.2031381266377468
# blue_1 False False 421 0.35889045077488746 88.76529298573973
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 306 blue_0 Shoot at red_0 launch distance : 58039.21640351014 True True
# 319 blue_0 Shoot at red_0 launch distance : 51763.02715811215 True True
# 369 red_1 Shoot at blue_0
# 380 red_1 Shoot at blue_0
# 420 blue_0 Splash :red_0
# 425 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8990001964942024 98.91510794348368
# blue_1 False False 1200 0.8930001964942024 -6.941758008995647
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 95 blue_1 DOWN
# 292 blue_0 Shoot at red_1 launch distance : 57420.85400284257 True True
# 303 blue_0 Shoot at red_1 launch distance : 52638.91621575127 True True
# 342 red_0 Shoot at blue_0
# 353 red_0 Shoot at blue_0
# 406 blue_0 Splash :red_1
# 416 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 416 0.8586228589430728 121.46174914895249
# blue_1 False False 416 0.8989996256097395 -0.3050196042904767
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 280 blue_1 Shoot at red_0 launch distance : 59671.51483814746 True True
# 295 blue_1 Shoot at red_0 launch distance : 52761.42888645637 True True
# 379 red_1 Shoot at blue_1
# 390 red_1 Shoot at blue_1
# 396 blue_1 Splash :red_0
# 448 blue_0 DOWN
# 457 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 457 0.8989998074475184 -8.039456757836009
# blue_1 False False 457 0.8586353407808518 82.68205050353826
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 289 blue_1 Shoot at red_0 launch distance : 58857.57032121238 True True
# 300 blue_1 Shoot at red_0 launch distance : 54174.03002483433 True True
# 315 blue_0 Shoot at red_0 launch distance : 53230.49430791068 True True
# 355 red_1 Shoot at blue_1
# 366 red_1 Shoot at blue_1
# 406 blue_1 Splash :red_0
# 428 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9939995991934333 57.41493187135638
# blue_1 False False 1200 0.8989995991934333 87.19214076258699
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 160 blue_0 DOWN
# 287 blue_1 Shoot at red_0 launch distance : 58515.79836001424 True True
# 299 blue_1 Shoot at red_0 launch distance : 52252.87871330686 True True
# 323 red_1 Shoot at blue_1
# 334 red_1 Shoot at blue_1
# 388 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 388 -0.10099989022293851 -1.2036646903835808
# blue_1 False False 388 0.35867057644372813 83.5051344706254
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 296 blue_0 Shoot at red_1 launch distance : 59553.0030224472 True True
# Same tgt shoot
# 306 blue_1 Shoot at red_0 launch distance : 59285.853108421274 True True
# Same tgt shoot
# 309 blue_0 Shoot at red_1 launch distance : 54093.032920847756 True True
# 363 red_0 Shoot at blue_1
# 374 red_0 Shoot at blue_1
# 402 blue_0 Splash :red_1
# 429 blue_1: Destroyed
# 576 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 576 -0.10699919220059528 107.49299213170596
# blue_1 False False 576 0.8990008077994047 48.113791136792244
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 343 blue_0 Shoot at red_0 launch distance : 59579.649812407515 True True
# Same tgt shoot
# 354 blue_0 Shoot at red_1 launch distance : 58093.22889749826 True True
# 461 blue_0 Splash :red_0
# 467 blue_0 Splash :red_1
# WIN
# blue_0 False True 467 28.210153018420137 108.13810146263299
# blue_1 False True 467 12.56997198958359 10.885503347751607
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 177 blue_1 DOWN
# 277 blue_0 Shoot at red_1 launch distance : 54336.73819988337 True True
# 288 blue_0 Shoot at red_1 launch distance : 48623.47034421416 True True
# 323 red_0 Shoot at blue_0
# 334 red_0 Shoot at blue_0
# 379 blue_0 Splash :red_1
# 391 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 391 0.8587330692789887 115.04998220713618
# blue_1 False False 391 0.8989993692789887 -0.3046208896476451
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 288 blue_1 Shoot at red_0 launch distance : 59088.229531862286 True True
# 304 blue_1 Shoot at red_0 launch distance : 51148.603255816655 True True
# 338 red_1 Shoot at blue_1
# 349 red_1 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 369 blue_0 Shoot at red_1 launch distance : 58333.02514049947 True True
# Same tgt shoot
# Same tgt shoot
# 384 blue_0 Shoot at red_1 launch distance : 55368.51560280462 True True
# 403 blue_1 Splash :red_0
# 408 blue_1: Destroyed
# 505 blue_0 Splash :red_1
# WIN
# blue_0 False True 584 12.053794520547946 129.5555129014057
# blue_1 False True 584 11.953794520547945 114.7259461916102
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 126 blue_0 DOWN
# 297 blue_1 Shoot at red_1 launch distance : 56616.92090521874 True True
# 309 blue_1 Shoot at red_1 launch distance : 50797.17278146499 True True
# 348 red_0 Shoot at blue_1
# 359 red_0 Shoot at blue_1
# 406 blue_1 Splash :red_1
# 423 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 423 0.8989997649525017 -0.3045518804647893
# blue_1 False False 423 0.8586065649525016 99.30973207282234
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 280 blue_1 Shoot at red_0 launch distance : 57497.70338119703 True True
# Same tgt shoot
# 291 blue_1 Shoot at red_1 launch distance : 59844.33021504889 True True
# 392 blue_1 Splash :red_0
# 408 blue_1 Splash :red_1
# WIN
# blue_0 False True 408 12.941493705785525 0.5298600372548972
# blue_1 False True 408 29.323842513628662 140.41222012468984
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 268 blue_0 Shoot at red_1 launch distance : 59689.412533697054 True True
# 284 blue_0 Shoot at red_1 launch distance : 51379.49797992827 True True
# 324 red_0 Shoot at blue_0
# 335 red_0 Shoot at blue_0
# 381 blue_0 Splash :red_1
# 391 blue_0: Destroyed
# Same tgt shoot
# Same tgt shoot
# 450 blue_1 Shoot at red_0 launch distance : 59704.529329498786 True True
# Same tgt shoot
# Same tgt shoot
# 461 blue_1 Shoot at red_0 launch distance : 55376.191618315155 True True
# 578 blue_1 Splash :red_0
# WIN
# blue_0 False True 661 11.714431164901663 126.05644481007481
# blue_1 False True 661 11.814431164901665 78.93192669984954
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 176 blue_1 DOWN
# 1016 red_1 Shoot at blue_0
# 1027 red_1 Shoot at blue_0
# 1028 red_0 Shoot at blue_0
# 1039 red_0 Shoot at blue_0
# 1078 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1078 -0.13600160815359688 -45.217578713251065
# blue_1 False False 1078 -0.10100160815359688 -1.5065848740637904
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 296 blue_0 Shoot at red_0 launch distance : 58459.899106763914 True True
# 309 blue_1 Shoot at red_0 launch distance : 59546.936473942995 True True
# Same tgt shoot
# Same tgt shoot
# 316 blue_0 Shoot at red_1 launch distance : 58342.970247944286 True True
# Same tgt shoot
# 320 blue_1 Shoot at red_0 launch distance : 55016.651161588 True True
# 409 blue_0 Splash :red_0
# 421 blue_0 Splash :red_1
# WIN
# blue_0 False True 520 12.307692307692307 152.21962419024572
# blue_1 False True 520 12.306692307692307 74.72793780769237
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 255 blue_0 DOWN
# 835 red_0 Shoot at blue_1
# 840 red_1 Shoot at blue_1
# 846 red_0 Shoot at blue_1
# 851 red_1 Shoot at blue_1
# 906 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 906 -0.1009990749171531 -3.361523242114365
# blue_1 False False 906 -0.14145097491715308 -23.831220822531648
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 412 red_1 Shoot at blue_0
# 414 red_0 Shoot at blue_0
# 423 red_1 Shoot at blue_0
# 425 red_0 Shoot at blue_0
# 490 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.10099937807204111 2.7352931267571376
# blue_1 False False 1200 -0.1129993780720411 -38.07282039307864
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2022-04-07 01:55:16,066	WARNING ppo.py:127 -- No data for red_1, not updating kl
# 2022-04-07 01:55:16,067	WARNING ppo.py:127 -- No data for red_0, not updating kl
# 2022-04-07 01:55:16,220	WARNING deprecation.py:46 -- DeprecationWarning: `clear_buffer` has been deprecated. Use `Filter.reset_buffer()` instead. This will raise an error in the future!
# agent_timesteps_total: 62220
# custom_metrics: {}
# date: 2022-04-07_01-55-16
# done: false
# episode_len_mean: 740.7142857142857
# episode_media: {}
# episode_reward_max: 244.28145909301588
# episode_reward_mean: 86.77617549669972
# episode_reward_min: -60.143906623785504
# episodes_this_iter: 42
# episodes_total: 42
# experiment_id: 67406e9c973b4678a42dadfef6f1ea34
# hostname: DESKTOP
# info:
#   learner:
#     blue_0:
#       learner_stats:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0002500000118743628
#         entropy: 6.898582935333252
#         entropy_coeff: 0.0
#         kl: 0.11648424714803696
#         model: {}
#         policy_loss: 0.06078886240720749
#         total_loss: 84.18666076660156
#         vf_explained_var: -0.09636684507131577
#         vf_loss: 84.10257720947266
#       train: null
#     blue_1:
#       learner_stats:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0002500000118743628
#         entropy: 7.145285129547119
#         entropy_coeff: 0.0
#         kl: 0.07833901047706604
#         model: {}
#         policy_loss: 0.002647959627211094
#         total_loss: 74.64491271972656
#         vf_explained_var: 0.08529922366142273
#         vf_loss: 74.62660217285156
#       train: null
#   num_agent_steps_sampled: 62220
#   num_agent_steps_trained: 62220
#   num_steps_sampled: 31110
#   num_steps_trained: 31110
#   num_steps_trained_this_iter: 31110
# iterations_since_restore: 1
# node_ip: 127.0.0.1
# num_healthy_workers: 0
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 43.04221540681941
#   ram_util_percent: 40.48037163990619
# pid: 22064
# policy_reward_max:
#   blue_0: 155.98295721234754
#   blue_1: 156.74100678510825
# policy_reward_mean:
#   blue_0: 25.57945613234855
#   blue_1: 61.19671936435121
# policy_reward_min:
#   blue_0: -58.83956388873293
#   blue_1: -38.07282039307864
# sampler_perf:
#   mean_action_processing_ms: 0.5623801672402322
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 65.61798253294963
#   mean_inference_ms: 18.485702646337707
#   mean_raw_obs_processing_ms: 5.897838528094744
# time_since_restore: 3906.470045566559
# time_this_iter_s: 3906.470045566559
# time_total_s: 3906.470045566559
# timers:
#   learn_throughput: 28.595
#   learn_time_ms: 1087961.57
#   load_throughput: 64850.894
#   load_time_ms: 479.716
#   sample_throughput: 10.959
#   sample_time_ms: 2838733.95
# timestamp: 1649264116
# timesteps_since_restore: 31110
# timesteps_this_iter: 31110
# timesteps_total: 31110
# training_iteration: 1
# trial_id: default
#
#
# -------------- Evaluation at steps:0 starting ! --------------
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.0009908937560995275 -2.888487760496629
# blue_1 False False 1200 -0.10099929375609953 -22.112681227163286
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 888 blue_1 Shoot at red_1 launch distance : 40742.691216846986 True True
# 1148 blue_0 Shoot at red_1 launch distance : 46828.26432497022 True True
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.1070030383855412 2.246072020516468
# blue_1 False False 1200 -0.0009902383855411956 137.97697838718327
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.10099723401844021 -71.17738438006577
# blue_1 False False 1200 -0.10100156735177354 -27.694035180065825
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 71 blue_1 DOWN
# 379 blue_0 Shoot at red_0 launch distance : 56841.85368549953 True True
# 397 blue_0 Shoot at red_0 launch distance : 47493.531768928326 True True
# 476 blue_0 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 0.999 81.32125824005445
# blue_1 False False 1200 0.899 -0.5074282312932241
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 376 blue_1 Shoot at red_0 launch distance : 53200.24133295776 True True
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.10099207198708059 -17.89001367247862
# blue_1 False False 1200 -0.10099993865374725 92.79291126085481
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.10099692365725096 -27.87923500232842
# blue_1 False False 1200 -0.10100002365725097 -31.718341368995056
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 871 blue_0 Shoot at red_1 launch distance : 26260.177862383785 True True
# 893 red_1 Shoot at blue_0
# 904 red_1 Shoot at blue_0
# TIME LIMIT LOSE
# blue_0 False False 1200 -1.2212982909566684e-06 120.85480733792929
# blue_1 False False 1200 -0.10100122129829096 89.41580570459597
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 902 red_0 Shoot at blue_1
# 971 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.0009917544488521903 -0.8487423827845414
# blue_1 False False 1200 -0.10100085444885219 16.932595808451282
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 388 red_1 Shoot at blue_1
# 409 red_1 Shoot at blue_1
# 1112 blue_1 Shoot at red_1 launch distance : 51885.34778770104 True True
# 1172 blue_1 Splash :red_1
# Same tgt shoot
# 1181 blue_1 Shoot at red_0 launch distance : 59960.462712204324 True True
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9989931225182649 0.1611950832983513
# blue_1 False False 1200 0.9989991891849316 105.74951501993083
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 568 blue_1 Shoot at red_0 launch distance : 59930.7657140621 True True
# 579 blue_1 Shoot at red_0 launch distance : 58505.68279056525 True True
# 693 blue_1 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9990081062494456 -52.85724184276779
# blue_1 False False 1200 0.9990006729161123 98.62936658710247
#
# ----------------- Training at steps:1 start! -----------------
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 305 blue_1 Shoot at red_0 launch distance : 55315.67041097086 True True
# Same tgt shoot
# 318 blue_1 Shoot at red_1 launch distance : 53650.20902410112 True True
# 417 blue_1 Splash :red_0
# 426 blue_1 Splash :red_1
# WIN
# blue_0 False True 426 12.817231606552474 6.5281118751173635
# blue_1 False True 426 28.951043023453884 154.05134367547203
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 307 blue_1 Shoot at red_0 launch distance : 56881.40815885312 True True
# 320 blue_1 Shoot at red_0 launch distance : 50377.153193538914 True True
# 340 red_1 Shoot at blue_1
# 351 red_1 Shoot at blue_1
# 410 blue_1: Destroyed
# 417 blue_1 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9930069630530253 -45.504421661515394
# blue_1 False False 1200 0.8990006630530253 112.01683632533211
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 303 blue_1 Shoot at red_1 launch distance : 59427.5009538593 True True
# Same tgt shoot
# 316 blue_1 Shoot at red_0 launch distance : 58140.141739520775 True True
# 415 blue_1 Splash :red_1
# 428 blue_1 Splash :red_0
# WIN
# blue_0 False True 428 12.804086694288754 12.278733184423675
# blue_1 False True 428 28.911564329802772 146.7465957833915
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 289 blue_1 Shoot at red_1 launch distance : 57798.90334783686 True True
# 305 blue_1 Shoot at red_1 launch distance : 50123.46433540576 True True
# 341 red_0 Shoot at blue_1
# 352 red_0 Shoot at blue_1
# 400 blue_1 Splash :red_1
# 407 blue_1: Destroyed
# Same tgt shoot
# Same tgt shoot
# 719 blue_0 Shoot at red_0 launch distance : 36859.775174005204 True True
# Same tgt shoot
# Same tgt shoot
# 732 blue_0 Shoot at red_0 launch distance : 31933.0040788304 True True
# 787 blue_0 Splash :red_0
# WIN
# blue_0 False True 932 11.286560381402003 89.06324015459144
# blue_1 False True 932 11.186553648068669 133.31934006690602
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 304 blue_1 Shoot at red_0 launch distance : 59788.17698293599 True True
# Same tgt shoot
# 316 blue_1 Shoot at red_1 launch distance : 49467.170971636646 True True
# 335 red_1 Shoot at blue_1
# 406 blue_1 Splash :red_1
# 422 blue_1 Splash :red_0
# WIN
# blue_0 False True 535 12.241990654205608 4.581237954205603
# blue_1 False True 535 12.241990654205608 148.4987659616022
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 954 red_1 Shoot at blue_0
# 962 red_0 Shoot at blue_0
# 965 red_1 Shoot at blue_0
# 973 red_0 Shoot at blue_0
# 1033 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.10100030717003096 -36.322247017143205
# blue_1 False False 1200 -0.10100030717003096 -69.648406027503
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 268 blue_0 Shoot at red_1 launch distance : 59266.68907229707 True True
# 280 blue_0 Shoot at red_1 launch distance : 53060.43281346498 True True
# 323 red_0 Shoot at blue_0
# 334 red_0 Shoot at blue_0
# 381 blue_0 Splash :red_1
# 393 blue_0: Destroyed
# 981 blue_1 DOWN
# TIME LIMIT LOSE
# blue_0 False False 981 0.8990007591684332 118.09301293360231
# blue_1 False False 981 -0.10699924083156676 -11.08109655083346
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 283 blue_1 Shoot at red_1 launch distance : 58260.56943170712 True True
# 295 blue_0 Shoot at red_1 launch distance : 53428.002857048195 True True
# Same tgt shoot
# Same tgt shoot
# 306 blue_0 Shoot at red_0 launch distance : 56811.08060238863 True True
# Same tgt shoot
# 319 blue_1 Shoot at red_1 launch distance : 44923.981672155904 True True
# 397 blue_0 Splash :red_1
# 417 blue_0 Splash :red_0
# WIN
# blue_0 False True 519 12.3121387283237 147.80512046215452
# blue_1 False True 519 12.211138728323698 81.27538789499026
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 285 blue_0 Shoot at red_1 launch distance : 59617.90432358757 True True
# 296 blue_0 Shoot at red_1 launch distance : 53753.234864401515 True True
# 339 red_0 Shoot at blue_0
# 350 red_0 Shoot at blue_0
# 398 blue_0 Splash :red_1
# 410 blue_0: Destroyed
# 604 blue_1 DOWN
# TIME LIMIT LOSE
# blue_0 False False 604 0.899000133448405 119.74792832587055
# blue_1 False False 604 -0.10299986655159499 -5.486240588168581
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 396 red_0 Shoot at blue_1
# 407 red_0 Shoot at blue_1
# 430 red_1 Shoot at blue_1
# 441 red_1 Shoot at blue_1
# 480 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.11299728919269517 -41.103421588701075
# blue_1 False False 1200 -0.10100055585936184 -8.513673076727244
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 335 blue_1 Shoot at red_1 launch distance : 59763.266915745284 True True
# 403 red_0 Shoot at blue_1
# 414 red_0 Shoot at blue_1
# 428 red_1 Shoot at blue_1
# 439 red_1 Shoot at blue_1
# 489 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.012998655615247566 -33.77918852010308
# blue_1 False False 1200 -0.1010006889485809 -8.878691680933372
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 302 blue_0 Shoot at red_0 launch distance : 58899.65838259681 True True
# 322 blue_1 Shoot at red_0 launch distance : 57803.23978913489 True True
# Same tgt shoot
# Same tgt shoot
# 337 blue_1 Shoot at red_1 launch distance : 53737.187925427395 True True
# Same tgt shoot
# 399 blue_0 Shoot at red_0 launch distance : 58275.282275588484 True True
# 415 blue_0 Splash :red_0
# 427 blue_1 Splash :red_1
# 585 blue_0 DOWN
# WIN
# blue_0 False True 599 11.902338898163604 95.39671986161709
# blue_1 False True 599 12.002337498163605 134.52191789746092
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 126 blue_1 DOWN
# 196 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 196 -1.1009944682722437 -1.2030713244534372
# blue_1 False False 196 -0.10100046827224367 -1.3051130965820228
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 126 blue_1 DOWN
# 289 blue_0 Shoot at red_0 launch distance : 56115.79893793506 True True
# 300 blue_0 Shoot at red_0 launch distance : 50311.86457639822 True True
# 332 red_1 Shoot at blue_0
# 343 red_1 Shoot at blue_0
# 396 blue_0 Splash :red_0
# 398 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 398 0.8586380426153593 120.63104983829444
# blue_1 False False 398 0.8989992426153592 -0.3046950003561555
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 283 blue_1 Shoot at red_0 launch distance : 58502.27377001983 True True
# 295 blue_1 Shoot at red_0 launch distance : 52920.46110604693 True True
# 329 red_1 Shoot at blue_1
# 340 red_1 Shoot at blue_1
# 402 blue_1: Destroyed
# 403 blue_1 Splash :red_0
# Same tgt shoot
# Same tgt shoot
# 696 blue_0 Shoot at red_1 launch distance : 59124.717923084216 True True
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9930009154229498 -14.139840472334983
# blue_1 False False 1200 0.8990002820896164 122.54782638743039
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 354 blue_0 Shoot at red_0 launch distance : 50607.31378020869 True True
# Same tgt shoot
# 375 blue_1 Shoot at red_1 launch distance : 59213.7199178015 True True
# 412 red_1 Shoot at blue_0
# 423 red_1 Shoot at blue_0
# 462 blue_0 Splash :red_0
# 506 blue_0: Destroyed
# Same tgt shoot
# 626 blue_1 Shoot at red_1 launch distance : 56697.09699136732 True True
# 734 blue_1 Splash :red_1
# WIN
# blue_0 False True 734 12.035342190381773 85.24992776696166
# blue_1 False True 734 24.905096958774145 152.74687791925518
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 133 blue_1 DOWN
# 250 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 250 -1.1010095685957353 -1.483335641692212
# blue_1 False False 250 -0.10100163526240197 -1.404918295017676
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 280 blue_0 Shoot at red_1 launch distance : 59893.32681708337 True True
# 292 blue_0 Shoot at red_1 launch distance : 54352.2640248587 True True
# 305 blue_1 Shoot at red_1 launch distance : 54772.53205078031 True True
# Same tgt shoot
# Same tgt shoot
# Same tgt shoot
# 317 blue_1 Shoot at red_0 launch distance : 50745.819616471425 True True
# 325 red_0 Shoot at blue_0
# 336 red_0 Shoot at blue_0
# 399 blue_0 Splash :red_1
# 413 blue_1 Splash :red_0
# WIN
# blue_0 False True 536 12.137805970149254 148.59709056413382
# blue_1 False True 536 12.237805970149255 123.7331900513434
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 109 blue_1 DOWN
# 173 blue_0 DOWN
# TIME LIMIT LOSE
# blue_0 False False 173 -1.1009984021710888 -1.4054858237128787
# blue_1 False False 173 -0.10100120217108881 -1.305399932829955
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 251 blue_0 DOWN
# 1067 red_1 Shoot at blue_1
# 1078 red_1 Shoot at blue_1
# 1103 red_0 Shoot at blue_1
# 1114 red_0 Shoot at blue_1
# 1123 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1123 -0.10100101773654405 -1.4050198546481514
# blue_1 False False 1123 -0.13600101773654405 -65.26159643048679
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 341 blue_1 Shoot at red_1 launch distance : 53567.73414309426 True True
# Same tgt shoot
# 354 blue_1 Shoot at red_0 launch distance : 59035.95718638284 True True
# 447 blue_1 Splash :red_1
# 474 blue_1 Splash :red_0
# WIN
# blue_0 False True 474 12.532032394934804 1.5668264029535788
# blue_1 False True 474 28.095323400841977 152.54331239230595
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 273 blue_0 Shoot at red_1 launch distance : 59101.79207253676 True True
# Same tgt shoot
# 286 blue_0 Shoot at red_0 launch distance : 57573.107726197406 True True
# 386 blue_0 Splash :red_1
# 396 blue_0 Splash :red_0
# WIN
# blue_0 False True 396 29.591240627839234 128.95376983788665
# blue_1 False True 396 13.030639533899839 6.6832290303030355
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 141 blue_0 DOWN
# 179 blue_1 DOWN
# TIME LIMIT LOSE
# blue_0 False False 179 -0.10100147495594934 -1.2031828797017587
# blue_1 False False 179 -1.1009976082892827 -1.405213558096547
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 292 blue_0 Shoot at red_1 launch distance : 59544.80035147343 True True
# 308 blue_0 Shoot at red_1 launch distance : 52028.79636641363 True True
# 347 red_0 Shoot at blue_0
# 358 red_0 Shoot at blue_0
# 408 blue_0 Splash :red_1
# 418 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8989988265545004 127.91213570963292
# blue_1 False False 1200 0.8929988265545004 -68.71468562624388
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 87 blue_1 DOWN
# 483 red_1 Shoot at blue_0
# 494 red_1 Shoot at blue_0
# 504 red_0 Shoot at blue_0
# 515 red_0 Shoot at blue_0
# 580 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 580 -0.14030328691919058 5.185181294572848
# blue_1 False False 580 -0.10100052025252393 -1.4053084811114485
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 305 blue_0 Shoot at red_1 launch distance : 59019.35025470783 True True
# 316 blue_0 Shoot at red_1 launch distance : 54078.573792764204 True True
# 354 red_0 Shoot at blue_0
# 362 blue_1 Shoot at red_1 launch distance : 59474.095439640994 True True
# 365 red_0 Shoot at blue_0
# 375 blue_1 Shoot at red_1 launch distance : 57301.730395426246 True True
# 420 blue_0 Splash :red_1
# 427 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.8989993269055032 114.55207553677229
# blue_1 False False 1200 0.8929993269055032 63.84791771329975
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 49 blue_0 DOWN
# 307 blue_1 Shoot at red_0 launch distance : 57313.379480714495 True True
# Same tgt shoot
# 320 blue_1 Shoot at red_1 launch distance : 58393.43539439338 True True
# 421 blue_1 Splash :red_0
# 435 blue_1 Splash :red_1
# WIN
# blue_0 False True 435 12.658953367413526 11.455139112576001
# blue_1 False True 435 28.776194746723874 138.43681322470584
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 179 blue_0 DOWN
# 473 red_1 Shoot at blue_1
# 484 red_1 Shoot at blue_1
# 577 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 577 -0.10100014063758488 -1.4049277213272922
# blue_1 False False 577 -0.14077690730425155 -18.79977160080269
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 869 red_1 Shoot at blue_1
# 880 red_1 Shoot at blue_1
# 940 red_0 Shoot at blue_1
# 943 blue_1: Destroyed
# 1152 red_0 Shoot at blue_0
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.11300085260117737 -74.33352195593852
# blue_1 False False 1200 -0.10100121926784404 -44.45624056069881
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 652 blue_0 DOWN
# 794 red_1 Shoot at blue_1
# 803 red_0 Shoot at blue_1
# 805 red_1 Shoot at blue_1
# 814 red_0 Shoot at blue_1
# 869 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 869 -0.10099773660267235 -6.923513560369687
# blue_1 False False 869 -0.14316323660267233 -33.5296469193315
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 371 blue_1 Shoot at red_0 launch distance : 59238.633261859504 True True
# Same tgt shoot
# 383 blue_1 Shoot at red_1 launch distance : 55995.22104087376 True True
# 484 blue_1 Splash :red_0
# 495 blue_1 Splash :red_1
# WIN
# blue_0 False True 495 12.425657227887045 4.600214024242421
# blue_1 False True 495 27.773145076371893 142.33164722534434
# ==============================================================
# ...
# 199 blue_1 DOWN
# 803 red_1 Shoot at blue_0
# 806 red_0 Shoot at blue_0
# 814 red_1 Shoot at blue_0
# 817 red_0 Shoot at blue_0
# 880 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 880 -0.14100920621705743 -24.723887635433456
# blue_1 False False 880 -0.10099923955039074 -2.82677860062626
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 291 blue_1 Shoot at red_0 launch distance : 56373.59391866554 True True
# 307 blue_1 Shoot at red_0 launch distance : 48052.03767427843 True True
# Same tgt shoot
# Same tgt shoot
# 340 blue_0 Shoot at red_1 launch distance : 59777.45523926003 True True
# 345 red_1 Shoot at blue_1
# Same tgt shoot
# Same tgt shoot
# 353 blue_0 Shoot at red_1 launch distance : 54262.68173161067 True True
# 356 red_1 Shoot at blue_1
# 396 blue_1 Splash :red_0
# 449 blue_0 DOWN
# 457 blue_0 Splash :red_1
# WIN
# blue_0 False True 556 12.057273381294964 132.52580547545202
# blue_1 False True 556 12.157273381294965 157.39612440856746
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 291 blue_1 Shoot at red_1 launch distance : 57905.130609714586 True True
# 297 blue_0 Shoot at red_1 launch distance : 52857.741553393345 True True
# 303 blue_1 Shoot at red_1 launch distance : 53167.65853253008 True True
# 308 blue_0 Shoot at red_1 launch distance : 48425.06579683433 True True
# 346 red_0 Shoot at blue_0
# 357 red_0 Shoot at blue_0
# 398 blue_1 Splash :red_1
# 412 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.899 101.44779078537637
# blue_1 False False 1200 0.899 53.02639962043548
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 122 blue_0 DOWN
# 1097 red_1 Shoot at blue_1
# 1108 red_1 Shoot at blue_1
# 1110 red_0 Shoot at blue_1
# 1121 red_0 Shoot at blue_1
# 1130 blue_1 DOWN
# TIME LIMIT LOSE
# blue_0 False False 1130 -0.10100047779741941 -1.3046822068723545
# blue_1 False False 1130 -1.1130004777974194 -60.60454196019133
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 2022-04-07 08:56:40,691	WARNING ppo.py:127 -- No data for red_1, not updating kl
# 2022-04-07 08:56:40,691	WARNING ppo.py:127 -- No data for red_0, not updating kl
# agent_timesteps_total: 365422
# custom_metrics: {}
# date: 2022-04-07_08-56-40
# done: false
# episode_len_mean: 633.87
# episode_media: {}
# episode_reward_max: 289.921929884021
# episode_reward_mean: 101.94915877040357
# episode_reward_min: -125.19173855777169
# episodes_this_iter: 47
# episodes_total: 269
# experiment_id: 67406e9c973b4678a42dadfef6f1ea34
# hostname: DESKTOP
# info:
#   learner:
#     blue_0:
#       learner_stats:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0002500000118743628
#         entropy: 7.106440544128418
#         entropy_coeff: 0.0
#         kl: 0.08672266453504562
#         model: {}
#         policy_loss: 0.018908565863966942
#         total_loss: 111.85910034179688
#         vf_explained_var: 0.13868620991706848
#         vf_loss: 111.82283782958984
#       train: null
#     blue_1:
#       learner_stats:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0002500000118743628
#         entropy: 7.42042350769043
#         entropy_coeff: 0.0
#         kl: 0.07520810514688492
#         model: {}
#         policy_loss: -0.002271659905090928
#         total_loss: 146.61801147460938
#         vf_explained_var: 0.21263256669044495
#         vf_loss: 146.60523986816406
#       train: null
#   num_agent_steps_sampled: 365422
#   num_agent_steps_trained: 365422
#   num_steps_sampled: 182711
#   num_steps_trained: 182711
#   num_steps_trained_this_iter: 30557
# iterations_since_restore: 6
# node_ip: 127.0.0.1
# num_healthy_workers: 0
# off_policy_estimator: {}
# perf:
#   cpu_util_percent: 44.48108371639504
#   ram_util_percent: 41.613957375679064
# pid: 22064
# policy_reward_max:
#   blue_0: 158.0600808044833
#   blue_1: 157.39612440856746
# policy_reward_mean:
#   blue_0: 42.77951966345193
#   blue_1: 59.16963910695166
# policy_reward_min:
#   blue_0: -76.6055275162595
#   blue_1: -84.15745891884902
# sampler_perf:
#   mean_action_processing_ms: 0.5645116535865903
#   mean_env_render_ms: 0.0
#   mean_env_wait_ms: 65.12216691126669
#   mean_inference_ms: 18.566647763506285
#   mean_raw_obs_processing_ms: 6.336569350909568
# time_since_restore: 23140.667157411575
# time_this_iter_s: 3901.433344602585
# time_total_s: 23140.667157411575
# timers:
#   learn_throughput: 27.775
#   learn_time_ms: 1096381.348
#   load_throughput: 92320.881
#   load_time_ms: 329.848
#   sample_throughput: 6.505
#   sample_time_ms: 4681250.251
# timestamp: 1649289400
# timesteps_since_restore: 182711
# timesteps_this_iter: 30557
# timesteps_total: 182711
# training_iteration: 6
# trial_id: default
#
#
# -------------- Evaluation at steps:5 starting ! --------------
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 687 blue_0 Shoot at red_0 launch distance : 59886.598336999086 True True
# 698 blue_0 Shoot at red_0 launch distance : 55655.97180047473 True True
# 777 blue_0 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 1.0 55.082049422136485
# blue_1 False False 1200 0.999 46.79124480000034
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 339 red_0 Shoot at blue_1
# 350 red_0 Shoot at blue_1
# 403 blue_1 Shoot at red_0 launch distance : 6747.889908061029 True True
# 409 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.0009980439227514058 96.20662921015091
# blue_1 False False 1200 -0.10099804392275141 29.90661296732498
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 364 blue_0 Shoot at red_1 launch distance : 59083.28238815889 True True
# 402 blue_0 Shoot at red_1 launch distance : 42342.6592854386 True True
# 432 blue_0 Splash :red_1
# Same tgt shoot
# Same tgt shoot
# 461 blue_1 Shoot at red_0 launch distance : 49328.12769950614 True True
# Same tgt shoot
# Same tgt shoot
# 474 blue_1 Shoot at red_0 launch distance : 47970.859200468556 True True
# 581 blue_1 Splash :red_0
# WIN
# blue_0 False True 674 11.780422130267063 119.3797117858226
# blue_1 False True 674 11.779415430267063 119.16647348035295
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 378 red_0 Shoot at blue_1
# 389 red_0 Shoot at blue_1
# 433 blue_1 Shoot at red_0 launch distance : 18533.962185209504 True True
# 472 blue_1 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9989999958668158 12.630215892220138
# blue_1 False False 1200 0.8989999958668158 61.88296785493194
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 354 blue_0 Shoot at red_0 launch distance : 59842.16058306225 True True
# 365 blue_0 Shoot at red_0 launch distance : 54156.777706549154 True True
# 367 red_0 Shoot at blue_1
# 378 red_0 Shoot at blue_1
# 379 blue_1 Shoot at red_0 launch distance : 35401.60859577827 True True
# 425 blue_1: Destroyed
# 428 blue_0 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 1.0000001463141117 89.58260460204461
# blue_1 False False 1200 0.8990001463141116 57.06933671080626
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 363 blue_0 Shoot at red_0 launch distance : 59647.61191138976 True True
# 370 red_0 Shoot at blue_1
# 374 blue_0 Shoot at red_0 launch distance : 54069.11035777248 True True
# 393 red_0 Shoot at blue_1
# 434 blue_0 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9970007735952429 72.6699091381362
# blue_1 False False 1200 0.9990007735952429 30.53994255441881
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 324 blue_0 Shoot at red_0 launch distance : 59886.40730516248 True True
# 335 blue_0 Shoot at red_0 launch distance : 54302.28835903528 True True
# 379 red_0 Shoot at blue_0
# 390 red_0 Shoot at blue_0
# 480 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.10099908023232862 97.94311904684012
# blue_1 False False 1200 -0.0009990802323286139 5.816036928160436
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 377 blue_0 Shoot at red_0 launch distance : 59590.97464376393 True True
# 388 blue_0 Shoot at red_0 launch distance : 54431.343523491254 True True
# 716 red_0 Shoot at blue_0
# 727 red_0 Shoot at blue_0
# 760 red_1 Shoot at blue_0
# 776 red_1 Shoot at blue_0
# 853 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 -0.10100095194013782 172.05861706538252
# blue_1 False False 1200 -0.10100095194013782 -21.824499662742674
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 338 blue_0 Shoot at red_1 launch distance : 19298.018551278114 True True
# Same tgt shoot
# 464 blue_0 Shoot at red_0 launch distance : 57264.63686501015 True True
# 541 blue_0 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 0.9990006423534544 147.61489409723742
# blue_1 False False 1200 0.9990006423534544 29.322651958728255
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 300 blue_0 Shoot at red_0 launch distance : 59805.92113486152 True True
# 316 blue_0 Shoot at red_0 launch distance : 52729.235129304834 True True
# 354 red_0 Shoot at blue_0
# 365 red_0 Shoot at blue_0
# 381 blue_0 Splash :red_0
# TIME LIMIT LOSE
# blue_0 False False 1200 1.0000008604358277 122.53815982904396
# blue_1 False False 1200 0.8990008604358277 -11.29305003604801
#
# ----------------- Training at steps:6 start! -----------------
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 285 blue_0 Shoot at red_0 launch distance : 59120.48272167667 True True
# 288 blue_1 Shoot at red_0 launch distance : 55602.42760321751 True True
# 296 blue_0 Shoot at red_0 launch distance : 53716.544396753954 True True
# 303 blue_1 Shoot at red_0 launch distance : 48740.0785613364 True True
# 338 red_1 Shoot at blue_1
# 349 red_1 Shoot at blue_1
# 396 blue_1 Splash :red_0
# 397 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.994008619939092 58.7633679086321
# blue_1 False False 1200 0.8990006532724253 90.8314252592898
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 245 blue_0 DOWN
# 288 blue_1 Shoot at red_0 launch distance : 59359.30813328252 True True
# 302 blue_1 Shoot at red_0 launch distance : 53701.16718084647 True True
# 339 red_1 Shoot at blue_1
# 350 red_1 Shoot at blue_1
# 398 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 398 -0.10099991971150377 -3.5335497476647886
# blue_1 False False 398 0.35899281362182955 76.85145209594938
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 88 blue_0 DOWN
# 295 blue_1 Shoot at red_1 launch distance : 59881.14949966622 True True
# 318 blue_1 Shoot at red_1 launch distance : 49706.05851158429 True True
# 359 red_0 Shoot at blue_1
# 370 red_0 Shoot at blue_1
# 414 blue_1 Splash :red_1
# 433 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 433 0.8989996201677113 -0.30455721782846945
# blue_1 False False 433 0.8588633535010446 112.85974380583386
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 291 blue_0 Shoot at red_0 launch distance : 56528.692625333555 True True
# 305 blue_0 Shoot at red_0 launch distance : 49318.41528127936 True True
# 337 red_1 Shoot at blue_0
# 348 red_1 Shoot at blue_0
# 397 blue_0 Splash :red_0
# Same tgt shoot
# Same tgt shoot
# 398 blue_1 Shoot at red_1 launch distance : 59155.84963116554 True True
# 404 blue_0: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 1200 0.899 119.33914329558114
# blue_1 False False 1200 0.899 5.3522469000000505
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 103 blue_1 DOWN
# 324 blue_0 Shoot at red_0 launch distance : 57005.857810020316 True True
# Same tgt shoot
# 335 blue_0 Shoot at red_1 launch distance : 58790.75534147393 True True
# 436 blue_0 Splash :red_0
# 447 blue_0 Splash :red_1
# WIN
# blue_0 False True 447 28.55403307679738 146.9335207644644
# blue_1 False True 447 12.584905560018859 11.280419184789698
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 280 blue_1 Shoot at red_1 launch distance : 56393.528523389075 True True
# 293 blue_1 Shoot at red_1 launch distance : 49977.557560403686 True True
# 325 red_0 Shoot at blue_1
# 336 red_0 Shoot at blue_1
# 378 blue_1 Splash :red_1
# 397 blue_1: Destroyed
# Same tgt shoot
# Same tgt shoot
# 507 blue_0 Shoot at red_0 launch distance : 59397.511021062455 True True
# Same tgt shoot
# Same tgt shoot
# 519 blue_0 Shoot at red_0 launch distance : 53260.61108804709 True True
# 621 blue_0 Splash :red_0
# WIN
# blue_0 False True 719 11.667976434306908 122.70715193382374
# blue_1 False True 719 11.567984700973573 116.63599226073762
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 191 blue_0 DOWN
# 324 blue_1 Shoot at red_1 launch distance : 58912.95162746025 True True
# 341 blue_1 Shoot at red_1 launch distance : 50998.432075794124 True True
# 366 red_0 Shoot at blue_1
# 377 red_0 Shoot at blue_1
# 431 blue_1: Destroyed
# TIME LIMIT LOSE
# blue_0 False False 431 0.39899999713287365 -0.9064507505028316
# blue_1 False False 431 0.3587942971328737 100.80519246192839
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
# 269 blue_0 Shoot at red_1 launch distance : 58584.6569581876 True True
# 281 blue_0 Shoot at red_1 launch distance : 52818.243320937705 True True
# Same tgt shoot
# Same tgt shoot
# 292 blue_1 Shoot at red_0 launch distance : 59370.9416558875 True True
# Same tgt shoot
# 305 blue_1 Shoot at red_1 launch distance : 46292.97875039 True True
# 385 blue_0 Splash :red_1
# 405 blue_1 Splash :red_0
# 501 blue_0 DOWN
# WIN
# blue_0 False True 505 12.275237623762376 139.07025305752833
# blue_1 False True 505 12.275231490429043 138.1813778496879
# ==============================================================
# -------------------------- Scene: 0 --------------------------
# ==============================================================
